# %% [markdown]
# ## INFERENCE FOR DINO RGB, NIR

# %%
import torch
import timm
import numpy as np
import pandas as pd
import cv2
import os
import joblib
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# =============== CONFIG ===============
data_root = "/DATA2/akshay/Akshat/NIJ/nir_images"  # Folder with images
csv_path = "/DATA2/akshay/Akshat/metadata/nij_nir.csv"  # Optional: CSV with 'filename' and 'pmi'
model_fold = 1
embedding_model_name = "vit_base_patch16_224_dino"
model_path = f"mlp_model_sam_fold{model_fold}.joblib"
scaler_path = f"scaler_sam_fold{model_fold}.joblib"
device = "cuda" if torch.cuda.is_available() else "cpu"
# =====================================

# ---------- Load MLP and Scaler ----------
mlp = joblib.load(model_path)
scaler = joblib.load(scaler_path)

# ---------- Load DINO Feature Extractor ----------
model = timm.create_model(embedding_model_name, pretrained=True)
model.eval().to(device)

def extract_dino_features(image_paths, batch_size=32):
    features = []
    valid_filenames = []
    for i in tqdm(range(0, len(image_paths), batch_size), desc="Extracting DINO Features"):
        batch_paths = image_paths[i:i + batch_size]
        batch_images = []
        current_filenames = []

        for path in batch_paths:
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"Warning: Unable to load image {path}")
                continue
            img = cv2.resize(img, (224, 224))
            img = np.stack([img] * 3, axis=-1)
            img = torch.tensor(img).permute(2, 0, 1).float() / 255.0
            batch_images.append(img)
            current_filenames.append(os.path.basename(path))

        if not batch_images:
            continue

        batch_tensor = torch.stack(batch_images).to(device)
        with torch.no_grad():
            batch_features = model.forward_features(batch_tensor)
            batch_features = batch_features.cpu().numpy()
        features.append(batch_features)
        valid_filenames.extend(current_filenames)

    return np.vstack(features), valid_filenames

# ---------- Load Images ----------
if csv_path and os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    image_paths = [os.path.join(data_root, fname) for fname in df["filename"]]
    ground_truth = df.set_index("filename")["pmi"].to_dict()
else:
    image_paths = [os.path.join(data_root, f) for f in os.listdir(data_root) if f.endswith(".bmp")]
    ground_truth = None

# ---------- Extract Features ----------
features, valid_filenames = extract_dino_features(image_paths)
features_cls = features[:, 0, :]  # CLS token
features_scaled = scaler.transform(features_cls)

# ---------- Predict PMI ----------
predicted_pmi = mlp.predict(features_scaled)

# ---------- Display Results ----------
for fname, pmi in zip(valid_filenames, predicted_pmi):
    print(f"{fname}: Predicted PMI = {pmi:.2f} hours")

# ---------- Evaluate (if ground truth available) ----------
if ground_truth:
    y_true = [ground_truth[f] for f in valid_filenames if f in ground_truth]
    y_pred = [p for f, p in zip(valid_filenames, predicted_pmi) if f in ground_truth]

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    print("\n================= Evaluation Metrics =================")
    print(f"MAE : {mae:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print(f"R²  : {r2:.3f}")
# Out:
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/timm/models/_factory.py:126: UserWarning: Mapping deprecated model name vit_base_patch16_224_dino to current vit_base_patch16_224.dino.
#   model = create_fn(
# Extracting DINO Features: 100%|██████████| 177/177 [00:19<00:00,  9.25it/s]
# 9170R_1_10.bmp: Predicted PMI = 5.58 hours
# 9259R_2_2.bmp: Predicted PMI = 8.97 hours
# 9223R_3_5.bmp: Predicted PMI = 14.94 hours
# 9124L_9_3.bmp: Predicted PMI = 5.45 hours
# 9181L_2_5.bmp: Predicted PMI = 29.79 hours
# 9174L_1_5.bmp: Predicted PMI = 5.52 hours
# 9261R_1_4.bmp: Predicted PMI = 71.68 hours
# 9088R_3_3.bmp: Predicted PMI = 6.00 hours
# 9191L_1_4.bmp: Predicted PMI = 8.61 hours
# 9248R_1_3.bmp: Predicted PMI = 8.68 hours
# 9016L_1_1.bmp: Predicted PMI = 9.94 hours
# 9180R_1_1.bmp: Predicted PMI = 26.53 hours
# 9052L_6_1.bmp: Predicted PMI = 11.70 hours
# 9175R_2_1.bmp: Predicted PMI = 8.52 hours
# 9259L_1_6.bmp: Predicted PMI = 10.44 hours
# 9101L_1_10.bmp: Predicted PMI = 3.19 hours
# 9190L_1_4.bmp: Predicted PMI = 4.26 hours
# 9260R_1_4.bmp: Predicted PMI = 11.79 hours
# 9224R_6_4.bmp: Predicted PMI = 8.85 hours
# 9017L_1_1.bmp: Predicted PMI = 9.19 hours
# 9174R_2_1.bmp: Predicted PMI = 10.55 hours
# 9258L_1_6.bmp: Predicted PMI = 25.79 hours
# 9181R_1_1.bmp: Predicted PMI = 25.63 hours
# 9049L_3_5.bmp: Predicted PMI = 4.90 hours
# 9206L_3_2.bmp: Predicted PMI = 18.52 hours
# 9179R_1_5.bmp: Predicted PMI = 5.14 hours
# 9060L_3_2.bmp: Predicted PMI = 6.21 hours
# 9033L_2_2.bmp: Predicted PMI = 13.56 hours
# 9150R_1_2.bmp: Predicted PMI = 8.33 hours
# 9083R_13_3.bmp: Predicted PMI = 23.52 hours
# 9083L_6_2.bmp: Predicted PMI = 10.06 hours
# 9151R_1_2.bmp: Predicted PMI = 5.60 hours
# 9083L_15_1.bmp: Predicted PMI = 6.31 hours
# 9207L_3_2.bmp: Predicted PMI = 96.49 hours
# 9178R_1_5.bmp: Predicted PMI = 12.45 hours
# 9112R_3_3.bmp: Predicted PMI = 15.99 hours
# 9168R_2_4.bmp: Predicted PMI = 11.24 hours
# 9244L_1_3.bmp: Predicted PMI = 12.17 hours
# 9103L_3_6.bmp: Predicted PMI = 5.75 hours
# 9169R_2_4.bmp: Predicted PMI = 6.99 hours
# 9129L_27_3.bmp: Predicted PMI = 95.70 hours
# 9023L_1_3.bmp: Predicted PMI = 9.29 hours
# 9228L_6_4.bmp: Predicted PMI = 18.17 hours
# 9113R_3_3.bmp: Predicted PMI = 5.10 hours
# 9140R_2_3.bmp: Predicted PMI = 16.39 hours
# 9092L_5_3.bmp: Predicted PMI = 7.47 hours
# 9178L_2_1.bmp: Predicted PMI = 25.89 hours
# 9254R_1_6.bmp: Predicted PMI = 11.65 hours
# 9083L_1_13.bmp: Predicted PMI = 10.02 hours
# 9083R_5_6.bmp: Predicted PMI = 6.90 hours
# 9045R_1_7.bmp: Predicted PMI = 9.16 hours
# 9232L_1_2.bmp: Predicted PMI = 30.31 hours
# 9137R_2_2.bmp: Predicted PMI = 3.11 hours
# 9054L_1_2.bmp: Predicted PMI = 4.99 hours
# 9136R_2_2.bmp: Predicted PMI = 26.99 hours
# 9055L_1_2.bmp: Predicted PMI = 11.42 hours
# 9233L_1_2.bmp: Predicted PMI = 12.15 hours
# 9224L_7_2.bmp: Predicted PMI = 10.01 hours
# 9126R_1_3.bmp: Predicted PMI = 22.75 hours
# 9259L_3_4.bmp: Predicted PMI = 9.68 hours
# 9052L_4_3.bmp: Predicted PMI = 10.59 hours
# 9180R_3_3.bmp: Predicted PMI = 20.85 hours
# 9202L_3_8.bmp: Predicted PMI = 15.03 hours
# 9016L_3_3.bmp: Predicted PMI = 59.79 hours
# 9223L_2_3.bmp: Predicted PMI = 25.07 hours
# 9099L_1_4.bmp: Predicted PMI = 7.16 hours
# 9088R_1_1.bmp: Predicted PMI = 5.93 hours
# 9222L_2_3.bmp: Predicted PMI = 7.75 hours
# 9098L_1_4.bmp: Predicted PMI = 9.23 hours
# 9181R_3_3.bmp: Predicted PMI = 29.51 hours
# 9127R_1_3.bmp: Predicted PMI = 20.93 hours
# 9044L_2_3.bmp: Predicted PMI = 50.89 hours
# 9017L_3_3.bmp: Predicted PMI = 27.17 hours
# 9089R_1_1.bmp: Predicted PMI = 39.17 hours
# 9129L_38_4.bmp: Predicted PMI = 12.27 hours
# 9049L_1_7.bmp: Predicted PMI = 6.40 hours
# 9112L_2_5.bmp: Predicted PMI = 86.25 hours
# 9217R_1_5.bmp: Predicted PMI = 13.08 hours
# 9059R_1_2.bmp: Predicted PMI = 7.46 hours
# 9216R_1_5.bmp: Predicted PMI = 6.57 hours
# 9083R_11_1.bmp: Predicted PMI = 11.20 hours
# 9228R_7_2.bmp: Predicted PMI = 15.27 hours
# 9113L_2_5.bmp: Predicted PMI = 28.70 hours
# 9049R_2_3.bmp: Predicted PMI = 7.26 hours
# 9206R_2_4.bmp: Predicted PMI = 38.18 hours
# 9129L_8_5.bmp: Predicted PMI = 8.62 hours
# 9103L_1_4.bmp: Predicted PMI = 7.78 hours
# 9129L_46_2.bmp: Predicted PMI = 84.41 hours
# 9112R_1_1.bmp: Predicted PMI = 100.72 hours
# 9084L_1_1.bmp: Predicted PMI = 41.90 hours
# 9071L_2_1.bmp: Predicted PMI = 35.66 hours
# 9094R_1_4.bmp: Predicted PMI = 5.60 hours
# 9083R_7_4.bmp: Predicted PMI = 11.13 hours
# 9102L_1_4.bmp: Predicted PMI = 7.59 hours
# 9048R_2_3.bmp: Predicted PMI = 11.49 hours
# 9207R_2_4.bmp: Predicted PMI = 6.78 hours
# 9085L_1_1.bmp: Predicted PMI = 29.10 hours
# 9129L_25_1.bmp: Predicted PMI = 16.72 hours
# 9245L_3_1.bmp: Predicted PMI = 34.70 hours
# 9216L_2_1.bmp: Predicted PMI = 23.46 hours
# 9201L_4_1.bmp: Predicted PMI = 6.52 hours
# 9130L_2_1.bmp: Predicted PMI = 5.92 hours
# 9174L_5_1.bmp: Predicted PMI = 11.05 hours
# 9053R_1_1.bmp: Predicted PMI = 6.90 hours
# 9235R_1_1.bmp: Predicted PMI = 7.81 hours
# 9224L_1_4.bmp: Predicted PMI = 10.80 hours
# 9108R_2_3.bmp: Predicted PMI = 3.94 hours
# 9234R_1_1.bmp: Predicted PMI = 26.36 hours
# 9131L_2_1.bmp: Predicted PMI = 17.18 hours
# 9016R_6_1.bmp: Predicted PMI = 12.21 hours
# 9052R_1_1.bmp: Predicted PMI = 16.97 hours
# 9225L_1_4.bmp: Predicted PMI = 4.21 hours
# 9109R_2_3.bmp: Predicted PMI = 7.67 hours
# 9119R_1_2.bmp: Predicted PMI = 4.08 hours
# 9130R_1_5.bmp: Predicted PMI = 5.72 hours
# 9131R_1_5.bmp: Predicted PMI = 61.86 hours
# 9016L_5_5.bmp: Predicted PMI = 7.25 hours
# 9129L_18_1.bmp: Predicted PMI = 18.57 hours
# 9118R_1_2.bmp: Predicted PMI = 5.35 hours
# 9239L_1_1.bmp: Predicted PMI = 14.52 hours
# 9176L_2_8.bmp: Predicted PMI = 129.10 hours
# 9228R_1_4.bmp: Predicted PMI = 8.34 hours
# 9104L_2_3.bmp: Predicted PMI = 6.01 hours
# 9140L_5_3.bmp: Predicted PMI = 20.28 hours
# 9113L_4_3.bmp: Predicted PMI = 25.23 hours
# 9092R_2_3.bmp: Predicted PMI = 7.90 hours
# 9238L_1_1.bmp: Predicted PMI = 15.19 hours
# 9049L_7_1.bmp: Predicted PMI = 17.35 hours
# 9229R_1_4.bmp: Predicted PMI = 95.55 hours
# 9093R_2_3.bmp: Predicted PMI = 3.22 hours
# 9112L_4_3.bmp: Predicted PMI = 15.31 hours
# 9200R_1_3.bmp: Predicted PMI = 40.56 hours
# 9177L_2_8.bmp: Predicted PMI = 8.98 hours
# 9014R_1_8.bmp: Predicted PMI = 11.43 hours
# 9160L_4_8.bmp: Predicted PMI = 5.57 hours
# 9115L_1_2.bmp: Predicted PMI = 40.71 hours
# 9083R_1_2.bmp: Predicted PMI = 67.81 hours
# 9210R_2_2.bmp: Predicted PMI = 12.27 hours
# 9092L_1_7.bmp: Predicted PMI = 4.66 hours
# 9129L_23_7.bmp: Predicted PMI = 4.96 hours
# 9211R_2_2.bmp: Predicted PMI = 13.31 hours
# 9242R_3_2.bmp: Predicted PMI = 8.00 hours
# 9049R_4_5.bmp: Predicted PMI = 7.89 hours
# 9206R_4_2.bmp: Predicted PMI = 18.48 hours
# 9114L_1_2.bmp: Predicted PMI = 9.82 hours
# 9103L_7_2.bmp: Predicted PMI = 166.10 hours
# 9082R_1_2.bmp: Predicted PMI = 10.80 hours
# 9038L_2_1.bmp: Predicted PMI = 35.37 hours
# 9172R_1_6.bmp: Predicted PMI = 100.06 hours
# 9160L_8_5.bmp: Predicted PMI = 7.60 hours
# 9111L_1_8.bmp: Predicted PMI = 14.06 hours
# 9053R_3_3.bmp: Predicted PMI = 7.24 hours
# 9163L_1_3.bmp: Predicted PMI = 3.05 hours
# 9173R_1_6.bmp: Predicted PMI = 5.95 hours
# 9052R_3_3.bmp: Predicted PMI = 7.07 hours
# 9016R_4_3.bmp: Predicted PMI = 6.79 hours
# 9162L_1_3.bmp: Predicted PMI = 54.22 hours
# 9223R_5_3.bmp: Predicted PMI = 67.18 hours
# 9110L_1_8.bmp: Predicted PMI = 7.97 hours
# 9011R_1_2.bmp: Predicted PMI = 21.05 hours
# 9187L_1_2.bmp: Predicted PMI = 17.40 hours
# 9010R_1_2.bmp: Predicted PMI = 20.57 hours
# 9173L_2_2.bmp: Predicted PMI = 20.44 hours
# 9186L_1_2.bmp: Predicted PMI = 6.77 hours
# 9175R_4_7.bmp: Predicted PMI = 9.15 hours
# 9034R_2_1.bmp: Predicted PMI = 4.89 hours
# 9140L_7_1.bmp: Predicted PMI = 9.69 hours
# 9157L_1_1.bmp: Predicted PMI = 20.55 hours
# 9201R_3_1.bmp: Predicted PMI = 5.42 hours
# 9146R_1_4.bmp: Predicted PMI = 6.48 hours
# 9080L_9_2.bmp: Predicted PMI = 9.72 hours
# 9112L_6_1.bmp: Predicted PMI = 29.59 hours
# 9156L_1_1.bmp: Predicted PMI = 12.23 hours
# 9049L_5_3.bmp: Predicted PMI = 7.18 hours
# 9242L_2_4.bmp: Predicted PMI = 34.27 hours
# 9147R_1_4.bmp: Predicted PMI = 11.74 hours
# 9103R_6_4.bmp: Predicted PMI = 44.33 hours
# 9252L_1_5.bmp: Predicted PMI = 3.16 hours
# 9129L_21_5.bmp: Predicted PMI = 28.13 hours
# 9092L_3_5.bmp: Predicted PMI = 32.34 hours
# 9253L_1_5.bmp: Predicted PMI = 5.20 hours
# 9129L_42_6.bmp: Predicted PMI = 34.24 hours
# 9129L_42_7.bmp: Predicted PMI = 80.82 hours
# 9253L_1_4.bmp: Predicted PMI = 10.16 hours
# 9035L_1_4.bmp: Predicted PMI = 34.48 hours
# 9112R_5_4.bmp: Predicted PMI = 20.38 hours
# 9156R_2_4.bmp: Predicted PMI = 6.80 hours
# 9049R_6_6.bmp: Predicted PMI = 9.39 hours
# 9242R_1_1.bmp: Predicted PMI = 13.86 hours
# 9114L_3_1.bmp: Predicted PMI = 9.98 hours
# 9092L_3_4.bmp: Predicted PMI = 12.32 hours
# 9140R_4_4.bmp: Predicted PMI = 15.00 hours
# 9113R_5_4.bmp: Predicted PMI = 27.98 hours
# 9034L_1_4.bmp: Predicted PMI = 5.33 hours
# 9157R_2_4.bmp: Predicted PMI = 29.00 hours
# 9252L_1_4.bmp: Predicted PMI = 4.69 hours
# 9083R_3_1.bmp: Predicted PMI = 12.22 hours
# 9025R_1_1.bmp: Predicted PMI = 6.48 hours
# 9243R_1_1.bmp: Predicted PMI = 12.87 hours
# 9147R_1_5.bmp: Predicted PMI = 20.15 hours
# 9049L_5_2.bmp: Predicted PMI = 8.43 hours
# 9242L_2_5.bmp: Predicted PMI = 22.72 hours
# 9080L_9_3.bmp: Predicted PMI = 9.86 hours
# 9146R_1_5.bmp: Predicted PMI = 5.63 hours
# 9186L_1_3.bmp: Predicted PMI = 5.70 hours
# 9173L_2_3.bmp: Predicted PMI = 14.52 hours
# 9101L_2_8.bmp: Predicted PMI = 15.49 hours
# 9039R_1_4.bmp: Predicted PMI = 9.01 hours
# 9175R_4_6.bmp: Predicted PMI = 4.10 hours
# 9028L_1_1.bmp: Predicted PMI = 6.39 hours
# 9038R_1_4.bmp: Predicted PMI = 36.58 hours
# 9187L_1_3.bmp: Predicted PMI = 5.39 hours
# 9029L_1_1.bmp: Predicted PMI = 9.08 hours
# 9173R_1_7.bmp: Predicted PMI = 9.06 hours
# 9110L_1_9.bmp: Predicted PMI = 8.15 hours
# 9223R_5_2.bmp: Predicted PMI = 17.24 hours
# 9162L_1_2.bmp: Predicted PMI = 57.08 hours
# 9016R_4_2.bmp: Predicted PMI = 9.32 hours
# 9052R_3_2.bmp: Predicted PMI = 8.73 hours
# 9172R_1_7.bmp: Predicted PMI = 44.77 hours
# 9163L_1_2.bmp: Predicted PMI = 2.40 hours
# 9053R_3_2.bmp: Predicted PMI = 7.07 hours
# 9160L_8_4.bmp: Predicted PMI = 9.09 hours
# 9082R_1_3.bmp: Predicted PMI = 9.60 hours
# 9103L_7_3.bmp: Predicted PMI = 107.65 hours
# 9238R_2_4.bmp: Predicted PMI = 4.88 hours
# 9114L_1_3.bmp: Predicted PMI = 30.67 hours
# 9206R_4_3.bmp: Predicted PMI = 21.37 hours
# 9242R_3_3.bmp: Predicted PMI = 15.42 hours
# 9049R_4_4.bmp: Predicted PMI = 7.89 hours
# 9211R_2_3.bmp: Predicted PMI = 16.84 hours
# 9229L_2_1.bmp: Predicted PMI = 14.09 hours
# 9210R_2_3.bmp: Predicted PMI = 13.05 hours
# 9083R_1_3.bmp: Predicted PMI = 67.81 hours
# 9239R_2_4.bmp: Predicted PMI = 13.05 hours
# 9115L_1_3.bmp: Predicted PMI = 46.11 hours
# 9129L_23_6.bmp: Predicted PMI = 5.91 hours
# 9228L_2_1.bmp: Predicted PMI = 21.68 hours
# 9092L_1_6.bmp: Predicted PMI = 4.66 hours
# 9200R_1_2.bmp: Predicted PMI = 34.08 hours
# 9112L_4_2.bmp: Predicted PMI = 31.56 hours
# 9093R_2_2.bmp: Predicted PMI = 4.82 hours
# 9092R_2_2.bmp: Predicted PMI = 7.90 hours
# 9113L_4_2.bmp: Predicted PMI = 30.57 hours
# 9140L_5_2.bmp: Predicted PMI = 34.52 hours
# 9228R_1_5.bmp: Predicted PMI = 11.88 hours
# 9104L_2_2.bmp: Predicted PMI = 8.98 hours
# 9201R_1_2.bmp: Predicted PMI = 5.97 hours
# 9118R_1_3.bmp: Predicted PMI = 11.52 hours
# 9223L_4_4.bmp: Predicted PMI = 13.10 hours
# 9016L_5_4.bmp: Predicted PMI = 14.97 hours
# 9131R_1_4.bmp: Predicted PMI = 20.67 hours
# 9225R_2_1.bmp: Predicted PMI = 14.94 hours
# 9120L_1_1.bmp: Predicted PMI = 14.89 hours
# 9130R_1_4.bmp: Predicted PMI = 9.44 hours
# 9235L_2_4.bmp: Predicted PMI = 33.53 hours
# 9119R_1_3.bmp: Predicted PMI = 4.67 hours
# 9187L_3_1.bmp: Predicted PMI = 45.30 hours
# 9121L_1_1.bmp: Predicted PMI = 7.04 hours
# 9224R_2_1.bmp: Predicted PMI = 11.95 hours
# 9225L_1_5.bmp: Predicted PMI = 7.79 hours
# 9109R_2_2.bmp: Predicted PMI = 9.54 hours
# 9224L_1_5.bmp: Predicted PMI = 12.47 hours
# 9108R_2_2.bmp: Predicted PMI = 6.99 hours
# 9048R_2_2.bmp: Predicted PMI = 10.23 hours
# 9102L_1_5.bmp: Predicted PMI = 15.99 hours
# 9083R_7_5.bmp: Predicted PMI = 8.26 hours
# 9103L_1_5.bmp: Predicted PMI = 5.80 hours
# 9129L_8_4.bmp: Predicted PMI = 8.62 hours
# 9049R_2_2.bmp: Predicted PMI = 7.26 hours
# 9129L_46_3.bmp: Predicted PMI = 84.87 hours
# 9061L_1_1.bmp: Predicted PMI = 47.22 hours
# 9083L_4_1.bmp: Predicted PMI = 6.51 hours
# 9151R_3_1.bmp: Predicted PMI = 24.80 hours
# 9207L_1_1.bmp: Predicted PMI = 6.14 hours
# 9113L_2_4.bmp: Predicted PMI = 9.57 hours
# 9140L_3_4.bmp: Predicted PMI = 6.42 hours
# 9228R_7_3.bmp: Predicted PMI = 12.87 hours
# 9216R_1_4.bmp: Predicted PMI = 11.39 hours
# 9059R_1_3.bmp: Predicted PMI = 5.80 hours
# 9049L_1_6.bmp: Predicted PMI = 6.40 hours
# 9206L_1_1.bmp: Predicted PMI = 30.18 hours
# 9060L_1_1.bmp: Predicted PMI = 6.08 hours
# 9103R_2_1.bmp: Predicted PMI = 7.61 hours
# 9217R_1_4.bmp: Predicted PMI = 15.86 hours
# 9112L_2_4.bmp: Predicted PMI = 69.29 hours
# 9071R_1_4.bmp: Predicted PMI = 11.19 hours
# 9017L_3_2.bmp: Predicted PMI = 19.76 hours
# 9044L_2_2.bmp: Predicted PMI = 70.38 hours
# 9127R_1_2.bmp: Predicted PMI = 13.25 hours
# 9181R_3_2.bmp: Predicted PMI = 17.23 hours
# 9098L_1_5.bmp: Predicted PMI = 7.52 hours
# 9124R_8_4.bmp: Predicted PMI = 9.67 hours
# 9222L_2_2.bmp: Predicted PMI = 7.27 hours
# 9099L_1_5.bmp: Predicted PMI = 7.49 hours
# 9223L_2_2.bmp: Predicted PMI = 31.61 hours
# 9016L_3_2.bmp: Predicted PMI = 8.66 hours
# 9180R_3_2.bmp: Predicted PMI = 10.25 hours
# 9259L_3_5.bmp: Predicted PMI = 6.37 hours
# 9052L_4_2.bmp: Predicted PMI = 11.17 hours
# 9126R_1_2.bmp: Predicted PMI = 22.15 hours
# 9222R_1_6.bmp: Predicted PMI = 9.39 hours
# 9098R_2_1.bmp: Predicted PMI = 8.64 hours
# 9224L_7_3.bmp: Predicted PMI = 11.04 hours
# 9233L_1_3.bmp: Predicted PMI = 19.27 hours
# 9055L_1_3.bmp: Predicted PMI = 10.84 hours
# 9136R_2_3.bmp: Predicted PMI = 8.19 hours
# 9045R_1_6.bmp: Predicted PMI = 7.67 hours
# 9054L_1_3.bmp: Predicted PMI = 4.81 hours
# 9137R_2_3.bmp: Predicted PMI = 13.15 hours
# 9232L_1_3.bmp: Predicted PMI = 21.93 hours
# 9092L_5_2.bmp: Predicted PMI = 13.75 hours
# 9140R_2_2.bmp: Predicted PMI = 9.59 hours
# 9113R_3_2.bmp: Predicted PMI = 9.92 hours
# 9023L_1_2.bmp: Predicted PMI = 4.04 hours
# 9228L_6_5.bmp: Predicted PMI = 7.99 hours
# 9129L_27_2.bmp: Predicted PMI = 39.52 hours
# 9083L_1_12.bmp: Predicted PMI = 10.02 hours
# 9254R_1_7.bmp: Predicted PMI = 16.41 hours
# 9244L_1_2.bmp: Predicted PMI = 12.67 hours
# 9129L_44_1.bmp: Predicted PMI = 67.32 hours
# 9112R_3_2.bmp: Predicted PMI = 87.77 hours
# 9022L_1_2.bmp: Predicted PMI = 11.12 hours
# 9103L_3_7.bmp: Predicted PMI = 6.10 hours
# 9169L_1_1.bmp: Predicted PMI = 8.58 hours
# 9083R_13_2.bmp: Predicted PMI = 8.66 hours
# 9228R_5_1.bmp: Predicted PMI = 9.36 hours
# 9178R_1_4.bmp: Predicted PMI = 16.48 hours
# 9207L_3_3.bmp: Predicted PMI = 32.92 hours
# 9151R_1_3.bmp: Predicted PMI = 6.79 hours
# 9168L_1_1.bmp: Predicted PMI = 18.34 hours
# 9150R_1_3.bmp: Predicted PMI = 6.05 hours
# 9033L_2_3.bmp: Predicted PMI = 4.55 hours
# 9060L_3_3.bmp: Predicted PMI = 5.16 hours
# 9179R_1_4.bmp: Predicted PMI = 9.12 hours
# 9206L_3_3.bmp: Predicted PMI = 13.93 hours
# 9049L_3_4.bmp: Predicted PMI = 4.90 hours
# 9260R_1_5.bmp: Predicted PMI = 9.57 hours
# 9190L_1_5.bmp: Predicted PMI = 4.36 hours
# 9258L_1_7.bmp: Predicted PMI = 16.84 hours
# 9248R_1_2.bmp: Predicted PMI = 5.25 hours
# 9191L_1_5.bmp: Predicted PMI = 7.00 hours
# 9088R_3_2.bmp: Predicted PMI = 7.37 hours
# 9261R_1_5.bmp: Predicted PMI = 73.40 hours
# 9259L_1_7.bmp: Predicted PMI = 5.58 hours
# 9165R_1_1.bmp: Predicted PMI = 10.06 hours
# 9187R_4_1.bmp: Predicted PMI = 10.88 hours
# 9224L_5_1.bmp: Predicted PMI = 14.71 hours
# 9174L_1_4.bmp: Predicted PMI = 9.36 hours
# 9181L_2_4.bmp: Predicted PMI = 7.21 hours
# 9124L_9_2.bmp: Predicted PMI = 24.17 hours
# 9222R_3_4.bmp: Predicted PMI = 12.95 hours
# 9191R_2_1.bmp: Predicted PMI = 6.95 hours
# 9164R_1_1.bmp: Predicted PMI = 9.84 hours
# 9007L_2_1.bmp: Predicted PMI = 22.99 hours
# 9223R_3_4.bmp: Predicted PMI = 42.10 hours
# 9259R_2_3.bmp: Predicted PMI = 8.37 hours
# 9181L_2_6.bmp: Predicted PMI = 12.30 hours
# 9174L_1_6.bmp: Predicted PMI = 5.52 hours
# 9224L_5_3.bmp: Predicted PMI = 14.11 hours
# 9187R_4_3.bmp: Predicted PMI = 9.33 hours
# 9249L_2_4.bmp: Predicted PMI = 55.52 hours
# 9165R_1_3.bmp: Predicted PMI = 10.27 hours
# 9259R_2_1.bmp: Predicted PMI = 8.97 hours
# 9248L_2_4.bmp: Predicted PMI = 15.06 hours
# 9164R_1_3.bmp: Predicted PMI = 9.07 hours
# 9191R_2_3.bmp: Predicted PMI = 23.17 hours
# 9017L_1_2.bmp: Predicted PMI = 8.79 hours
# 9258L_1_5.bmp: Predicted PMI = 25.79 hours
# 9174R_2_2.bmp: Predicted PMI = 10.55 hours
# 9181R_1_2.bmp: Predicted PMI = 20.16 hours
# 9203L_1_9.bmp: Predicted PMI = 7.70 hours
# 9260R_1_7.bmp: Predicted PMI = 12.76 hours
# 9016L_1_2.bmp: Predicted PMI = 8.12 hours
# 9180R_1_2.bmp: Predicted PMI = 26.53 hours
# 9202L_1_9.bmp: Predicted PMI = 21.07 hours
# 9259L_1_5.bmp: Predicted PMI = 10.44 hours
# 9052L_6_2.bmp: Predicted PMI = 11.80 hours
# 9175R_2_2.bmp: Predicted PMI = 8.52 hours
# 9261R_1_7.bmp: Predicted PMI = 75.66 hours
# 9083L_6_1.bmp: Predicted PMI = 9.66 hours
# 9151R_1_1.bmp: Predicted PMI = 9.75 hours
# 9083L_15_2.bmp: Predicted PMI = 10.93 hours
# 9178R_1_6.bmp: Predicted PMI = 12.45 hours
# 9207L_3_1.bmp: Predicted PMI = 85.85 hours
# 9140L_1_4.bmp: Predicted PMI = 9.97 hours
# 9228R_5_3.bmp: Predicted PMI = 6.51 hours
# 9245R_2_4.bmp: Predicted PMI = 41.61 hours
# 9169L_1_3.bmp: Predicted PMI = 6.87 hours
# 9216R_3_4.bmp: Predicted PMI = 17.34 hours
# 9049L_3_6.bmp: Predicted PMI = 4.90 hours
# 9179R_1_6.bmp: Predicted PMI = 5.14 hours
# 9206L_3_1.bmp: Predicted PMI = 35.22 hours
# 9033L_2_1.bmp: Predicted PMI = 14.01 hours
# 9060L_3_1.bmp: Predicted PMI = 10.73 hours
# 9150R_1_1.bmp: Predicted PMI = 8.74 hours
# 9244R_2_4.bmp: Predicted PMI = 5.66 hours
# 9168L_1_3.bmp: Predicted PMI = 14.89 hours
# 9141L_1_4.bmp: Predicted PMI = 5.91 hours
# 9254R_1_5.bmp: Predicted PMI = 11.65 hours
# 9178L_2_2.bmp: Predicted PMI = 25.89 hours
# 9083L_1_10.bmp: Predicted PMI = 8.10 hours
# 9083R_5_5.bmp: Predicted PMI = 6.90 hours
# 9103L_3_5.bmp: Predicted PMI = 5.75 hours
# 9129L_44_3.bmp: Predicted PMI = 52.15 hours
# 9136R_2_1.bmp: Predicted PMI = 6.82 hours
# 9055L_1_1.bmp: Predicted PMI = 12.91 hours
# 9233L_1_1.bmp: Predicted PMI = 12.92 hours
# 9224L_7_1.bmp: Predicted PMI = 28.18 hours
# 9127L_2_4.bmp: Predicted PMI = 40.29 hours
# 9098R_2_3.bmp: Predicted PMI = 5.73 hours
# 9222R_1_4.bmp: Predicted PMI = 16.18 hours
# 9232L_1_1.bmp: Predicted PMI = 8.00 hours
# 9137R_2_1.bmp: Predicted PMI = 2.98 hours
# 9054L_1_1.bmp: Predicted PMI = 10.83 hours
# 9223R_1_4.bmp: Predicted PMI = 12.68 hours
# 9045R_1_4.bmp: Predicted PMI = 5.90 hours
# 9089R_1_2.bmp: Predicted PMI = 41.46 hours
# 9137L_1_5.bmp: Predicted PMI = 3.90 hours
# 9088R_1_2.bmp: Predicted PMI = 8.03 hours
# 9259L_3_7.bmp: Predicted PMI = 5.60 hours
# 9113L_1_14.bmp: Predicted PMI = 8.31 hours
# 9059R_1_1.bmp: Predicted PMI = 7.79 hours
# 9083R_11_2.bmp: Predicted PMI = 17.65 hours
# 9228R_7_1.bmp: Predicted PMI = 8.62 hours
# 9207L_1_3.bmp: Predicted PMI = 7.50 hours
# 9170R_2_8.bmp: Predicted PMI = 7.68 hours
# 9151R_3_3.bmp: Predicted PMI = 14.87 hours
# 9083L_4_3.bmp: Predicted PMI = 9.23 hours
# 9061L_1_3.bmp: Predicted PMI = 57.98 hours
# 9112L_2_6.bmp: Predicted PMI = 86.25 hours
# 9058R_1_1.bmp: Predicted PMI = 7.54 hours
# 9103R_2_3.bmp: Predicted PMI = 17.58 hours
# 9060L_1_3.bmp: Predicted PMI = 6.64 hours
# 9206L_1_3.bmp: Predicted PMI = 10.03 hours
# 9049L_1_4.bmp: Predicted PMI = 7.83 hours
# 9129L_25_2.bmp: Predicted PMI = 9.36 hours
# 9085L_1_2.bmp: Predicted PMI = 22.91 hours
# 9216L_2_2.bmp: Predicted PMI = 9.36 hours
# 9245L_3_2.bmp: Predicted PMI = 20.01 hours
# 9201L_4_2.bmp: Predicted PMI = 8.87 hours
# 9176L_1_10.bmp: Predicted PMI = 5.16 hours
# 9129L_46_1.bmp: Predicted PMI = 84.41 hours
# 9112R_1_2.bmp: Predicted PMI = 100.72 hours
# 9084L_1_2.bmp: Predicted PMI = 6.76 hours
# 9071L_2_2.bmp: Predicted PMI = 25.23 hours
# 9103L_1_7.bmp: Predicted PMI = 6.59 hours
# 9234R_1_2.bmp: Predicted PMI = 24.54 hours
# 9131L_2_2.bmp: Predicted PMI = 84.79 hours
# 9016R_6_2.bmp: Predicted PMI = 5.91 hours
# 9052R_1_2.bmp: Predicted PMI = 15.29 hours
# 9130L_2_2.bmp: Predicted PMI = 5.23 hours
# 9174L_5_2.bmp: Predicted PMI = 11.05 hours
# 9053R_1_2.bmp: Predicted PMI = 11.62 hours
# 9235R_1_2.bmp: Predicted PMI = 13.21 hours
# 9120L_1_3.bmp: Predicted PMI = 8.94 hours
# 9109L_1_4.bmp: Predicted PMI = 8.13 hours
# 9225R_2_3.bmp: Predicted PMI = 7.92 hours
# 9016L_5_6.bmp: Predicted PMI = 5.30 hours
# 9129L_18_2.bmp: Predicted PMI = 46.88 hours
# 9118R_1_1.bmp: Predicted PMI = 11.01 hours
# 9108L_1_4.bmp: Predicted PMI = 6.26 hours
# 9224R_2_3.bmp: Predicted PMI = 12.84 hours
# 9121L_1_3.bmp: Predicted PMI = 20.56 hours
# 9187L_3_3.bmp: Predicted PMI = 89.05 hours
# 9256R_2_8.bmp: Predicted PMI = 97.92 hours
# 9119R_1_1.bmp: Predicted PMI = 4.14 hours
# 9238L_1_2.bmp: Predicted PMI = 11.38 hours
# 9049L_7_2.bmp: Predicted PMI = 17.35 hours
# 9210L_1_5.bmp: Predicted PMI = 8.74 hours
# 9076L_1_5.bmp: Predicted PMI = 26.02 hours
# 9239L_1_2.bmp: Predicted PMI = 18.16 hours
# 9112R_7_4.bmp: Predicted PMI = 40.13 hours
# 9093L_1_4.bmp: Predicted PMI = 3.79 hours
# 9229L_2_3.bmp: Predicted PMI = 36.38 hours
# 9049R_4_6.bmp: Predicted PMI = 7.89 hours
# 9242R_3_1.bmp: Predicted PMI = 17.58 hours
# 9211R_2_1.bmp: Predicted PMI = 17.55 hours
# 9206R_4_1.bmp: Predicted PMI = 8.31 hours
# 9114L_1_1.bmp: Predicted PMI = 20.85 hours
# 9103L_7_1.bmp: Predicted PMI = 40.00 hours
# 9082R_1_1.bmp: Predicted PMI = 6.71 hours
# 9092L_1_4.bmp: Predicted PMI = 5.21 hours
# 9140R_6_4.bmp: Predicted PMI = 17.13 hours
# 9104R_1_4.bmp: Predicted PMI = 5.86 hours
# 9228L_2_3.bmp: Predicted PMI = 53.02 hours
# 9129L_23_4.bmp: Predicted PMI = 18.77 hours
# 9201L_2_4.bmp: Predicted PMI = 6.13 hours
# 9115L_1_1.bmp: Predicted PMI = 25.67 hours
# 9083R_1_1.bmp: Predicted PMI = 8.50 hours
# 9210R_2_1.bmp: Predicted PMI = 14.90 hours
# 9173R_1_5.bmp: Predicted PMI = 5.95 hours
# 9160L_8_6.bmp: Predicted PMI = 7.60 hours
# 9038L_2_2.bmp: Predicted PMI = 77.99 hours
# 9172R_1_5.bmp: Predicted PMI = 100.06 hours
# 9129R_1_9.bmp: Predicted PMI = 94.16 hours
# 9028L_1_3.bmp: Predicted PMI = 5.83 hours
# 9016L_7_4.bmp: Predicted PMI = 9.57 hours
# 9197R_1_4.bmp: Predicted PMI = 40.84 hours
# 9175R_4_4.bmp: Predicted PMI = 4.09 hours
# 9010R_1_1.bmp: Predicted PMI = 10.60 hours
# 9173L_2_1.bmp: Predicted PMI = 20.44 hours
# 9186L_1_1.bmp: Predicted PMI = 6.23 hours
# 9196R_1_4.bmp: Predicted PMI = 21.64 hours
# 9029L_1_3.bmp: Predicted PMI = 7.60 hours
# 9011R_1_1.bmp: Predicted PMI = 17.72 hours
# 9187L_1_1.bmp: Predicted PMI = 7.45 hours
# 9242L_2_7.bmp: Predicted PMI = 16.49 hours
# 9112L_6_2.bmp: Predicted PMI = 15.95 hours
# 9156L_1_2.bmp: Predicted PMI = 11.84 hours
# 9080L_9_1.bmp: Predicted PMI = 11.17 hours
# 9140L_7_2.bmp: Predicted PMI = 19.17 hours
# 9034R_2_2.bmp: Predicted PMI = 14.27 hours
# 9157L_1_2.bmp: Predicted PMI = 48.35 hours
# 9201R_3_2.bmp: Predicted PMI = 4.17 hours
# 9024R_1_3.bmp: Predicted PMI = 6.80 hours
# 9114L_3_3.bmp: Predicted PMI = 11.66 hours
# 9242R_1_3.bmp: Predicted PMI = 14.80 hours
# 9049R_6_4.bmp: Predicted PMI = 17.46 hours
# 9253L_1_6.bmp: Predicted PMI = 5.20 hours
# 9129L_42_5.bmp: Predicted PMI = 34.24 hours
# 9243R_1_3.bmp: Predicted PMI = 10.67 hours
# 9025R_1_3.bmp: Predicted PMI = 6.68 hours
# 9083R_3_3.bmp: Predicted PMI = 7.53 hours
# 9252L_1_6.bmp: Predicted PMI = 3.16 hours
# 9129L_21_6.bmp: Predicted PMI = 72.64 hours
# 9092L_3_6.bmp: Predicted PMI = 32.34 hours
# 9083R_3_2.bmp: Predicted PMI = 12.22 hours
# 9025R_1_2.bmp: Predicted PMI = 6.04 hours
# 9243R_1_2.bmp: Predicted PMI = 21.06 hours
# 9252L_1_7.bmp: Predicted PMI = 5.15 hours
# 9242R_1_2.bmp: Predicted PMI = 14.80 hours
# 9049R_6_5.bmp: Predicted PMI = 9.39 hours
# 9114L_3_2.bmp: Predicted PMI = 6.23 hours
# 9024R_1_2.bmp: Predicted PMI = 8.87 hours
# 9129L_42_4.bmp: Predicted PMI = 13.18 hours
# 9253L_1_7.bmp: Predicted PMI = 7.86 hours
# 9201R_3_3.bmp: Predicted PMI = 6.39 hours
# 9157L_1_3.bmp: Predicted PMI = 63.40 hours
# 9228R_3_4.bmp: Predicted PMI = 11.56 hours
# 9034R_2_3.bmp: Predicted PMI = 14.50 hours
# 9140L_7_3.bmp: Predicted PMI = 21.57 hours
# 9242L_2_6.bmp: Predicted PMI = 22.72 hours
# 9049L_5_1.bmp: Predicted PMI = 8.43 hours
# 9156L_1_3.bmp: Predicted PMI = 12.61 hours
# 9229R_3_4.bmp: Predicted PMI = 106.44 hours
# 9112L_6_3.bmp: Predicted PMI = 47.57 hours
# 9160L_6_8.bmp: Predicted PMI = 21.70 hours
# 9029L_1_2.bmp: Predicted PMI = 7.08 hours
# 9196R_1_5.bmp: Predicted PMI = 7.18 hours
# 9175R_4_5.bmp: Predicted PMI = 4.10 hours
# 9197R_1_5.bmp: Predicted PMI = 59.00 hours
# 9016L_7_5.bmp: Predicted PMI = 10.68 hours
# 9028L_1_2.bmp: Predicted PMI = 5.35 hours
# 9163L_1_1.bmp: Predicted PMI = 4.48 hours
# 9053R_3_1.bmp: Predicted PMI = 22.44 hours
# 9160L_8_7.bmp: Predicted PMI = 11.36 hours
# 9187R_2_4.bmp: Predicted PMI = 6.90 hours
# 9129R_1_8.bmp: Predicted PMI = 94.16 hours
# 9172R_1_4.bmp: Predicted PMI = 91.71 hours
# 9038L_2_3.bmp: Predicted PMI = 131.53 hours
# 9224L_3_4.bmp: Predicted PMI = 7.98 hours
# 9223R_5_1.bmp: Predicted PMI = 21.82 hours
# 9016R_4_1.bmp: Predicted PMI = 29.72 hours
# 9162L_1_1.bmp: Predicted PMI = 94.00 hours
# 9052R_3_1.bmp: Predicted PMI = 18.86 hours
# 9001R_2_1.bmp: Predicted PMI = 12.30 hours
# 9199R_5_8.bmp: Predicted PMI = 6.66 hours
# 9173R_1_4.bmp: Predicted PMI = 11.99 hours
# 9186R_2_4.bmp: Predicted PMI = 3.11 hours
# 9129L_23_5.bmp: Predicted PMI = 5.91 hours
# 9104R_1_5.bmp: Predicted PMI = 8.89 hours
# 9228L_2_2.bmp: Predicted PMI = 71.41 hours
# 9092L_1_5.bmp: Predicted PMI = 5.21 hours
# 9229L_2_2.bmp: Predicted PMI = 8.50 hours
# 9049R_4_7.bmp: Predicted PMI = 5.06 hours
# 9092R_2_1.bmp: Predicted PMI = 6.54 hours
# 9140L_5_1.bmp: Predicted PMI = 24.93 hours
# 9113L_4_1.bmp: Predicted PMI = 39.35 hours
# 9104L_2_1.bmp: Predicted PMI = 10.38 hours
# 9201R_1_1.bmp: Predicted PMI = 7.29 hours
# 9115R_2_4.bmp: Predicted PMI = 101.47 hours
# 9239L_1_3.bmp: Predicted PMI = 22.06 hours
# 9076L_1_4.bmp: Predicted PMI = 54.34 hours
# 9210L_1_4.bmp: Predicted PMI = 4.16 hours
# 9200R_1_1.bmp: Predicted PMI = 27.19 hours
# 9112L_4_1.bmp: Predicted PMI = 42.12 hours
# 9093R_2_1.bmp: Predicted PMI = 9.65 hours
# 9211L_1_4.bmp: Predicted PMI = 11.88 hours
# 9114R_2_4.bmp: Predicted PMI = 14.50 hours
# 9238L_1_3.bmp: Predicted PMI = 10.44 hours
# 9103R_4_4.bmp: Predicted PMI = 5.26 hours
# 9187L_3_2.bmp: Predicted PMI = 121.14 hours
# 9121L_1_2.bmp: Predicted PMI = 12.02 hours
# 9108L_1_5.bmp: Predicted PMI = 4.98 hours
# 9224R_2_2.bmp: Predicted PMI = 22.02 hours
# 9109L_1_5.bmp: Predicted PMI = 7.72 hours
# 9225R_2_2.bmp: Predicted PMI = 13.67 hours
# 9120L_1_2.bmp: Predicted PMI = 10.51 hours
# 9129L_18_3.bmp: Predicted PMI = 22.05 hours
# 9108R_2_1.bmp: Predicted PMI = 6.38 hours
# 9119L_2_4.bmp: Predicted PMI = 8.68 hours
# 9235R_1_3.bmp: Predicted PMI = 10.31 hours
# 9053R_1_3.bmp: Predicted PMI = 5.84 hours
# 9174L_5_3.bmp: Predicted PMI = 9.53 hours
# 9130L_2_3.bmp: Predicted PMI = 6.96 hours
# 9109R_2_1.bmp: Predicted PMI = 8.98 hours
# 9052R_1_3.bmp: Predicted PMI = 10.85 hours
# 9016R_6_3.bmp: Predicted PMI = 10.66 hours
# 9131L_2_3.bmp: Predicted PMI = 89.87 hours
# 9110L_3_8.bmp: Predicted PMI = 6.09 hours
# 9234R_1_3.bmp: Predicted PMI = 20.65 hours
# 9229L_4_4.bmp: Predicted PMI = 93.11 hours
# 9071L_2_3.bmp: Predicted PMI = 7.40 hours
# 9084L_1_3.bmp: Predicted PMI = 6.64 hours
# 9112R_1_3.bmp: Predicted PMI = 69.68 hours
# 9103L_1_6.bmp: Predicted PMI = 5.80 hours
# 9049R_2_1.bmp: Predicted PMI = 9.09 hours
# 9201L_4_3.bmp: Predicted PMI = 10.10 hours
# 9245L_3_3.bmp: Predicted PMI = 25.64 hours
# 9216L_2_3.bmp: Predicted PMI = 12.61 hours
# 9085L_1_3.bmp: Predicted PMI = 19.34 hours
# 9129L_25_3.bmp: Predicted PMI = 17.67 hours
# 9228L_4_4.bmp: Predicted PMI = 8.33 hours
# 9048R_2_1.bmp: Predicted PMI = 9.66 hours
# 9102L_1_6.bmp: Predicted PMI = 15.99 hours
# 9083R_7_6.bmp: Predicted PMI = 8.26 hours
# 9112L_2_7.bmp: Predicted PMI = 93.40 hours
# 9049L_1_5.bmp: Predicted PMI = 6.40 hours
# 9206L_1_2.bmp: Predicted PMI = 6.10 hours
# 9060L_1_2.bmp: Predicted PMI = 5.47 hours
# 9103R_2_2.bmp: Predicted PMI = 7.61 hours
# 9083R_11_3.bmp: Predicted PMI = 10.84 hours
# 9061L_1_2.bmp: Predicted PMI = 77.86 hours
# 9083L_4_2.bmp: Predicted PMI = 6.51 hours
# 9151R_3_2.bmp: Predicted PMI = 51.01 hours
# 9207L_1_2.bmp: Predicted PMI = 15.13 hours
# 9088R_1_3.bmp: Predicted PMI = 8.40 hours
# 9137L_1_4.bmp: Predicted PMI = 5.02 hours
# 9199L_2_8.bmp: Predicted PMI = 15.62 hours
# 9223L_2_1.bmp: Predicted PMI = 49.13 hours
# 9113L_1_15.bmp: Predicted PMI = 8.31 hours
# 9016L_3_1.bmp: Predicted PMI = 39.83 hours
# 9180R_3_1.bmp: Predicted PMI = 14.58 hours
# 9126R_1_1.bmp: Predicted PMI = 31.50 hours
# 9052L_4_1.bmp: Predicted PMI = 10.12 hours
# 9259L_3_6.bmp: Predicted PMI = 6.37 hours
# 9136L_1_4.bmp: Predicted PMI = 16.60 hours
# 9089R_1_3.bmp: Predicted PMI = 19.05 hours
# 9224R_4_4.bmp: Predicted PMI = 15.25 hours
# 9044L_2_1.bmp: Predicted PMI = 138.38 hours
# 9017L_3_1.bmp: Predicted PMI = 28.35 hours
# 9127R_1_1.bmp: Predicted PMI = 10.35 hours
# 9181R_3_1.bmp: Predicted PMI = 24.28 hours
# 9222L_2_1.bmp: Predicted PMI = 14.14 hours
# 9045R_1_5.bmp: Predicted PMI = 7.03 hours
# 9223R_1_5.bmp: Predicted PMI = 15.82 hours
# 9222R_1_5.bmp: Predicted PMI = 28.93 hours
# 9098R_2_2.bmp: Predicted PMI = 6.68 hours
# 9127L_2_5.bmp: Predicted PMI = 68.64 hours
# 9033R_1_4.bmp: Predicted PMI = 18.32 hours
# 9103L_3_4.bmp: Predicted PMI = 6.83 hours
# 9150L_2_4.bmp: Predicted PMI = 9.45 hours
# 9244L_1_1.bmp: Predicted PMI = 13.64 hours
# 9129L_44_2.bmp: Predicted PMI = 67.32 hours
# 9112R_3_1.bmp: Predicted PMI = 87.77 hours
# 9022L_1_1.bmp: Predicted PMI = 7.90 hours
# 9032R_1_4.bmp: Predicted PMI = 5.99 hours
# 9083R_5_4.bmp: Predicted PMI = 11.94 hours
# 9083L_1_11.bmp: Predicted PMI = 8.10 hours
# 9151L_2_4.bmp: Predicted PMI = 4.00 hours
# 9254R_1_4.bmp: Predicted PMI = 7.07 hours
# 9178L_2_3.bmp: Predicted PMI = 21.52 hours
# 9092L_5_1.bmp: Predicted PMI = 15.63 hours
# 9113R_3_1.bmp: Predicted PMI = 6.64 hours
# 9140R_2_1.bmp: Predicted PMI = 9.85 hours
# 9023L_1_1.bmp: Predicted PMI = 6.43 hours
# 9129L_27_1.bmp: Predicted PMI = 43.44 hours
# 9049L_3_7.bmp: Predicted PMI = 7.03 hours
# 9141L_1_5.bmp: Predicted PMI = 8.70 hours
# 9168L_1_2.bmp: Predicted PMI = 61.70 hours
# 9178R_1_7.bmp: Predicted PMI = 19.35 hours
# 9083L_15_3.bmp: Predicted PMI = 15.67 hours
# 9169L_1_2.bmp: Predicted PMI = 6.54 hours
# 9083R_13_1.bmp: Predicted PMI = 21.58 hours
# 9228R_5_2.bmp: Predicted PMI = 11.05 hours
# 9140L_1_5.bmp: Predicted PMI = 10.45 hours
# 9259L_1_4.bmp: Predicted PMI = 7.86 hours
# 9175R_2_3.bmp: Predicted PMI = 7.68 hours
# 9052L_6_3.bmp: Predicted PMI = 14.08 hours
# 9202L_1_8.bmp: Predicted PMI = 8.43 hours
# 9180R_1_3.bmp: Predicted PMI = 20.11 hours
# 9016L_1_3.bmp: Predicted PMI = 8.94 hours
# 9110R_4_8.bmp: Predicted PMI = 11.34 hours
# 9248R_1_1.bmp: Predicted PMI = 4.82 hours
# 9088R_3_1.bmp: Predicted PMI = 11.11 hours
# 9261R_1_6.bmp: Predicted PMI = 73.40 hours
# 9203L_1_8.bmp: Predicted PMI = 4.14 hours
# 9181R_1_3.bmp: Predicted PMI = 14.00 hours
# 9258L_1_4.bmp: Predicted PMI = 37.24 hours
# 9174R_2_3.bmp: Predicted PMI = 10.54 hours
# 9017L_1_3.bmp: Predicted PMI = 9.50 hours
# 9260R_1_6.bmp: Predicted PMI = 9.57 hours
# 9191R_2_2.bmp: Predicted PMI = 17.37 hours
# 9164R_1_2.bmp: Predicted PMI = 16.13 hours
# 9007L_2_2.bmp: Predicted PMI = 13.47 hours
# 9174L_1_7.bmp: Predicted PMI = 6.42 hours
# 9181L_2_7.bmp: Predicted PMI = 44.38 hours
# 9124L_9_1.bmp: Predicted PMI = 10.56 hours
# 9165R_1_2.bmp: Predicted PMI = 9.63 hours
# 9187R_4_2.bmp: Predicted PMI = 9.42 hours
# 9256R_1_10.bmp: Predicted PMI = 5.45 hours
# 9224L_5_2.bmp: Predicted PMI = 20.59 hours
# 9190L_1_2.bmp: Predicted PMI = 5.34 hours
# 9006R_1_2.bmp: Predicted PMI = 12.38 hours
# 9260R_1_2.bmp: Predicted PMI = 8.30 hours
# 9224R_6_2.bmp: Predicted PMI = 14.20 hours
# 9174R_2_7.bmp: Predicted PMI = 22.73 hours
# 9261R_1_2.bmp: Predicted PMI = 54.40 hours
# 9248R_1_5.bmp: Predicted PMI = 11.71 hours
# 9191L_1_2.bmp: Predicted PMI = 8.65 hours
# 9007R_1_2.bmp: Predicted PMI = 8.57 hours
# 9175R_2_7.bmp: Predicted PMI = 19.06 hours
# 9180R_1_7.bmp: Predicted PMI = 14.04 hours
# 9249L_2_1.bmp: Predicted PMI = 64.58 hours
# 9222R_3_3.bmp: Predicted PMI = 11.57 hours
# 9129L_41_11.bmp: Predicted PMI = 61.63 hours
# 9174L_1_3.bmp: Predicted PMI = 9.36 hours
# 9181L_2_3.bmp: Predicted PMI = 40.28 hours
# 9203R_2_8.bmp: Predicted PMI = 13.95 hours
# 9017R_2_3.bmp: Predicted PMI = 8.41 hours
# 9248L_2_1.bmp: Predicted PMI = 12.31 hours
# 9202R_2_8.bmp: Predicted PMI = 11.72 hours
# 9259R_2_4.bmp: Predicted PMI = 8.37 hours
# 9045R_3_3.bmp: Predicted PMI = 6.58 hours
# 9016R_2_3.bmp: Predicted PMI = 15.13 hours
# 9223R_3_3.bmp: Predicted PMI = 37.93 hours
# 9169R_2_2.bmp: Predicted PMI = 8.51 hours
# 9242L_1_10.bmp: Predicted PMI = 6.14 hours
# 9228L_6_2.bmp: Predicted PMI = 24.72 hours
# 9129L_27_5.bmp: Predicted PMI = 83.79 hours
# 9178L_2_7.bmp: Predicted PMI = 19.82 hours
# 9112R_3_5.bmp: Predicted PMI = 7.16 hours
# 9129L_44_6.bmp: Predicted PMI = 43.59 hours
# 9168R_2_2.bmp: Predicted PMI = 10.71 hours
# 9244L_1_5.bmp: Predicted PMI = 16.07 hours
# 9140L_1_1.bmp: Predicted PMI = 11.22 hours
# 9023R_2_1.bmp: Predicted PMI = 9.76 hours
# 9245R_2_1.bmp: Predicted PMI = 17.83 hours
# 9216R_3_1.bmp: Predicted PMI = 14.31 hours
# 9151R_1_4.bmp: Predicted PMI = 5.82 hours
# 9048L_3_3.bmp: Predicted PMI = 46.41 hours
# 9178R_1_3.bmp: Predicted PMI = 16.48 hours
# 9207L_3_4.bmp: Predicted PMI = 52.38 hours
# 9244R_2_1.bmp: Predicted PMI = 5.84 hours
# 9141L_1_1.bmp: Predicted PMI = 4.69 hours
# 9022R_2_1.bmp: Predicted PMI = 9.85 hours
# 9049L_3_3.bmp: Predicted PMI = 7.03 hours
# 9179R_1_3.bmp: Predicted PMI = 9.12 hours
# 9206L_3_4.bmp: Predicted PMI = 17.96 hours
# 9150R_1_4.bmp: Predicted PMI = 6.57 hours
# 9098L_1_2.bmp: Predicted PMI = 7.10 hours
# 9124R_8_3.bmp: Predicted PMI = 26.99 hours
# 9127R_1_5.bmp: Predicted PMI = 9.44 hours
# 9129L_38_2.bmp: Predicted PMI = 93.70 hours
# 9259L_3_2.bmp: Predicted PMI = 8.01 hours
# 9126R_1_5.bmp: Predicted PMI = 44.65 hours
# 9113L_1_11.bmp: Predicted PMI = 8.02 hours
# 9099L_1_2.bmp: Predicted PMI = 8.19 hours
# 9127L_2_1.bmp: Predicted PMI = 49.23 hours
# 9222R_1_1.bmp: Predicted PMI = 6.47 hours
# 9136R_2_4.bmp: Predicted PMI = 10.39 hours
# 9055L_1_4.bmp: Predicted PMI = 5.86 hours
# 9233L_1_4.bmp: Predicted PMI = 22.49 hours
# 9224L_7_4.bmp: Predicted PMI = 9.79 hours
# 9223R_1_1.bmp: Predicted PMI = 7.08 hours
# 9045R_1_1.bmp: Predicted PMI = 6.19 hours
# 9232L_1_4.bmp: Predicted PMI = 27.86 hours
# 9088L_2_3.bmp: Predicted PMI = 9.26 hours
# 9199R_1_8.bmp: Predicted PMI = 4.03 hours
# 9137R_2_4.bmp: Predicted PMI = 4.63 hours
# 9054L_1_4.bmp: Predicted PMI = 4.69 hours
# 9094R_1_2.bmp: Predicted PMI = 6.40 hours
# 9102L_1_2.bmp: Predicted PMI = 24.03 hours
# 9083R_7_2.bmp: Predicted PMI = 13.40 hours
# 9170L_1_9.bmp: Predicted PMI = 3.82 hours
# 9049R_2_5.bmp: Predicted PMI = 25.13 hours
# 9206R_2_2.bmp: Predicted PMI = 4.81 hours
# 9060R_2_2.bmp: Predicted PMI = 10.43 hours
# 9129L_8_3.bmp: Predicted PMI = 8.02 hours
# 9103L_1_2.bmp: Predicted PMI = 4.44 hours
# 9129L_46_4.bmp: Predicted PMI = 84.87 hours
# 9112R_1_7.bmp: Predicted PMI = 129.28 hours
# 9207L_1_6.bmp: Predicted PMI = 8.22 hours
# 9048L_1_1.bmp: Predicted PMI = 35.28 hours
# 9083L_4_6.bmp: Predicted PMI = 8.74 hours
# 9059R_1_4.bmp: Predicted PMI = 9.44 hours
# 9216R_1_3.bmp: Predicted PMI = 3.52 hours
# 9228R_7_4.bmp: Predicted PMI = 8.53 hours
# 9085R_2_3.bmp: Predicted PMI = 11.48 hours
# 9113L_2_3.bmp: Predicted PMI = 9.98 hours
# 9140L_3_3.bmp: Predicted PMI = 16.83 hours
# 9103R_2_6.bmp: Predicted PMI = 8.09 hours
# 9049L_1_1.bmp: Predicted PMI = 7.46 hours
# 9071R_1_3.bmp: Predicted PMI = 12.21 hours
# 9112L_2_3.bmp: Predicted PMI = 69.29 hours
# 9217R_1_3.bmp: Predicted PMI = 16.79 hours
# 9052L_2_3.bmp: Predicted PMI = 9.81 hours
# 9131R_1_3.bmp: Predicted PMI = 23.02 hours
# 9016L_5_3.bmp: Predicted PMI = 23.49 hours
# 9223L_4_3.bmp: Predicted PMI = 17.61 hours
# 9118R_1_4.bmp: Predicted PMI = 7.42 hours
# 9109L_1_1.bmp: Predicted PMI = 22.91 hours
# 9235L_2_3.bmp: Predicted PMI = 16.38 hours
# 9119R_1_4.bmp: Predicted PMI = 4.70 hours
# 9053L_2_3.bmp: Predicted PMI = 25.11 hours
# 9130R_1_3.bmp: Predicted PMI = 11.35 hours
# 9108L_1_1.bmp: Predicted PMI = 6.06 hours
# 9225L_1_2.bmp: Predicted PMI = 6.44 hours
# 9257L_1_9.bmp: Predicted PMI = 10.80 hours
# 9174L_5_7.bmp: Predicted PMI = 7.57 hours
# 9042L_1_2.bmp: Predicted PMI = 10.95 hours
# 9256L_1_9.bmp: Predicted PMI = 19.26 hours
# 9224L_1_2.bmp: Predicted PMI = 5.79 hours
# 9049R_4_3.bmp: Predicted PMI = 11.56 hours
# 9211R_2_4.bmp: Predicted PMI = 15.37 hours
# 9206R_4_4.bmp: Predicted PMI = 43.38 hours
# 9238R_2_3.bmp: Predicted PMI = 6.26 hours
# 9114L_1_4.bmp: Predicted PMI = 28.14 hours
# 9103L_7_4.bmp: Predicted PMI = 69.76 hours
# 9200L_2_1.bmp: Predicted PMI = 17.41 hours
# 9093L_1_1.bmp: Predicted PMI = 8.45 hours
# 9112R_7_1.bmp: Predicted PMI = 44.73 hours
# 9066L_2_1.bmp: Predicted PMI = 29.66 hours
# 9105R_1_1.bmp: Predicted PMI = 11.16 hours
# 9239R_2_3.bmp: Predicted PMI = 74.54 hours
# 9115L_1_4.bmp: Predicted PMI = 14.44 hours
# 9083R_1_4.bmp: Predicted PMI = 6.48 hours
# 9129L_53_8.bmp: Predicted PMI = 154.99 hours
# 9080R_8_2.bmp: Predicted PMI = 8.99 hours
# 9210R_2_4.bmp: Predicted PMI = 16.41 hours
# 9140R_6_1.bmp: Predicted PMI = 17.97 hours
# 9092L_1_1.bmp: Predicted PMI = 5.69 hours
# 9129L_23_1.bmp: Predicted PMI = 5.71 hours
# 9104R_1_1.bmp: Predicted PMI = 6.57 hours
# 9201L_2_1.bmp: Predicted PMI = 5.09 hours
# 9229R_1_2.bmp: Predicted PMI = 10.57 hours
# 9200R_1_5.bmp: Predicted PMI = 14.74 hours
# 9083L_11_3.bmp: Predicted PMI = 5.96 hours
# 9201R_1_5.bmp: Predicted PMI = 9.05 hours
# 9228R_1_2.bmp: Predicted PMI = 36.01 hours
# 9092R_2_5.bmp: Predicted PMI = 6.52 hours
# 9039R_1_3.bmp: Predicted PMI = 6.42 hours
# 9186L_1_4.bmp: Predicted PMI = 5.89 hours
# 9173L_2_4.bmp: Predicted PMI = 14.52 hours
# 9197R_1_1.bmp: Predicted PMI = 25.57 hours
# 9001L_1_1.bmp: Predicted PMI = 6.41 hours
# 9175R_4_1.bmp: Predicted PMI = 9.58 hours
# 9129L_2_8.bmp: Predicted PMI = 64.18 hours
# 9187L_1_4.bmp: Predicted PMI = 3.97 hours
# 9038R_1_3.bmp: Predicted PMI = 74.35 hours
# 9196R_1_1.bmp: Predicted PMI = 8.62 hours
# 9162L_1_5.bmp: Predicted PMI = 32.20 hours
# 9028R_2_2.bmp: Predicted PMI = 8.05 hours
# 9256L_1_10.bmp: Predicted PMI = 19.26 hours
# 9160L_8_3.bmp: Predicted PMI = 9.09 hours
# 9163L_1_5.bmp: Predicted PMI = 5.67 hours
# 9156R_2_3.bmp: Predicted PMI = 10.29 hours
# 9112R_5_3.bmp: Predicted PMI = 31.45 hours
# 9035L_1_3.bmp: Predicted PMI = 95.98 hours
# 9093L_3_3.bmp: Predicted PMI = 7.84 hours
# 9177R_3_8.bmp: Predicted PMI = 13.61 hours
# 9253L_1_3.bmp: Predicted PMI = 10.16 hours
# 9049R_6_1.bmp: Predicted PMI = 14.57 hours
# 9242R_1_6.bmp: Predicted PMI = 14.51 hours
# 9252L_1_3.bmp: Predicted PMI = 4.69 hours
# 9157R_2_3.bmp: Predicted PMI = 21.10 hours
# 9129L_21_3.bmp: Predicted PMI = 44.19 hours
# 9092L_3_3.bmp: Predicted PMI = 12.32 hours
# 9140R_4_3.bmp: Predicted PMI = 15.48 hours
# 9083R_1_11.bmp: Predicted PMI = 11.78 hours
# 9034L_1_3.bmp: Predicted PMI = 10.59 hours
# 9113R_5_3.bmp: Predicted PMI = 97.53 hours
# 9083R_3_6.bmp: Predicted PMI = 6.63 hours
# 9049L_5_5.bmp: Predicted PMI = 5.99 hours
# 9242L_2_2.bmp: Predicted PMI = 6.40 hours
# 9147R_1_2.bmp: Predicted PMI = 9.46 hours
# 9083R_15_3.bmp: Predicted PMI = 9.85 hours
# 9146R_1_2.bmp: Predicted PMI = 7.42 hours
# 9083L_13_1.bmp: Predicted PMI = 10.34 hours
# 9083R_15_2.bmp: Predicted PMI = 9.80 hours
# 9228R_3_1.bmp: Predicted PMI = 9.27 hours
# 9146R_1_3.bmp: Predicted PMI = 5.86 hours
# 9229R_3_1.bmp: Predicted PMI = 61.06 hours
# 9103R_6_3.bmp: Predicted PMI = 52.63 hours
# 9147R_1_3.bmp: Predicted PMI = 27.18 hours
# 9049L_5_4.bmp: Predicted PMI = 7.18 hours
# 9242L_2_3.bmp: Predicted PMI = 34.27 hours
# 9113R_5_2.bmp: Predicted PMI = 45.44 hours
# 9034L_1_2.bmp: Predicted PMI = 10.42 hours
# 9140R_4_2.bmp: Predicted PMI = 11.06 hours
# 9083R_1_10.bmp: Predicted PMI = 11.78 hours
# 9092L_3_2.bmp: Predicted PMI = 48.07 hours
# 9129L_21_2.bmp: Predicted PMI = 38.62 hours
# 9157R_2_2.bmp: Predicted PMI = 12.44 hours
# 9252L_1_2.bmp: Predicted PMI = 5.50 hours
# 9253L_1_2.bmp: Predicted PMI = 7.17 hours
# 9129L_42_1.bmp: Predicted PMI = 14.28 hours
# 9093L_3_2.bmp: Predicted PMI = 5.73 hours
# 9035L_1_2.bmp: Predicted PMI = 71.15 hours
# 9112R_5_2.bmp: Predicted PMI = 31.80 hours
# 9156R_2_2.bmp: Predicted PMI = 9.41 hours
# 9242R_1_7.bmp: Predicted PMI = 14.51 hours
# 9011L_2_1.bmp: Predicted PMI = 11.30 hours
# 9172R_1_1.bmp: Predicted PMI = 91.71 hours
# 9187R_2_1.bmp: Predicted PMI = 8.75 hours
# 9224L_3_1.bmp: Predicted PMI = 9.10 hours
# 9163L_1_4.bmp: Predicted PMI = 4.55 hours
# 9160L_8_2.bmp: Predicted PMI = 25.77 hours
# 9186R_2_1.bmp: Predicted PMI = 7.74 hours
# 9173R_1_1.bmp: Predicted PMI = 9.52 hours
# 9028R_2_3.bmp: Predicted PMI = 11.39 hours
# 9223R_5_4.bmp: Predicted PMI = 45.11 hours
# 9016R_4_4.bmp: Predicted PMI = 7.07 hours
# 9162L_1_4.bmp: Predicted PMI = 55.89 hours
# 9038R_1_2.bmp: Predicted PMI = 16.25 hours
# 9187L_1_5.bmp: Predicted PMI = 11.97 hours
# 9129L_2_9.bmp: Predicted PMI = 16.31 hours
# 9173L_2_5.bmp: Predicted PMI = 36.26 hours
# 9186L_1_5.bmp: Predicted PMI = 6.16 hours
# 9039R_1_2.bmp: Predicted PMI = 7.57 hours
# 9115R_2_1.bmp: Predicted PMI = 45.76 hours
# 9076L_1_1.bmp: Predicted PMI = 44.64 hours
# 9083L_2_1.bmp: Predicted PMI = 12.25 hours
# 9210L_1_1.bmp: Predicted PMI = 10.51 hours
# 9083L_11_2.bmp: Predicted PMI = 6.49 hours
# 9140L_5_4.bmp: Predicted PMI = 14.19 hours
# 9113L_4_4.bmp: Predicted PMI = 28.44 hours
# 9092R_2_4.bmp: Predicted PMI = 6.52 hours
# 9228R_1_3.bmp: Predicted PMI = 9.30 hours
# 9104L_2_4.bmp: Predicted PMI = 5.36 hours
# 9201R_1_4.bmp: Predicted PMI = 7.19 hours
# 9211L_1_1.bmp: Predicted PMI = 9.60 hours
# 9049L_7_6.bmp: Predicted PMI = 11.80 hours
# 9114R_2_1.bmp: Predicted PMI = 10.23 hours
# 9082L_2_1.bmp: Predicted PMI = 15.71 hours
# 9103R_4_1.bmp: Predicted PMI = 12.03 hours
# 9200R_1_4.bmp: Predicted PMI = 21.04 hours
# 9112L_4_4.bmp: Predicted PMI = 26.82 hours
# 9229R_1_3.bmp: Predicted PMI = 11.71 hours
# 9080R_8_3.bmp: Predicted PMI = 10.09 hours
# 9083R_1_5.bmp: Predicted PMI = 6.48 hours
# 9239R_2_2.bmp: Predicted PMI = 40.72 hours
# 9115L_1_5.bmp: Predicted PMI = 15.93 hours
# 9176R_1_10.bmp: Predicted PMI = 27.64 hours
# 9238R_2_2.bmp: Predicted PMI = 10.46 hours
# 9114L_1_5.bmp: Predicted PMI = 22.67 hours
# 9049R_4_2.bmp: Predicted PMI = 11.56 hours
# 9250R_1_12.bmp: Predicted PMI = 25.44 hours
# 9119L_2_1.bmp: Predicted PMI = 7.54 hours
# 9174L_5_6.bmp: Predicted PMI = 7.00 hours
# 9224L_1_3.bmp: Predicted PMI = 12.36 hours
# 9108R_2_4.bmp: Predicted PMI = 3.07 hours
# 9256L_1_8.bmp: Predicted PMI = 16.62 hours
# 9042L_1_3.bmp: Predicted PMI = 17.99 hours
# 9257L_1_8.bmp: Predicted PMI = 6.69 hours
# 9225L_1_3.bmp: Predicted PMI = 4.39 hours
# 9109R_2_4.bmp: Predicted PMI = 7.17 hours
# 9130R_1_2.bmp: Predicted PMI = 5.37 hours
# 9053L_2_2.bmp: Predicted PMI = 39.30 hours
# 9235L_2_2.bmp: Predicted PMI = 28.39 hours
# 9119R_1_5.bmp: Predicted PMI = 4.22 hours
# 9118R_1_5.bmp: Predicted PMI = 15.17 hours
# 9223L_4_2.bmp: Predicted PMI = 13.22 hours
# 9016L_5_2.bmp: Predicted PMI = 34.13 hours
# 9131R_1_2.bmp: Predicted PMI = 40.15 hours
# 9052L_2_2.bmp: Predicted PMI = 6.44 hours
# 9103R_2_7.bmp: Predicted PMI = 5.06 hours
# 9217R_1_2.bmp: Predicted PMI = 11.64 hours
# 9112L_2_2.bmp: Predicted PMI = 16.38 hours
# 9071R_1_2.bmp: Predicted PMI = 17.72 hours
# 9140L_3_2.bmp: Predicted PMI = 9.48 hours
# 9113L_2_2.bmp: Predicted PMI = 30.91 hours
# 9085R_2_2.bmp: Predicted PMI = 24.26 hours
# 9216R_1_2.bmp: Predicted PMI = 4.29 hours
# 9103L_1_3.bmp: Predicted PMI = 7.78 hours
# 9129L_8_2.bmp: Predicted PMI = 11.69 hours
# 9060R_2_3.bmp: Predicted PMI = 11.46 hours
# 9206R_2_3.bmp: Predicted PMI = 39.24 hours
# 9049R_2_4.bmp: Predicted PMI = 7.26 hours
# 9229L_4_1.bmp: Predicted PMI = 66.75 hours
# 9112R_1_6.bmp: Predicted PMI = 84.91 hours
# 9129L_46_5.bmp: Predicted PMI = 65.99 hours
# 9170L_1_8.bmp: Predicted PMI = 5.19 hours
# 9207R_2_3.bmp: Predicted PMI = 51.74 hours
# 9083R_7_3.bmp: Predicted PMI = 11.13 hours
# 9102L_1_3.bmp: Predicted PMI = 7.59 hours
# 9094R_1_3.bmp: Predicted PMI = 6.34 hours
# 9059L_2_1.bmp: Predicted PMI = 7.46 hours
# 9228L_4_1.bmp: Predicted PMI = 83.90 hours
# 9199R_1_9.bmp: Predicted PMI = 3.74 hours
# 9088L_2_2.bmp: Predicted PMI = 5.80 hours
# 9232L_1_5.bmp: Predicted PMI = 14.98 hours
# 9233L_1_5.bmp: Predicted PMI = 9.92 hours
# 9099L_1_3.bmp: Predicted PMI = 7.44 hours
# 9223L_2_4.bmp: Predicted PMI = 28.57 hours
# 9113L_1_10.bmp: Predicted PMI = 11.25 hours
# 9126R_1_4.bmp: Predicted PMI = 21.77 hours
# 9259L_3_3.bmp: Predicted PMI = 9.68 hours
# 9180R_3_4.bmp: Predicted PMI = 10.30 hours
# 9088R_1_6.bmp: Predicted PMI = 14.64 hours
# 9137L_1_1.bmp: Predicted PMI = 5.16 hours
# 9017L_3_4.bmp: Predicted PMI = 6.90 hours
# 9181R_3_4.bmp: Predicted PMI = 35.40 hours
# 9127R_1_4.bmp: Predicted PMI = 7.70 hours
# 9124R_8_2.bmp: Predicted PMI = 9.87 hours
# 9098L_1_3.bmp: Predicted PMI = 5.80 hours
# 9222L_2_4.bmp: Predicted PMI = 6.91 hours
# 9136L_1_1.bmp: Predicted PMI = 41.83 hours
# 9055R_2_1.bmp: Predicted PMI = 7.25 hours
# 9129L_38_3.bmp: Predicted PMI = 11.52 hours
# 9224R_4_1.bmp: Predicted PMI = 46.52 hours
# 9150R_1_5.bmp: Predicted PMI = 4.61 hours
# 9179R_1_2.bmp: Predicted PMI = 7.04 hours
# 9049L_3_2.bmp: Predicted PMI = 7.03 hours
# 9178R_1_2.bmp: Predicted PMI = 12.16 hours
# 9048L_3_2.bmp: Predicted PMI = 24.02 hours
# 9151R_1_5.bmp: Predicted PMI = 7.72 hours
# 9168R_2_3.bmp: Predicted PMI = 10.05 hours
# 9244L_1_4.bmp: Predicted PMI = 14.69 hours
# 9129L_44_7.bmp: Predicted PMI = 62.90 hours
# 9112R_3_4.bmp: Predicted PMI = 15.99 hours
# 9033R_1_1.bmp: Predicted PMI = 19.90 hours
# 9103L_3_1.bmp: Predicted PMI = 6.30 hours
# 9150L_2_1.bmp: Predicted PMI = 7.09 hours
# 9113R_3_4.bmp: Predicted PMI = 5.02 hours
# 9140R_2_4.bmp: Predicted PMI = 10.60 hours
# 9129L_27_4.bmp: Predicted PMI = 85.19 hours
# 9023L_1_4.bmp: Predicted PMI = 8.36 hours
# 9228L_6_3.bmp: Predicted PMI = 19.47 hours
# 9169R_2_3.bmp: Predicted PMI = 7.88 hours
# 9032R_1_1.bmp: Predicted PMI = 52.87 hours
# 9151L_2_1.bmp: Predicted PMI = 6.08 hours
# 9083R_5_1.bmp: Predicted PMI = 4.58 hours
# 9178L_2_6.bmp: Predicted PMI = 8.41 hours
# 9254R_1_1.bmp: Predicted PMI = 26.22 hours
# 9223R_3_2.bmp: Predicted PMI = 52.37 hours
# 9016R_2_2.bmp: Predicted PMI = 9.32 hours
# 9045R_3_2.bmp: Predicted PMI = 5.68 hours
# 9052R_5_2.bmp: Predicted PMI = 10.04 hours
# 9259R_2_5.bmp: Predicted PMI = 10.24 hours
# 9017R_2_2.bmp: Predicted PMI = 16.02 hours
# 9181L_2_2.bmp: Predicted PMI = 5.74 hours
# 9174L_1_2.bmp: Predicted PMI = 6.10 hours
# 9124L_9_4.bmp: Predicted PMI = 12.93 hours
# 9129L_41_10.bmp: Predicted PMI = 61.63 hours
# 9222R_3_2.bmp: Predicted PMI = 16.57 hours
# 9191L_1_3.bmp: Predicted PMI = 5.08 hours
# 9248R_1_4.bmp: Predicted PMI = 5.23 hours
# 9261R_1_3.bmp: Predicted PMI = 71.68 hours
# 9180R_1_6.bmp: Predicted PMI = 45.16 hours
# 9175R_2_6.bmp: Predicted PMI = 21.07 hours
# 9259L_1_1.bmp: Predicted PMI = 12.61 hours
# 9224R_6_3.bmp: Predicted PMI = 28.29 hours
# 9260R_1_3.bmp: Predicted PMI = 11.79 hours
# 9144L_3_8.bmp: Predicted PMI = 20.29 hours
# 9190L_1_3.bmp: Predicted PMI = 6.04 hours
# 9174R_2_6.bmp: Predicted PMI = 9.21 hours
# 9258L_1_1.bmp: Predicted PMI = 19.44 hours
# 9259L_1_3.bmp: Predicted PMI = 7.86 hours
# 9175R_2_4.bmp: Predicted PMI = 7.68 hours
# 9180R_1_4.bmp: Predicted PMI = 20.11 hours
# 9261R_1_1.bmp: Predicted PMI = 54.40 hours
# 9191L_1_1.bmp: Predicted PMI = 7.38 hours
# 9007R_1_1.bmp: Predicted PMI = 9.19 hours
# 9181R_1_4.bmp: Predicted PMI = 16.08 hours
# 9258L_1_3.bmp: Predicted PMI = 37.24 hours
# 9174R_2_4.bmp: Predicted PMI = 10.54 hours
# 9190L_1_1.bmp: Predicted PMI = 6.27 hours
# 9006R_1_1.bmp: Predicted PMI = 26.24 hours
# 9260R_1_1.bmp: Predicted PMI = 8.30 hours
# 9224R_6_1.bmp: Predicted PMI = 17.97 hours
# 9259R_2_7.bmp: Predicted PMI = 10.72 hours
# 9248L_2_2.bmp: Predicted PMI = 22.31 hours
# 9164R_1_5.bmp: Predicted PMI = 7.52 hours
# 9129L_41_12.bmp: Predicted PMI = 61.63 hours
# 9249L_2_2.bmp: Predicted PMI = 78.69 hours
# 9165R_1_5.bmp: Predicted PMI = 10.28 hours
# 9103L_3_3.bmp: Predicted PMI = 6.83 hours
# 9150L_2_3.bmp: Predicted PMI = 4.69 hours
# 9033R_1_3.bmp: Predicted PMI = 14.64 hours
# 9112R_3_6.bmp: Predicted PMI = 7.16 hours
# 9129L_44_5.bmp: Predicted PMI = 43.59 hours
# 9168R_2_1.bmp: Predicted PMI = 10.28 hours
# 9170L_3_8.bmp: Predicted PMI = 5.79 hours
# 9254R_1_3.bmp: Predicted PMI = 7.07 hours
# 9178L_2_4.bmp: Predicted PMI = 21.52 hours
# 9083R_5_3.bmp: Predicted PMI = 11.94 hours
# 9151L_2_3.bmp: Predicted PMI = 6.41 hours
# 9032R_1_3.bmp: Predicted PMI = 11.93 hours
# 9169R_2_1.bmp: Predicted PMI = 10.24 hours
# 9228L_6_1.bmp: Predicted PMI = 48.18 hours
# 9129L_27_6.bmp: Predicted PMI = 81.05 hours
# 9244R_2_2.bmp: Predicted PMI = 6.43 hours
# 9168L_1_5.bmp: Predicted PMI = 10.19 hours
# 9141L_1_2.bmp: Predicted PMI = 5.95 hours
# 9022R_2_2.bmp: Predicted PMI = 16.41 hours
# 9140L_1_2.bmp: Predicted PMI = 6.86 hours
# 9023R_2_2.bmp: Predicted PMI = 15.69 hours
# 9216R_3_2.bmp: Predicted PMI = 8.21 hours
# 9245R_2_2.bmp: Predicted PMI = 53.45 hours
# 9169L_1_5.bmp: Predicted PMI = 13.74 hours
# 9137L_1_3.bmp: Predicted PMI = 5.62 hours
# 9088R_1_4.bmp: Predicted PMI = 5.46 hours
# 9259L_3_1.bmp: Predicted PMI = 8.01 hours
# 9113L_1_12.bmp: Predicted PMI = 9.42 hours
# 9099L_1_1.bmp: Predicted PMI = 7.61 hours
# 9224R_4_3.bmp: Predicted PMI = 11.74 hours
# ...
# 9203L_1_4.bmp: Predicted PMI = 3.93 hours
# 9106R_2_4.bmp: Predicted PMI = 48.02 hours
# 9212R_1_1.bmp: Predicted PMI = 10.89 hours
# 9074R_1_1.bmp: Predicted PMI = 10.29 hours
# 9144L_3_1.bmp: Predicted PMI = 15.66 hours
# 9154R_3_4.bmp: Predicted PMI = 4.99 hours
# 9107R_2_4.bmp: Predicted PMI = 5.45 hours
# 9110R_4_4.bmp: Predicted PMI = 14.09 hours
# 9202L_1_4.bmp: Predicted PMI = 15.53 hours
# 9259L_1_8.bmp: Predicted PMI = 5.58 hours
# 9129L_29_2.bmp: Predicted PMI = 18.90 hours
# 9080R_2_1.bmp: Predicted PMI = 5.83 hours
# 9213R_1_1.bmp: Predicted PMI = 3.96 hours
# 9117R_1_5.bmp: Predicted PMI = 4.31 hours
# 9205L_4_5.bmp: Predicted PMI = 39.14 hours
# 9083L_8_3.bmp: Predicted PMI = 20.41 hours
# 9116R_1_5.bmp: Predicted PMI = 12.84 hours
# 9174L_1_9.bmp: Predicted PMI = 5.36 hours
# 9203R_2_2.bmp: Predicted PMI = 24.53 hours
# 9106L_1_2.bmp: Predicted PMI = 8.90 hours
# 9065R_2_2.bmp: Predicted PMI = 12.52 hours
# 9090R_1_2.bmp: Predicted PMI = 67.89 hours
# 9083L_8_1.bmp: Predicted PMI = 15.72 hours
# 9107L_1_2.bmp: Predicted PMI = 4.29 hours
# 9064R_2_2.bmp: Predicted PMI = 7.30 hours
# 9202R_2_2.bmp: Predicted PMI = 6.91 hours
# 9144L_3_3.bmp: Predicted PMI = 41.19 hours
# 9260R_1_8.bmp: Predicted PMI = 12.76 hours
# 9074R_1_3.bmp: Predicted PMI = 8.83 hours
# 9212R_1_3.bmp: Predicted PMI = 18.44 hours
# 9203L_1_6.bmp: Predicted PMI = 7.09 hours
# 9213R_1_3.bmp: Predicted PMI = 12.65 hours
# 9160L_10_2.bmp: Predicted PMI = 5.75 hours
# 9261R_1_8.bmp: Predicted PMI = 75.66 hours
# 9145L_3_3.bmp: Predicted PMI = 10.69 hours
# 9224R_11_4.bmp: Predicted PMI = 7.92 hours
# 9080R_2_3.bmp: Predicted PMI = 9.86 hours
# 9202L_1_6.bmp: Predicted PMI = 23.19 hours
# 9110R_4_6.bmp: Predicted PMI = 13.21 hours
# 9178R_1_9.bmp: Predicted PMI = 21.93 hours
# 9069L_2_2.bmp: Predicted PMI = 13.59 hours
# 9068L_2_2.bmp: Predicted PMI = 11.13 hours
# 9049L_3_9.bmp: Predicted PMI = 7.64 hours
# 9122R_1_5.bmp: Predicted PMI = 29.62 hours
# 9179R_1_9.bmp: Predicted PMI = 6.98 hours
# 9078L_1_3.bmp: Predicted PMI = 5.16 hours
# 9237L_1_4.bmp: Predicted PMI = 18.79 hours
# 9051L_1_4.bmp: Predicted PMI = 6.43 hours
# 9132R_2_4.bmp: Predicted PMI = 65.87 hours
# 9226R_1_1.bmp: Predicted PMI = 9.05 hours
# 9049R_11_5.bmp: Predicted PMI = 19.52 hours
# 9004R_6_1.bmp: Predicted PMI = 13.93 hours
# 9170L_3_1.bmp: Predicted PMI = 5.38 hours
# 9040R_1_1.bmp: Predicted PMI = 6.78 hours
# 9050L_1_4.bmp: Predicted PMI = 7.42 hours
# 9124R_4_4.bmp: Predicted PMI = 9.58 hours
# 9079L_1_3.bmp: Predicted PMI = 3.92 hours
# 9236L_1_4.bmp: Predicted PMI = 5.50 hours
# 9149R_3_3.bmp: Predicted PMI = 16.72 hours
# 9041R_1_1.bmp: Predicted PMI = 6.57 hours
# 9227R_1_1.bmp: Predicted PMI = 8.62 hours
# 9241L_1_5.bmp: Predicted PMI = 10.71 hours
# 9198R_1_2.bmp: Predicted PMI = 8.49 hours
# 9199R_1_2.bmp: Predicted PMI = 4.29 hours
# 9240L_1_5.bmp: Predicted PMI = 15.46 hours
# 9129L_48_1.bmp: Predicted PMI = 18.92 hours
# 9241R_2_1.bmp: Predicted PMI = 11.31 hours
# 9027R_2_1.bmp: Predicted PMI = 6.71 hours
# 9224L_15_4.bmp: Predicted PMI = 10.82 hours
# 9202L_3_4.bmp: Predicted PMI = 7.50 hours
# 9188R_2_3.bmp: Predicted PMI = 14.92 hours
# 9259L_3_8.bmp: Predicted PMI = 5.60 hours
# 9026R_2_1.bmp: Predicted PMI = 31.03 hours
# 9145L_1_1.bmp: Predicted PMI = 6.63 hours
# 9199L_2_6.bmp: Predicted PMI = 9.82 hours
# 9170R_2_7.bmp: Predicted PMI = 7.68 hours
# 9194L_1_2.bmp: Predicted PMI = 31.28 hours
# 9224L_9_1.bmp: Predicted PMI = 11.26 hours
# 9124L_5_2.bmp: Predicted PMI = 10.60 hours
# 9195L_1_2.bmp: Predicted PMI = 9.22 hours
# 9013R_2_3.bmp: Predicted PMI = 7.31 hours
# 9040R_3_3.bmp: Predicted PMI = 11.00 hours
# 9170L_1_3.bmp: Predicted PMI = 5.22 hours
# 9159L_1_4.bmp: Predicted PMI = 7.38 hours
# 9226R_3_3.bmp: Predicted PMI = 9.76 hours
# 9129L_10_4.bmp: Predicted PMI = 20.61 hours
# 9148R_1_1.bmp: Predicted PMI = 6.67 hours
# 9158L_1_4.bmp: Predicted PMI = 11.32 hours
# 9103L_1_8.bmp: Predicted PMI = 6.59 hours
# 9041R_3_3.bmp: Predicted PMI = 15.81 hours
# 9184L_2_3.bmp: Predicted PMI = 4.40 hours
# 9149R_1_1.bmp: Predicted PMI = 28.17 hours
# 9079L_3_1.bmp: Predicted PMI = 10.46 hours
# 9050L_3_6.bmp: Predicted PMI = 3.46 hours
# 9009R_1_1.bmp: Predicted PMI = 9.20 hours
# 9110L_3_6.bmp: Predicted PMI = 7.15 hours
# 9103L_10_1.bmp: Predicted PMI = 12.76 hours
# 9018L_1_4.bmp: Predicted PMI = 9.86 hours
# 9257L_1_3.bmp: Predicted PMI = 8.65 hours
# 9031L_1_3.bmp: Predicted PMI = 7.78 hours
# 9145R_4_3.bmp: Predicted PMI = 14.07 hours
# 9101R_3_3.bmp: Predicted PMI = 11.75 hours
# 9080L_5_3.bmp: Predicted PMI = 6.18 hours
# 9203L_1_10.bmp: Predicted PMI = 7.70 hours
# 9138L_3_1.bmp: Predicted PMI = 5.25 hours
# 9144R_4_3.bmp: Predicted PMI = 40.79 hours
# 9049L_9_2.bmp: Predicted PMI = 13.68 hours
# 9153R_2_3.bmp: Predicted PMI = 8.96 hours
# 9019L_1_4.bmp: Predicted PMI = 7.77 hours
# 9256L_1_3.bmp: Predicted PMI = 16.78 hours
# 9224L_13_2.bmp: Predicted PMI = 11.04 hours
# 9143R_1_2.bmp: Predicted PMI = 12.65 hours
# 9140R_8_4.bmp: Predicted PMI = 22.55 hours
# 9173L_1_10.bmp: Predicted PMI = 41.11 hours
# 9214L_3_2.bmp: Predicted PMI = 13.46 hours
# 9142R_1_2.bmp: Predicted PMI = 8.53 hours
# 9256R_2_7.bmp: Predicted PMI = 97.92 hours
# 9103L_9_1.bmp: Predicted PMI = 73.55 hours
# 9005L_1_1.bmp: Predicted PMI = 6.94 hours
# 9166R_2_1.bmp: Predicted PMI = 109.08 hours
# 9193R_1_1.bmp: Predicted PMI = 11.33 hours
# 9263L_1_1.bmp: Predicted PMI = 78.65 hours
# 9177L_2_4.bmp: Predicted PMI = 12.09 hours
# 9182L_1_4.bmp: Predicted PMI = 4.52 hours
# 9160L_4_4.bmp: Predicted PMI = 19.62 hours
# 9014R_1_4.bmp: Predicted PMI = 10.31 hours
# 9149L_4_3.bmp: Predicted PMI = 13.07 hours
# 9262L_1_1.bmp: Predicted PMI = 4.89 hours
# 9004L_1_1.bmp: Predicted PMI = 5.20 hours
# 9192R_1_1.bmp: Predicted PMI = 12.14 hours
# 9167R_2_1.bmp: Predicted PMI = 6.00 hours
# 9016R_8_2.bmp: Predicted PMI = 7.15 hours
# 9183L_1_4.bmp: Predicted PMI = 11.98 hours
# 9176L_2_4.bmp: Predicted PMI = 19.25 hours
# 9129L_30_1.bmp: Predicted PMI = 12.10 hours
# 9049R_4_9.bmp: Predicted PMI = 5.06 hours
# 9167L_1_5.bmp: Predicted PMI = 6.98 hours
# 9129L_53_2.bmp: Predicted PMI = 50.72 hours
# 9049R_15_1.bmp: Predicted PMI = 15.22 hours
# 9129L_16_2.bmp: Predicted PMI = 8.15 hours
# 9080L_7_1.bmp: Predicted PMI = 20.67 hours
# 9101R_1_1.bmp: Predicted PMI = 6.38 hours
# 9062L_2_1.bmp: Predicted PMI = 74.32 hours
# 9097L_1_1.bmp: Predicted PMI = 8.43 hours
# 9199R_5_6.bmp: Predicted PMI = 8.07 hours
# 9073R_2_4.bmp: Predicted PMI = 52.34 hours
# 9110L_1_4.bmp: Predicted PMI = 6.35 hours
# 9140L_9_2.bmp: Predicted PMI = 10.30 hours
# 9202R_4_4.bmp: Predicted PMI = 14.23 hours
# 9215R_2_4.bmp: Predicted PMI = 16.74 hours
# 9139L_1_3.bmp: Predicted PMI = 18.44 hours
# 9205L_2_1.bmp: Predicted PMI = 9.85 hours
# 9129R_1_6.bmp: Predicted PMI = 73.97 hours
# 9100R_1_1.bmp: Predicted PMI = 12.34 hours
# 9096L_1_1.bmp: Predicted PMI = 5.22 hours
# 9063L_2_1.bmp: Predicted PMI = 13.49 hours
# 9144R_6_1.bmp: Predicted PMI = 14.46 hours
# 9214R_2_4.bmp: Predicted PMI = 13.68 hours
# 9138L_1_3.bmp: Predicted PMI = 4.84 hours
# 9124R_12_1.bmp: Predicted PMI = 29.01 hours
# 9155L_6_4.bmp: Predicted PMI = 44.62 hours
# 9111L_1_4.bmp: Predicted PMI = 45.63 hours
# 9199L_6_2.bmp: Predicted PMI = 33.78 hours
# 9204R_1_5.bmp: Predicted PMI = 9.13 hours
# 9128L_2_2.bmp: Predicted PMI = 14.13 hours
# 9101L_2_5.bmp: Predicted PMI = 10.73 hours
# 9049R_8_4.bmp: Predicted PMI = 17.59 hours
# 9205R_1_5.bmp: Predicted PMI = 6.80 hours
# 9129L_2_2.bmp: Predicted PMI = 11.14 hours
# 9178R_1_10.bmp: Predicted PMI = 21.93 hours
# 9160L_6_6.bmp: Predicted PMI = 16.31 hours
# 9050R_4_6.bmp: Predicted PMI = 5.74 hours
# 9230L_2_3.bmp: Predicted PMI = 4.13 hours
# 9242L_2_8.bmp: Predicted PMI = 16.49 hours
# 9219L_2_4.bmp: Predicted PMI = 9.69 hours
# 9135R_1_3.bmp: Predicted PMI = 5.90 hours
# 9056L_2_3.bmp: Predicted PMI = 6.22 hours
# 9218L_2_4.bmp: Predicted PMI = 6.94 hours
# 9134R_1_3.bmp: Predicted PMI = 11.86 hours
# 9231L_2_3.bmp: Predicted PMI = 17.66 hours
# 9226L_4_3.bmp: Predicted PMI = 8.82 hours
# 9177R_3_2.bmp: Predicted PMI = 13.02 hours
# 9253L_1_9.bmp: Predicted PMI = 5.09 hours
# 9047L_1_2.bmp: Predicted PMI = 36.48 hours
# 9221L_1_2.bmp: Predicted PMI = 18.40 hours
# 9129L_32_3.bmp: Predicted PMI = 7.05 hours
# 9049L_11_1.bmp: Predicted PMI = 10.49 hours
# 9220L_1_2.bmp: Predicted PMI = 15.39 hours
# 9252L_1_9.bmp: Predicted PMI = 3.11 hours
# 9125R_2_2.bmp: Predicted PMI = 34.55 hours
# 9046L_1_2.bmp: Predicted PMI = 3.45 hours
# 9046L_1_3.bmp: Predicted PMI = 4.83 hours
# 9129L_14_1.bmp: Predicted PMI = 29.04 hours
# 9125R_2_3.bmp: Predicted PMI = 68.66 hours
# 9252L_1_8.bmp: Predicted PMI = 5.15 hours
# 9220L_1_3.bmp: Predicted PMI = 47.71 hours
# 9218R_1_1.bmp: Predicted PMI = 29.25 hours
# 9129L_51_1.bmp: Predicted PMI = 91.95 hours
# 9221L_1_3.bmp: Predicted PMI = 25.20 hours
# 9047L_1_3.bmp: Predicted PMI = 7.58 hours
# 9253L_1_8.bmp: Predicted PMI = 7.86 hours
# 9177R_3_3.bmp: Predicted PMI = 12.41 hours
# 9129L_32_2.bmp: Predicted PMI = 5.61 hours
# 9219R_1_1.bmp: Predicted PMI = 10.85 hours
# 9226L_4_2.bmp: Predicted PMI = 12.70 hours
# 9231L_2_2.bmp: Predicted PMI = 11.75 hours
# 9218L_2_5.bmp: Predicted PMI = 16.80 hours
# 9134R_1_2.bmp: Predicted PMI = 12.46 hours
# 9160L_6_7.bmp: Predicted PMI = 21.70 hours
# 9056L_2_2.bmp: Predicted PMI = 5.84 hours
# 9135R_1_2.bmp: Predicted PMI = 15.58 hours
# 9230L_2_2.bmp: Predicted PMI = 9.99 hours
# 9253R_1_10.bmp: Predicted PMI = 4.58 hours
# 9205R_1_4.bmp: Predicted PMI = 10.12 hours
# 9129L_2_3.bmp: Predicted PMI = 31.81 hours
# 9049R_8_5.bmp: Predicted PMI = 8.18 hours
# 9100L_2_4.bmp: Predicted PMI = 15.07 hours
# 9214L_1_1.bmp: Predicted PMI = 15.63 hours
# 9087L_2_1.bmp: Predicted PMI = 11.86 hours
# 9072L_1_1.bmp: Predicted PMI = 5.77 hours
# 9142R_3_1.bmp: Predicted PMI = 18.60 hours
# 9090L_4_1.bmp: Predicted PMI = 29.92 hours
# 9152L_3_4.bmp: Predicted PMI = 19.23 hours
# 9101L_2_4.bmp: Predicted PMI = 6.84 hours
# 9145L_5_4.bmp: Predicted PMI = 57.86 hours
# 9204R_1_4.bmp: Predicted PMI = 5.07 hours
# 9128L_2_3.bmp: Predicted PMI = 11.74 hours
# 9199L_6_3.bmp: Predicted PMI = 17.54 hours
# 9224L_11_1.bmp: Predicted PMI = 10.45 hours
# 9073L_1_1.bmp: Predicted PMI = 31.09 hours
# 9086L_2_1.bmp: Predicted PMI = 9.45 hours
# 9091L_4_1.bmp: Predicted PMI = 13.38 hours
# 9110R_2_1.bmp: Predicted PMI = 6.78 hours
# 9215L_1_1.bmp: Predicted PMI = 8.19 hours
# 9129R_1_7.bmp: Predicted PMI = 94.16 hours
# 9111L_1_5.bmp: Predicted PMI = 7.57 hours
# 9160L_8_8.bmp: Predicted PMI = 11.36 hours
# 9138L_1_2.bmp: Predicted PMI = 13.44 hours
# 9199R_5_7.bmp: Predicted PMI = 6.66 hours
# 9139L_1_2.bmp: Predicted PMI = 13.36 hours
# 9140L_9_3.bmp: Predicted PMI = 10.91 hours
# 9110L_1_5.bmp: Predicted PMI = 4.14 hours
# 9226R_5_4.bmp: Predicted PMI = 11.45 hours
# 9192L_2_4.bmp: Predicted PMI = 9.29 hours
# 9167L_1_4.bmp: Predicted PMI = 7.17 hours
# 9129L_53_3.bmp: Predicted PMI = 58.74 hours
# 9220L_3_1.bmp: Predicted PMI = 21.26 hours
# 9176R_1_1.bmp: Predicted PMI = 4.50 hours
# 9002L_4_1.bmp: Predicted PMI = 23.42 hours
# 9015L_2_1.bmp: Predicted PMI = 40.34 hours
# 9129L_16_3.bmp: Predicted PMI = 6.11 hours
# 9184L_4_4.bmp: Predicted PMI = 34.62 hours
# 9049R_4_8.bmp: Predicted PMI = 5.06 hours
# 9050L_5_1.bmp: Predicted PMI = 5.09 hours
# 9177R_1_1.bmp: Predicted PMI = 7.03 hours
# 9014L_2_1.bmp: Predicted PMI = 9.16 hours
# 9221L_3_1.bmp: Predicted PMI = 23.49 hours
# 9176L_2_5.bmp: Predicted PMI = 15.65 hours
# 9258L_1_10.bmp: Predicted PMI = 13.15 hours
# 9016R_8_3.bmp: Predicted PMI = 10.11 hours
# 9149L_4_2.bmp: Predicted PMI = 15.74 hours
# 9014R_1_5.bmp: Predicted PMI = 8.61 hours
# 9160L_4_5.bmp: Predicted PMI = 13.77 hours
# 9182L_1_5.bmp: Predicted PMI = 6.16 hours
# 9177L_2_5.bmp: Predicted PMI = 8.23 hours
# 9142R_1_3.bmp: Predicted PMI = 11.51 hours
# 9214L_3_3.bmp: Predicted PMI = 33.14 hours
# 9019R_2_1.bmp: Predicted PMI = 36.90 hours
# 9256R_2_6.bmp: Predicted PMI = 40.63 hours
# 9188R_4_4.bmp: Predicted PMI = 13.61 hours
# 9143R_1_3.bmp: Predicted PMI = 13.31 hours
# 9224L_13_3.bmp: Predicted PMI = 5.74 hours
# 9199L_4_1.bmp: Predicted PMI = 2.14 hours
# 9018R_2_1.bmp: Predicted PMI = 14.88 hours
# 9224R_15_1.bmp: Predicted PMI = 5.16 hours
# 9256L_1_2.bmp: Predicted PMI = 27.60 hours
# 9153R_2_2.bmp: Predicted PMI = 8.99 hours
# 9049L_9_3.bmp: Predicted PMI = 15.82 hours
# 9144R_4_2.bmp: Predicted PMI = 39.63 hours
# 9110L_3_7.bmp: Predicted PMI = 6.09 hours
# 9080L_5_2.bmp: Predicted PMI = 10.71 hours
# 9101R_3_2.bmp: Predicted PMI = 12.40 hours
# 9145R_4_2.bmp: Predicted PMI = 27.06 hours
# 9031L_1_2.bmp: Predicted PMI = 12.02 hours
# 9257L_1_2.bmp: Predicted PMI = 11.63 hours
# 9018L_1_5.bmp: Predicted PMI = 15.26 hours
# 9184L_2_2.bmp: Predicted PMI = 6.82 hours
# 9041R_3_2.bmp: Predicted PMI = 9.78 hours
# 9103L_1_9.bmp: Predicted PMI = 10.37 hours
# 9158L_1_5.bmp: Predicted PMI = 10.85 hours
# 9226R_3_2.bmp: Predicted PMI = 7.72 hours
# 9159L_1_5.bmp: Predicted PMI = 4.17 hours
# 9170L_1_2.bmp: Predicted PMI = 5.84 hours
# 9040R_3_2.bmp: Predicted PMI = 9.07 hours
# 9013R_2_2.bmp: Predicted PMI = 8.33 hours
# 9158R_2_1.bmp: Predicted PMI = 28.95 hours
# 9012L_1_6.bmp: Predicted PMI = 23.39 hours
# 9149L_2_4.bmp: Predicted PMI = 27.85 hours
# 9112L_2_8.bmp: Predicted PMI = 93.40 hours
# 9195L_1_3.bmp: Predicted PMI = 6.62 hours
# 9124L_5_3.bmp: Predicted PMI = 23.66 hours
# 9170R_2_6.bmp: Predicted PMI = 9.99 hours
# 9194L_1_3.bmp: Predicted PMI = 17.99 hours
# 9148L_2_4.bmp: Predicted PMI = 15.08 hours
# 9188R_2_2.bmp: Predicted PMI = 15.39 hours
# 9202L_3_5.bmp: Predicted PMI = 8.39 hours
# 9199L_2_7.bmp: Predicted PMI = 15.62 hours
# 9154L_2_1.bmp: Predicted PMI = 9.28 hours
# 9091R_3_1.bmp: Predicted PMI = 15.66 hours
# 9251R_1_1.bmp: Predicted PMI = 6.59 hours
# 9103R_10_4.bmp: Predicted PMI = 78.21 hours
# 9145R_2_4.bmp: Predicted PMI = 13.78 hours
# 9240L_1_4.bmp: Predicted PMI = 27.15 hours
# 9199R_1_3.bmp: Predicted PMI = 4.25 hours
# 9250R_1_1.bmp: Predicted PMI = 17.74 hours
# 9124R_16_4.bmp: Predicted PMI = 51.29 hours
# 9155L_2_1.bmp: Predicted PMI = 7.34 hours
# 9106L_3_1.bmp: Predicted PMI = 9.60 hours
# 9036R_1_1.bmp: Predicted PMI = 13.86 hours
# 9090R_3_1.bmp: Predicted PMI = 7.82 hours
# 9198R_1_3.bmp: Predicted PMI = 12.47 hours
# 9241L_1_4.bmp: Predicted PMI = 12.41 hours
# 9144R_2_4.bmp: Predicted PMI = 13.62 hours
# 9149R_3_2.bmp: Predicted PMI = 38.57 hours
# 9236L_1_5.bmp: Predicted PMI = 7.81 hours
# 9079L_1_2.bmp: Predicted PMI = 5.12 hours
# 9050L_1_5.bmp: Predicted PMI = 7.42 hours
# 9051L_1_5.bmp: Predicted PMI = 6.43 hours
# 9237L_1_5.bmp: Predicted PMI = 24.39 hours
# 9078L_1_2.bmp: Predicted PMI = 23.42 hours
# 9049R_11_4.bmp: Predicted PMI = 15.16 hours
# 9003R_3_1.bmp: Predicted PMI = 119.92 hours
# 9124L_7_1.bmp: Predicted PMI = 21.14 hours
# 9050R_2_1.bmp: Predicted PMI = 4.82 hours
# 9133L_1_1.bmp: Predicted PMI = 15.94 hours
# 9221R_4_1.bmp: Predicted PMI = 13.73 hours
# 9236R_2_1.bmp: Predicted PMI = 25.75 hours
# 9184R_3_4.bmp: Predicted PMI = 18.92 hours
# 9122R_1_4.bmp: Predicted PMI = 67.64 hours
# 9041L_2_4.bmp: Predicted PMI = 38.94 hours
# 9166R_6_4.bmp: Predicted PMI = 78.20 hours
# 9049L_3_8.bmp: Predicted PMI = 7.64 hours
# 9068L_2_3.bmp: Predicted PMI = 6.47 hours
# 9002R_3_1.bmp: Predicted PMI = 9.29 hours
# 9051R_2_1.bmp: Predicted PMI = 6.70 hours
# 9132L_1_1.bmp: Predicted PMI = 8.85 hours
# 9226L_2_4.bmp: Predicted PMI = 10.57 hours
# 9069L_2_3.bmp: Predicted PMI = 11.98 hours
# 9178R_1_8.bmp: Predicted PMI = 19.35 hours
# 9080R_2_2.bmp: Predicted PMI = 10.70 hours
# 9145L_3_2.bmp: Predicted PMI = 8.89 hours
# 9261R_1_9.bmp: Predicted PMI = 116.25 hours
# 9160L_10_3.bmp: Predicted PMI = 4.92 hours
# 9213R_1_2.bmp: Predicted PMI = 20.55 hours
# 9110R_4_7.bmp: Predicted PMI = 11.34 hours
# 9202L_1_7.bmp: Predicted PMI = 8.43 hours
# 9129L_29_1.bmp: Predicted PMI = 37.92 hours
# 9212R_1_2.bmp: Predicted PMI = 10.03 hours
# 9074R_1_2.bmp: Predicted PMI = 7.67 hours
# 9260R_1_9.bmp: Predicted PMI = 13.02 hours
# 9144L_3_2.bmp: Predicted PMI = 41.87 hours
# 9203L_1_7.bmp: Predicted PMI = 4.14 hours
# 9188L_3_4.bmp: Predicted PMI = 9.57 hours
# 9202R_2_3.bmp: Predicted PMI = 12.75 hours
# 9064R_2_3.bmp: Predicted PMI = 12.15 hours
# 9107L_1_3.bmp: Predicted PMI = 5.04 hours
# 9090R_1_3.bmp: Predicted PMI = 86.51 hours
# 9065R_2_3.bmp: Predicted PMI = 6.59 hours
# 9106L_1_3.bmp: Predicted PMI = 6.55 hours
# 9203R_2_3.bmp: Predicted PMI = 13.46 hours
# 9181L_2_8.bmp: Predicted PMI = 7.21 hours
# 9174L_1_8.bmp: Predicted PMI = 6.42 hours
#
# ================= Evaluation Metrics =================
# MAE : 92.181
# RMSE: 229.922
# R²  : -0.121

# %% [markdown]
# ## INFERENCE FOR CLIP NIR, RGB

# %%
import torch
import open_clip
import numpy as np
import pandas as pd
import cv2
import os
import joblib
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from PIL import Image

# ============ CONFIG ============
data_root = "/DATA2/akshay/Akshat/NIJ/nir_images"  # Image folder
csv_path = "/DATA2/akshay/Akshat/metadata/nij_nir.csv"  # Optional CSV with 'filename' and 'pmi'
embedding_cache_path = "inference_openclip_embeddings.npz"
model_name = "ViT-B-32"
pretrained = "openai"
model_fold = 2 # Fold number of trained model to use
device = "cuda" if torch.cuda.is_available() else "cpu"
# ================================

print(f"Device: {device}")
print(f"Using fold {model_fold}")

# ---------- Load MLP and Scaler ----------
mlp = joblib.load(f"mlp_openclip_model_fold{model_fold}.joblib")
scaler = joblib.load(f"scaler_openclip_fold{model_fold}.joblib")

# ---------- Load OpenCLIP ----------
model, _, preprocess = open_clip.create_model_and_transforms(model_name, pretrained=pretrained)
model.eval().to(device)

# ---------- Extract or Load Features ----------
def extract_openclip_features(image_paths, batch_size=32):
    features = []
    valid_filenames = []
    for i in tqdm(range(0, len(image_paths), batch_size), desc="Extracting OpenCLIP Features"):
        batch_paths = image_paths[i:i + batch_size]
        batch_images = []
        current_filenames = []

        for path in batch_paths:
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"Warning: Unable to load image {path}")
                continue
            img = cv2.resize(img, (224, 224))
            img = np.stack([img] * 3, axis=-1)
            img = preprocess(Image.fromarray(img))  # OpenCLIP's transform
            batch_images.append(img)
            current_filenames.append(os.path.basename(path))

        if not batch_images:
            continue

        batch_tensor = torch.stack(batch_images).to(device)
        with torch.no_grad():
            batch_features = model.encode_image(batch_tensor).cpu().numpy()
        features.append(batch_features)
        valid_filenames.extend(current_filenames)

    return np.vstack(features), valid_filenames

# ---------- Gather Image Paths ----------
if csv_path and os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    image_paths = [os.path.join(data_root, fname) for fname in df["filename"]]
    ground_truth = df.set_index("filename")["pmi"].to_dict()
else:
    image_paths = [os.path.join(data_root, f) for f in os.listdir(data_root) if f.endswith(".bmp")]
    ground_truth = None

# ---------- Load or Generate Embeddings ----------
if os.path.exists(embedding_cache_path):
    print("Loading cached OpenCLIP embeddings...")
    data = np.load(embedding_cache_path, allow_pickle=True)
    features = data["features"]
    valid_filenames = data["filenames"]
else:
    print("Extracting OpenCLIP embeddings...")
    features, valid_filenames = extract_openclip_features(image_paths)
    np.savez(embedding_cache_path, features=features, filenames=valid_filenames)

# ---------- Scale + Predict ----------
features_scaled = scaler.transform(features)
predicted_pmi = mlp.predict(features_scaled)

# ---------- Output Predictions ----------
for fname, pred in zip(valid_filenames, predicted_pmi):
    print(f"{fname}: Predicted PMI = {pred:.2f} hours")

# ---------- Metrics (if ground truth exists) ----------
if ground_truth:
    y_true = [ground_truth[f] for f in valid_filenames if f in ground_truth]
    y_pred = [p for f, p in zip(valid_filenames, predicted_pmi) if f in ground_truth]

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    print("\n================= Evaluation Metrics =================")
    print(f"MAE : {mae:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print(f"R²  : {r2:.3f}")
# Out:
# Device: cuda
# Using fold 2
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/open_clip/factory.py:388: UserWarning: These pretrained weights were trained with QuickGELU activation but the model config does not have that enabled. Consider using a model config with a "-quickgelu" suffix or enable with a flag.
#   warnings.warn(
# Loading cached OpenCLIP embeddings...
# 9003L_3_3.png: Predicted PMI = 66.16 hours
# 9013L_1_1.png: Predicted PMI = 93.72 hours
# 9013L_2_1.png: Predicted PMI = 48.00 hours
# 9013R_1_1.png: Predicted PMI = 100.42 hours
# 9013R_2_1.png: Predicted PMI = 135.16 hours
# 9014L_1_1.png: Predicted PMI = 154.34 hours
# 9014L_2_1.png: Predicted PMI = 81.49 hours
# 9015L_1_1.png: Predicted PMI = 24.07 hours
# 9015L_2_1.png: Predicted PMI = 15.93 hours
# 9021L_1_1.png: Predicted PMI = 6.31 hours
# 9021L_1_2.png: Predicted PMI = 12.63 hours
# 9021L_1_3.png: Predicted PMI = 111.46 hours
# 9021R_1_1.png: Predicted PMI = 21.22 hours
# 9021R_1_2.png: Predicted PMI = 17.47 hours
# 9021R_1_3.png: Predicted PMI = 32.28 hours
# 9023L_1_1.png: Predicted PMI = 4.87 hours
# 9023L_1_2.png: Predicted PMI = 28.68 hours
# 9023L_1_3.png: Predicted PMI = 4.23 hours
# 9023R_1_1.png: Predicted PMI = 14.97 hours
# 9023R_1_2.png: Predicted PMI = 28.51 hours
# 9023R_1_3.png: Predicted PMI = 20.48 hours
# 9025L_1_1.png: Predicted PMI = 48.82 hours
# 9025L_1_2.png: Predicted PMI = 27.45 hours
# 9025L_1_3.png: Predicted PMI = 40.78 hours
# 9025R_1_1.png: Predicted PMI = 9.47 hours
# 9025R_1_2.png: Predicted PMI = 12.74 hours
# 9025R_1_3.png: Predicted PMI = 1.69 hours
# 9027L_1_1.png: Predicted PMI = 4.57 hours
# 9027L_1_2.png: Predicted PMI = 30.25 hours
# 9027R_1_4.png: Predicted PMI = 337.38 hours
# 9027R_1_5.png: Predicted PMI = 217.46 hours
# 9027R_1_6.png: Predicted PMI = 156.79 hours
# 9028L_1_1.png: Predicted PMI = 31.11 hours
# 9028L_1_2.png: Predicted PMI = 20.52 hours
# 9028L_1_3.png: Predicted PMI = 31.42 hours
# 9028L_2_1.png: Predicted PMI = 124.80 hours
# 9028L_2_2.png: Predicted PMI = 47.75 hours
# 9028L_2_3.png: Predicted PMI = 39.63 hours
# 9028R_1_4.png: Predicted PMI = 38.78 hours
# 9028R_1_5.png: Predicted PMI = 40.63 hours
# 9028R_1_6.png: Predicted PMI = 104.28 hours
# 9028R_2_1.png: Predicted PMI = 82.22 hours
# 9028R_2_2.png: Predicted PMI = 53.08 hours
# 9029L_1_1.png: Predicted PMI = 97.90 hours
# 9029L_1_2.png: Predicted PMI = 181.50 hours
# 9029L_1_3.png: Predicted PMI = 107.74 hours
# 9029R_1_1.png: Predicted PMI = 81.67 hours
# 9029R_1_2.png: Predicted PMI = 52.68 hours
# 9029R_1_3.png: Predicted PMI = 113.03 hours
# 9030L_1_1.png: Predicted PMI = 180.16 hours
# 9030L_1_2.png: Predicted PMI = 70.35 hours
# 9030L_1_3.png: Predicted PMI = 123.27 hours
# 9030R_1_1.png: Predicted PMI = 1.89 hours
# 9030R_1_2.png: Predicted PMI = 12.55 hours
# 9030R_1_3.png: Predicted PMI = 4.48 hours
# 9031L_1_1.png: Predicted PMI = 4.95 hours
# 9031L_1_2.png: Predicted PMI = 5.10 hours
# 9031L_1_3.png: Predicted PMI = -0.05 hours
# 9031L_2_1.png: Predicted PMI = 31.90 hours
# 9031L_2_2.png: Predicted PMI = 28.18 hours
# 9031L_2_3.png: Predicted PMI = 24.48 hours
# 9031R_1_1.png: Predicted PMI = 2.01 hours
# 9031R_1_2.png: Predicted PMI = 7.18 hours
# 9031R_1_3.png: Predicted PMI = 0.98 hours
# 9031R_2_1.png: Predicted PMI = 32.62 hours
# 9031R_2_2.png: Predicted PMI = 37.19 hours
# 9031R_2_3.png: Predicted PMI = 31.06 hours
# 9032L_1_1.png: Predicted PMI = 24.94 hours
# 9032L_1_2.png: Predicted PMI = 30.60 hours
# 9032L_1_3.png: Predicted PMI = 10.94 hours
# 9033L_1_1.png: Predicted PMI = 47.26 hours
# 9033L_1_2.png: Predicted PMI = 39.00 hours
# 9033L_1_3.png: Predicted PMI = 38.84 hours
# 9033L_2_1.png: Predicted PMI = 18.44 hours
# 9033L_2_2.png: Predicted PMI = 15.29 hours
# 9033R_1_1.png: Predicted PMI = 108.84 hours
# 9033R_1_2.png: Predicted PMI = 82.58 hours
# 9033R_1_3.png: Predicted PMI = 47.78 hours
# 9033R_2_1.png: Predicted PMI = 11.30 hours
# 9033R_2_2.png: Predicted PMI = 5.32 hours
# 9033R_2_3.png: Predicted PMI = 0.79 hours
# 9034L_1_1.png: Predicted PMI = 52.96 hours
# 9034L_1_2.png: Predicted PMI = 47.74 hours
# 9034L_1_3.png: Predicted PMI = 24.97 hours
# 9034L_2_1.png: Predicted PMI = 25.83 hours
# 9034L_2_3.png: Predicted PMI = 45.64 hours
# 9034R_2_1.png: Predicted PMI = 42.17 hours
# 9034R_2_2.png: Predicted PMI = 110.03 hours
# 9034R_2_3.png: Predicted PMI = 34.57 hours
# 9035L_1_1.png: Predicted PMI = 63.58 hours
# 9035L_1_2.png: Predicted PMI = 119.25 hours
# 9035L_1_3.png: Predicted PMI = 150.77 hours
# 9035R_1_1.png: Predicted PMI = 147.78 hours
# 9035R_1_2.png: Predicted PMI = 98.09 hours
# 9035R_1_3.png: Predicted PMI = 113.57 hours
# 9036L_2_1.png: Predicted PMI = 53.56 hours
# 9036L_2_2.png: Predicted PMI = 77.94 hours
# 9036L_2_3.png: Predicted PMI = 89.79 hours
# 9036R_2_1.png: Predicted PMI = 87.69 hours
# 9036R_2_2.png: Predicted PMI = 31.44 hours
# 9036R_2_3.png: Predicted PMI = 35.32 hours
# 9037L_1_1.png: Predicted PMI = 11.09 hours
# 9037L_1_2.png: Predicted PMI = 16.53 hours
# 9037L_1_3.png: Predicted PMI = 11.49 hours
# 9037R_1_2.png: Predicted PMI = 6.70 hours
# 9037R_1_3.png: Predicted PMI = 7.87 hours
# 9038L_2_1.png: Predicted PMI = 50.38 hours
# 9038L_2_2.png: Predicted PMI = 131.10 hours
# 9038L_2_3.png: Predicted PMI = 122.15 hours
# 9038R_2_1.png: Predicted PMI = 11.57 hours
# 9038R_2_2.png: Predicted PMI = 25.86 hours
# 9038R_2_3.png: Predicted PMI = 15.32 hours
# 9039L_1_1.png: Predicted PMI = 27.26 hours
# 9039L_1_3.png: Predicted PMI = 1.09 hours
# 9039R_1_1.png: Predicted PMI = 12.39 hours
# 9039R_1_2.png: Predicted PMI = 4.14 hours
# 9039R_1_3.png: Predicted PMI = 12.30 hours
# 9040L_1_1.png: Predicted PMI = 15.11 hours
# 9040L_1_2.png: Predicted PMI = 28.72 hours
# 9040L_1_3.png: Predicted PMI = 28.77 hours
# 9040L_2_1.png: Predicted PMI = 7.59 hours
# 9040L_2_2.png: Predicted PMI = 101.28 hours
# 9040L_2_3.png: Predicted PMI = 8.28 hours
# 9040L_3_1.png: Predicted PMI = 21.11 hours
# 9040L_3_2.png: Predicted PMI = 62.20 hours
# 9040L_3_3.png: Predicted PMI = 75.51 hours
# 9040R_1_1.png: Predicted PMI = 32.63 hours
# 9040R_1_2.png: Predicted PMI = 14.91 hours
# 9040R_1_3.png: Predicted PMI = 17.66 hours
# 9040R_2_1.png: Predicted PMI = 2.73 hours
# 9040R_2_2.png: Predicted PMI = 8.25 hours
# 9040R_2_3.png: Predicted PMI = 21.90 hours
# 9040R_3_1.png: Predicted PMI = 47.29 hours
# 9040R_3_2.png: Predicted PMI = 57.38 hours
# 9040R_3_3.png: Predicted PMI = 48.44 hours
# 9041L_1_1.png: Predicted PMI = 57.56 hours
# 9041L_1_2.png: Predicted PMI = 39.56 hours
# 9041L_1_3.png: Predicted PMI = 81.77 hours
# 9041L_2_1.png: Predicted PMI = 50.51 hours
# 9041L_2_2.png: Predicted PMI = 17.70 hours
# 9041L_2_3.png: Predicted PMI = 8.03 hours
# 9041L_3_1.png: Predicted PMI = 128.58 hours
# 9041L_3_2.png: Predicted PMI = 86.95 hours
# 9041L_3_3.png: Predicted PMI = 76.31 hours
# 9041R_1_1.png: Predicted PMI = 8.86 hours
# 9041R_1_2.png: Predicted PMI = 8.62 hours
# 9041R_1_3.png: Predicted PMI = 11.02 hours
# 9041R_2_1.png: Predicted PMI = 70.44 hours
# 9041R_2_2.png: Predicted PMI = 51.73 hours
# 9041R_2_3.png: Predicted PMI = 97.03 hours
# 9041R_3_1.png: Predicted PMI = 151.92 hours
# 9041R_3_2.png: Predicted PMI = 88.02 hours
# 9041R_3_3.png: Predicted PMI = 158.79 hours
# 9042L_1_1.png: Predicted PMI = 73.41 hours
# 9042L_1_2.png: Predicted PMI = 80.95 hours
# 9042L_1_3.png: Predicted PMI = 70.94 hours
# 9042R_1_1.png: Predicted PMI = 32.14 hours
# 9042R_1_2.png: Predicted PMI = 70.46 hours
# 9042R_1_3.png: Predicted PMI = 43.33 hours
# 9043L_1_1.png: Predicted PMI = 36.30 hours
# 9043L_1_2.png: Predicted PMI = 9.77 hours
# 9043L_1_3.png: Predicted PMI = 35.77 hours
# 9043R_1_1.png: Predicted PMI = 6.13 hours
# 9043R_1_2.png: Predicted PMI = 10.10 hours
# 9043R_1_3.png: Predicted PMI = 11.14 hours
# 9044L_1_1.png: Predicted PMI = 35.12 hours
# 9044L_1_2.png: Predicted PMI = 10.92 hours
# 9044L_1_3.png: Predicted PMI = 18.83 hours
# 9044L_2_1.png: Predicted PMI = 73.25 hours
# 9044L_2_2.png: Predicted PMI = 22.98 hours
# 9044L_2_3.png: Predicted PMI = 145.42 hours
# 9044R_1_1.png: Predicted PMI = 1.33 hours
# 9044R_1_2.png: Predicted PMI = 2.70 hours
# 9044R_1_3.png: Predicted PMI = 86.78 hours
# 9044R_2_1.png: Predicted PMI = 139.74 hours
# 9044R_2_2.png: Predicted PMI = 85.64 hours
# 9044R_2_3.png: Predicted PMI = 55.56 hours
# 9045L_2_1.png: Predicted PMI = 13.10 hours
# 9045L_2_2.png: Predicted PMI = 9.69 hours
# 9045L_2_3.png: Predicted PMI = 10.84 hours
# 9045R_1_1.png: Predicted PMI = 40.25 hours
# 9045R_1_2.png: Predicted PMI = 41.03 hours
# 9045R_1_3.png: Predicted PMI = 26.86 hours
# 9045R_2_1.png: Predicted PMI = 23.70 hours
# 9045R_2_2.png: Predicted PMI = 17.39 hours
# 9045R_2_3.png: Predicted PMI = 22.16 hours
# 9046L_1_1.png: Predicted PMI = 22.92 hours
# 9046L_1_2.png: Predicted PMI = 4.83 hours
# 9046L_1_3.png: Predicted PMI = 15.35 hours
# 9046L_2_1.png: Predicted PMI = 17.96 hours
# 9046L_2_2.png: Predicted PMI = 23.69 hours
# 9046L_2_3.png: Predicted PMI = 18.00 hours
# 9046L_3_1.png: Predicted PMI = 12.66 hours
# 9046L_3_2.png: Predicted PMI = 7.04 hours
# 9046L_3_3.png: Predicted PMI = 14.72 hours
# 9046R_1_1.png: Predicted PMI = 7.50 hours
# 9046R_1_2.png: Predicted PMI = 4.90 hours
# 9046R_1_3.png: Predicted PMI = 3.51 hours
# 9046R_2_1.png: Predicted PMI = 11.65 hours
# 9046R_2_2.png: Predicted PMI = 23.69 hours
# 9046R_2_3.png: Predicted PMI = 13.76 hours
# 9046R_3_1.png: Predicted PMI = 29.11 hours
# 9046R_3_2.png: Predicted PMI = 24.55 hours
# 9046R_3_3.png: Predicted PMI = 34.40 hours
# 9047L_1_1.png: Predicted PMI = 9.81 hours
# 9047L_1_2.png: Predicted PMI = 12.59 hours
# 9047L_1_3.png: Predicted PMI = 10.07 hours
# 9047L_2_1.png: Predicted PMI = 3.00 hours
# 9047L_2_2.png: Predicted PMI = 14.23 hours
# 9047L_2_3.png: Predicted PMI = 19.28 hours
# 9047R_1_1.png: Predicted PMI = 29.82 hours
# 9047R_1_2.png: Predicted PMI = 62.89 hours
# 9047R_1_3.png: Predicted PMI = 27.24 hours
# 9047R_2_1.png: Predicted PMI = 21.51 hours
# 9047R_2_2.png: Predicted PMI = 12.41 hours
# 9047R_2_3.png: Predicted PMI = 17.27 hours
# 9048L_1_1.png: Predicted PMI = 39.31 hours
# 9048L_1_2.png: Predicted PMI = 45.33 hours
# 9048L_1_3.png: Predicted PMI = 87.53 hours
# 9048L_2_1.png: Predicted PMI = 49.97 hours
# 9048L_2_2.png: Predicted PMI = 26.04 hours
# 9048L_2_3.png: Predicted PMI = 97.33 hours
# 9048L_3_1.png: Predicted PMI = 22.70 hours
# 9048L_3_2.png: Predicted PMI = 44.08 hours
# 9048L_3_3.png: Predicted PMI = 16.13 hours
# 9048R_1_1.png: Predicted PMI = 2.59 hours
# 9048R_1_2.png: Predicted PMI = 21.50 hours
# 9048R_1_3.png: Predicted PMI = 10.46 hours
# 9048R_2_1.png: Predicted PMI = 79.43 hours
# 9048R_2_2.png: Predicted PMI = 39.52 hours
# 9048R_2_3.png: Predicted PMI = 8.09 hours
# 9048R_3_1.png: Predicted PMI = 59.05 hours
# 9048R_3_2.png: Predicted PMI = 64.88 hours
# 9048R_3_3.png: Predicted PMI = 80.50 hours
# 9049L_10_1.png: Predicted PMI = 20.91 hours
# 9049L_10_2.png: Predicted PMI = 50.10 hours
# 9049L_10_3.png: Predicted PMI = 27.61 hours
# 9049L_11_1.png: Predicted PMI = 22.80 hours
# 9049L_11_2.png: Predicted PMI = 41.29 hours
# 9049L_11_3.png: Predicted PMI = 34.82 hours
# 9049L_12_1.png: Predicted PMI = 23.79 hours
# 9049L_12_2.png: Predicted PMI = 35.50 hours
# 9049L_12_3.png: Predicted PMI = 156.54 hours
# 9049L_13_1.png: Predicted PMI = 99.63 hours
# 9049L_13_2.png: Predicted PMI = 34.48 hours
# 9049L_13_3.png: Predicted PMI = 149.19 hours
# 9049L_15_1.png: Predicted PMI = 88.72 hours
# 9049L_15_2.png: Predicted PMI = 109.74 hours
# 9049L_15_3.png: Predicted PMI = 91.72 hours
# 9049L_1_1.png: Predicted PMI = 9.19 hours
# 9049L_1_2.png: Predicted PMI = 24.66 hours
# 9049L_1_3.png: Predicted PMI = 37.08 hours
# 9049L_2_1.png: Predicted PMI = 72.25 hours
# 9049L_2_2.png: Predicted PMI = 52.63 hours
# 9049L_2_3.png: Predicted PMI = 43.05 hours
# 9049L_3_1.png: Predicted PMI = 15.72 hours
# 9049L_3_2.png: Predicted PMI = 21.39 hours
# 9049L_3_3.png: Predicted PMI = 17.88 hours
# 9049L_4_1.png: Predicted PMI = 92.19 hours
# 9049L_4_2.png: Predicted PMI = 47.53 hours
# 9049L_4_3.png: Predicted PMI = 57.22 hours
# 9049L_5_1.png: Predicted PMI = 43.36 hours
# 9049L_5_2.png: Predicted PMI = 27.39 hours
# 9049L_5_3.png: Predicted PMI = 59.11 hours
# 9049L_6_1.png: Predicted PMI = 51.03 hours
# 9049L_6_2.png: Predicted PMI = 59.34 hours
# 9049L_6_3.png: Predicted PMI = 79.29 hours
# 9049L_7_1.png: Predicted PMI = 34.83 hours
# 9049L_7_2.png: Predicted PMI = 117.76 hours
# 9049L_7_3.png: Predicted PMI = 102.58 hours
# 9049L_7_4.png: Predicted PMI = 109.04 hours
# 9049L_8_1.png: Predicted PMI = 73.72 hours
# 9049L_8_2.png: Predicted PMI = 48.09 hours
# 9049L_8_3.png: Predicted PMI = 69.67 hours
# 9049L_9_1.png: Predicted PMI = 59.91 hours
# 9049L_9_2.png: Predicted PMI = 105.66 hours
# 9049L_9_3.png: Predicted PMI = 153.35 hours
# 9049R_10_1.png: Predicted PMI = 10.81 hours
# 9049R_10_2.png: Predicted PMI = 21.38 hours
# 9049R_10_3.png: Predicted PMI = 15.34 hours
# 9049R_11_1.png: Predicted PMI = 134.59 hours
# 9049R_11_2.png: Predicted PMI = 155.90 hours
# 9049R_11_3.png: Predicted PMI = 98.13 hours
# 9049R_12_1.png: Predicted PMI = 109.34 hours
# 9049R_12_2.png: Predicted PMI = 99.99 hours
# 9049R_12_3.png: Predicted PMI = 55.09 hours
# 9049R_13_1.png: Predicted PMI = 39.49 hours
# 9049R_13_2.png: Predicted PMI = 83.45 hours
# 9049R_13_3.png: Predicted PMI = 109.07 hours
# 9049R_14_1.png: Predicted PMI = 11.39 hours
# 9049R_14_2.png: Predicted PMI = 15.71 hours
# 9049R_14_3.png: Predicted PMI = 25.22 hours
# 9049R_15_1.png: Predicted PMI = 94.29 hours
# 9049R_15_2.png: Predicted PMI = 185.78 hours
# 9049R_15_3.png: Predicted PMI = 138.49 hours
# 9049R_1_1.png: Predicted PMI = 8.24 hours
# 9049R_1_2.png: Predicted PMI = 48.58 hours
# 9049R_1_3.png: Predicted PMI = 103.25 hours
# 9049R_2_1.png: Predicted PMI = 53.08 hours
# 9049R_2_2.png: Predicted PMI = 43.38 hours
# 9049R_2_3.png: Predicted PMI = 64.25 hours
# 9049R_3_1.png: Predicted PMI = 184.06 hours
# 9049R_3_2.png: Predicted PMI = 21.14 hours
# 9049R_3_3.png: Predicted PMI = 16.86 hours
# 9049R_4_1.png: Predicted PMI = 11.89 hours
# 9049R_4_2.png: Predicted PMI = 15.68 hours
# 9049R_4_3.png: Predicted PMI = 130.15 hours
# 9049R_5_1.png: Predicted PMI = 81.39 hours
# 9049R_5_2.png: Predicted PMI = 31.28 hours
# 9049R_5_3.png: Predicted PMI = 51.79 hours
# 9049R_6_1.png: Predicted PMI = 184.51 hours
# 9049R_6_2.png: Predicted PMI = 96.20 hours
# 9049R_6_3.png: Predicted PMI = 180.44 hours
# 9049R_7_1.png: Predicted PMI = 85.28 hours
# 9049R_7_2.png: Predicted PMI = 218.54 hours
# 9049R_7_3.png: Predicted PMI = 204.40 hours
# 9049R_8_1.png: Predicted PMI = 57.87 hours
# 9049R_8_2.png: Predicted PMI = 96.40 hours
# 9049R_8_3.png: Predicted PMI = 66.44 hours
# 9049R_9_1.png: Predicted PMI = 57.62 hours
# 9049R_9_2.png: Predicted PMI = 63.41 hours
# 9049R_9_3.png: Predicted PMI = 50.99 hours
# 9050L_1_1.png: Predicted PMI = 17.23 hours
# 9050L_1_2.png: Predicted PMI = 3.71 hours
# 9050L_1_3.png: Predicted PMI = 38.73 hours
# 9050L_2_1.png: Predicted PMI = 14.40 hours
# 9050L_2_2.png: Predicted PMI = 15.07 hours
# 9050L_2_3.png: Predicted PMI = 8.43 hours
# 9050L_3_1.png: Predicted PMI = 17.85 hours
# 9050L_3_2.png: Predicted PMI = 14.56 hours
# 9050L_3_3.png: Predicted PMI = 22.42 hours
# 9050L_4_1.png: Predicted PMI = 24.89 hours
# 9050L_4_2.png: Predicted PMI = 3.75 hours
# 9050L_4_3.png: Predicted PMI = 5.06 hours
# 9050L_5_1.png: Predicted PMI = 59.41 hours
# 9050L_5_2.png: Predicted PMI = 159.94 hours
# 9050L_5_3.png: Predicted PMI = 37.39 hours
# 9050L_6_1.png: Predicted PMI = 27.86 hours
# 9050L_6_2.png: Predicted PMI = 19.91 hours
# 9050L_6_3.png: Predicted PMI = 17.16 hours
# 9050R_1_1.png: Predicted PMI = 26.03 hours
# 9050R_1_2.png: Predicted PMI = 24.75 hours
# 9050R_1_3.png: Predicted PMI = 15.37 hours
# 9050R_2_1.png: Predicted PMI = 12.89 hours
# 9050R_2_2.png: Predicted PMI = 1.31 hours
# 9050R_2_3.png: Predicted PMI = 8.74 hours
# 9050R_3_1.png: Predicted PMI = 15.29 hours
# 9050R_3_2.png: Predicted PMI = 9.40 hours
# 9050R_3_3.png: Predicted PMI = 12.49 hours
# 9050R_4_1.png: Predicted PMI = 96.75 hours
# 9050R_4_2.png: Predicted PMI = 78.04 hours
# 9050R_4_3.png: Predicted PMI = 11.29 hours
# 9050R_5_1.png: Predicted PMI = 7.53 hours
# 9050R_5_2.png: Predicted PMI = 23.81 hours
# 9050R_5_3.png: Predicted PMI = 25.25 hours
# 9050R_6_1.png: Predicted PMI = 27.18 hours
# 9050R_6_2.png: Predicted PMI = 30.51 hours
# 9050R_6_3.png: Predicted PMI = 40.85 hours
# 9051L_1_1.png: Predicted PMI = 22.01 hours
# 9051L_1_2.png: Predicted PMI = 18.16 hours
# 9051L_1_3.png: Predicted PMI = 16.62 hours
# 9051L_2_1.png: Predicted PMI = 59.52 hours
# 9051L_2_2.png: Predicted PMI = 23.61 hours
# 9051L_2_3.png: Predicted PMI = 113.24 hours
# 9051R_1_1.png: Predicted PMI = 6.84 hours
# 9051R_1_2.png: Predicted PMI = 27.63 hours
# 9051R_1_3.png: Predicted PMI = 69.12 hours
# 9051R_2_1.png: Predicted PMI = 75.85 hours
# 9051R_2_3.png: Predicted PMI = 19.43 hours
# 9052L_1_1.png: Predicted PMI = 6.88 hours
# 9052L_1_2.png: Predicted PMI = 4.78 hours
# 9052L_1_3.png: Predicted PMI = 4.54 hours
# 9052L_2_1.png: Predicted PMI = 25.09 hours
# 9052L_2_2.png: Predicted PMI = 26.91 hours
# 9052L_2_3.png: Predicted PMI = 25.54 hours
# 9052L_3_1.png: Predicted PMI = 43.67 hours
# 9052L_3_2.png: Predicted PMI = 50.25 hours
# 9052L_3_3.png: Predicted PMI = 51.64 hours
# 9052L_4_2.png: Predicted PMI = 46.29 hours
# 9052L_4_3.png: Predicted PMI = 47.86 hours
# 9052L_5_1.png: Predicted PMI = 7.02 hours
# 9052L_5_2.png: Predicted PMI = 31.58 hours
# 9052L_5_3.png: Predicted PMI = 4.96 hours
# 9052L_6_1.png: Predicted PMI = 9.56 hours
# 9052L_6_2.png: Predicted PMI = 10.88 hours
# 9052L_6_3.png: Predicted PMI = 6.79 hours
# 9052R_1_1.png: Predicted PMI = 8.19 hours
# 9052R_1_2.png: Predicted PMI = 4.99 hours
# 9052R_1_3.png: Predicted PMI = 4.46 hours
# 9052R_2_1.png: Predicted PMI = 21.55 hours
# 9052R_2_2.png: Predicted PMI = 13.46 hours
# 9052R_2_3.png: Predicted PMI = 13.04 hours
# 9052R_3_1.png: Predicted PMI = 45.95 hours
# 9052R_3_2.png: Predicted PMI = 18.21 hours
# 9052R_3_3.png: Predicted PMI = 106.23 hours
# 9052R_4_1.png: Predicted PMI = 168.23 hours
# 9052R_4_2.png: Predicted PMI = 17.58 hours
# 9052R_4_3.png: Predicted PMI = 24.35 hours
# 9052R_5_1.png: Predicted PMI = 21.06 hours
# 9052R_5_2.png: Predicted PMI = 38.58 hours
# 9052R_5_3.png: Predicted PMI = 18.16 hours
# 9052R_6_1.png: Predicted PMI = 8.25 hours
# 9052R_6_2.png: Predicted PMI = 14.30 hours
# 9052R_6_3.png: Predicted PMI = 4.15 hours
# 9053L_1_1.png: Predicted PMI = 10.56 hours
# 9053L_1_2.png: Predicted PMI = 15.18 hours
# 9053L_1_3.png: Predicted PMI = 10.20 hours
# 9053L_2_1.png: Predicted PMI = 44.18 hours
# 9053L_2_2.png: Predicted PMI = 49.14 hours
# 9053L_2_3.png: Predicted PMI = 42.69 hours
# 9053L_3_1.png: Predicted PMI = 51.74 hours
# 9053L_3_2.png: Predicted PMI = 27.60 hours
# 9053L_3_3.png: Predicted PMI = 46.30 hours
# 9053R_1_1.png: Predicted PMI = 17.66 hours
# 9053R_1_2.png: Predicted PMI = 17.84 hours
# 9053R_1_3.png: Predicted PMI = 15.35 hours
# 9053R_2_1.png: Predicted PMI = 70.43 hours
# 9053R_2_2.png: Predicted PMI = 71.20 hours
# 9053R_2_3.png: Predicted PMI = 70.77 hours
# 9053R_3_1.png: Predicted PMI = 13.29 hours
# 9053R_3_2.png: Predicted PMI = 18.82 hours
# 9053R_3_3.png: Predicted PMI = 33.84 hours
# 9054L_1_1.png: Predicted PMI = 18.88 hours
# 9054L_1_2.png: Predicted PMI = 3.54 hours
# 9054L_1_3.png: Predicted PMI = 14.53 hours
# 9054L_2_2.png: Predicted PMI = 20.36 hours
# 9054R_1_1.png: Predicted PMI = 16.51 hours
# 9054R_1_2.png: Predicted PMI = 24.50 hours
# 9054R_1_3.png: Predicted PMI = 18.63 hours
# 9054R_2_1.png: Predicted PMI = 13.66 hours
# 9054R_2_3.png: Predicted PMI = 13.72 hours
# 9055L_1_1.png: Predicted PMI = 4.05 hours
# 9055L_1_2.png: Predicted PMI = 10.98 hours
# 9055L_1_3.png: Predicted PMI = 9.70 hours
# 9055L_2_1.png: Predicted PMI = 20.28 hours
# 9055L_2_2.png: Predicted PMI = 30.51 hours
# 9055L_2_3.png: Predicted PMI = 34.03 hours
# 9055R_1_1.png: Predicted PMI = 19.32 hours
# 9055R_1_2.png: Predicted PMI = 4.48 hours
# 9055R_1_3.png: Predicted PMI = 13.28 hours
# 9055R_2_1.png: Predicted PMI = 17.36 hours
# 9055R_2_2.png: Predicted PMI = 14.30 hours
# 9055R_2_3.png: Predicted PMI = 24.33 hours
# 9056L_1_1.png: Predicted PMI = 73.50 hours
# 9056L_1_2.png: Predicted PMI = 55.48 hours
# 9056L_1_3.png: Predicted PMI = 27.11 hours
# 9056L_2_1.png: Predicted PMI = 10.52 hours
# 9056L_2_2.png: Predicted PMI = 6.06 hours
# 9056L_2_3.png: Predicted PMI = 10.79 hours
# 9056L_3_1.png: Predicted PMI = 17.86 hours
# 9056L_3_2.png: Predicted PMI = 16.60 hours
# 9056L_3_3.png: Predicted PMI = 56.01 hours
# 9056R_1_1.png: Predicted PMI = 13.80 hours
# 9056R_1_2.png: Predicted PMI = 16.41 hours
# 9056R_1_3.png: Predicted PMI = 8.70 hours
# 9056R_2_1.png: Predicted PMI = 13.40 hours
# 9056R_2_2.png: Predicted PMI = 9.63 hours
# 9056R_2_3.png: Predicted PMI = 11.12 hours
# 9056R_3_1.png: Predicted PMI = 80.38 hours
# 9056R_3_2.png: Predicted PMI = 150.43 hours
# 9056R_3_3.png: Predicted PMI = 109.86 hours
# 9057L_1_1.png: Predicted PMI = 28.36 hours
# 9057L_1_2.png: Predicted PMI = 14.02 hours
# 9057L_1_3.png: Predicted PMI = 21.54 hours
# 9057L_2_1.png: Predicted PMI = 18.44 hours
# 9057L_2_2.png: Predicted PMI = 8.43 hours
# 9057L_2_3.png: Predicted PMI = 5.57 hours
# 9057L_3_1.png: Predicted PMI = 38.31 hours
# 9057L_3_2.png: Predicted PMI = 17.95 hours
# 9057L_3_3.png: Predicted PMI = 64.86 hours
# 9057R_1_1.png: Predicted PMI = 23.60 hours
# 9057R_1_2.png: Predicted PMI = 14.99 hours
# 9057R_1_3.png: Predicted PMI = 7.48 hours
# 9057R_2_1.png: Predicted PMI = 79.25 hours
# 9057R_2_2.png: Predicted PMI = 203.81 hours
# 9057R_2_3.png: Predicted PMI = 111.73 hours
# 9057R_3_1.png: Predicted PMI = 9.19 hours
# 9057R_3_2.png: Predicted PMI = 10.71 hours
# 9057R_3_3.png: Predicted PMI = 23.34 hours
# 9058L_1_2.png: Predicted PMI = 25.56 hours
# 9058R_1_1.png: Predicted PMI = 72.65 hours
# 9058R_1_2.png: Predicted PMI = 43.93 hours
# 9058R_1_3.png: Predicted PMI = 37.66 hours
# 9059L_1_1.png: Predicted PMI = 23.52 hours
# 9059L_1_2.png: Predicted PMI = 113.39 hours
# 9059L_1_3.png: Predicted PMI = 32.59 hours
# 9059L_2_1.png: Predicted PMI = 7.25 hours
# 9059L_2_2.png: Predicted PMI = 4.89 hours
# 9059L_2_3.png: Predicted PMI = 15.85 hours
# 9059R_1_1.png: Predicted PMI = 69.64 hours
# 9059R_1_2.png: Predicted PMI = 111.93 hours
# 9059R_1_3.png: Predicted PMI = 37.15 hours
# 9059R_2_1.png: Predicted PMI = 18.18 hours
# 9059R_2_2.png: Predicted PMI = 58.79 hours
# 9059R_2_3.png: Predicted PMI = 52.17 hours
# 9060L_1_1.png: Predicted PMI = 37.95 hours
# 9060L_1_2.png: Predicted PMI = 8.99 hours
# 9060L_1_3.png: Predicted PMI = 30.42 hours
# 9060L_2_1.png: Predicted PMI = 8.04 hours
# 9060L_2_2.png: Predicted PMI = 13.47 hours
# 9060L_2_3.png: Predicted PMI = 20.24 hours
# 9060L_3_2.png: Predicted PMI = 94.27 hours
# 9060R_1_1.png: Predicted PMI = 22.41 hours
# 9060R_1_2.png: Predicted PMI = 17.00 hours
# 9060R_1_3.png: Predicted PMI = 15.28 hours
# 9060R_2_1.png: Predicted PMI = 18.48 hours
# 9060R_2_2.png: Predicted PMI = 6.83 hours
# 9060R_2_3.png: Predicted PMI = 18.40 hours
# 9060R_3_1.png: Predicted PMI = 20.28 hours
# 9060R_3_2.png: Predicted PMI = 38.42 hours
# 9060R_3_3.png: Predicted PMI = 76.57 hours
# 9061L_1_1.png: Predicted PMI = 23.82 hours
# 9061L_1_2.png: Predicted PMI = 25.01 hours
# 9061L_1_3.png: Predicted PMI = 58.46 hours
# 9061L_2_1.png: Predicted PMI = 24.03 hours
# 9061L_2_2.png: Predicted PMI = 38.70 hours
# 9061L_2_3.png: Predicted PMI = 130.69 hours
# 9061R_1_1.png: Predicted PMI = 89.12 hours
# 9061R_1_2.png: Predicted PMI = 64.20 hours
# 9061R_1_3.png: Predicted PMI = 45.07 hours
# 9061R_2_2.png: Predicted PMI = 29.94 hours
# 9062L_1_2.png: Predicted PMI = 113.40 hours
# 9062L_2_1.png: Predicted PMI = 357.54 hours
# 9062L_2_2.png: Predicted PMI = 37.06 hours
# 9062L_2_3.png: Predicted PMI = 53.46 hours
# 9062R_1_2.png: Predicted PMI = 24.74 hours
# 9062R_1_3.png: Predicted PMI = 11.90 hours
# 9062R_2_1.png: Predicted PMI = 54.20 hours
# 9062R_2_2.png: Predicted PMI = 80.33 hours
# 9062R_2_3.png: Predicted PMI = 71.55 hours
# 9063L_1_1.png: Predicted PMI = 24.70 hours
# 9063L_1_2.png: Predicted PMI = 19.20 hours
# 9063L_1_3.png: Predicted PMI = 6.89 hours
# 9063L_2_1.png: Predicted PMI = 24.49 hours
# 9063L_2_2.png: Predicted PMI = 82.17 hours
# 9063L_2_3.png: Predicted PMI = 33.90 hours
# 9063L_3_1.png: Predicted PMI = 29.23 hours
# 9063L_3_2.png: Predicted PMI = 51.26 hours
# 9063L_3_3.png: Predicted PMI = 55.21 hours
# 9063R_1_1.png: Predicted PMI = 9.17 hours
# 9063R_1_2.png: Predicted PMI = 1.89 hours
# 9063R_1_3.png: Predicted PMI = 2.58 hours
# 9063R_2_1.png: Predicted PMI = 104.82 hours
# 9063R_2_2.png: Predicted PMI = 77.07 hours
# 9063R_2_3.png: Predicted PMI = 30.39 hours
# 9063R_3_1.png: Predicted PMI = 34.93 hours
# 9063R_3_2.png: Predicted PMI = 31.36 hours
# 9063R_3_3.png: Predicted PMI = 33.12 hours
# 9064L_1_1.png: Predicted PMI = 9.80 hours
# 9064L_1_2.png: Predicted PMI = 3.42 hours
# 9064L_1_3.png: Predicted PMI = 5.97 hours
# 9064L_2_1.png: Predicted PMI = 34.12 hours
# 9064L_2_2.png: Predicted PMI = 161.84 hours
# 9064L_2_3.png: Predicted PMI = 38.57 hours
# 9064R_1_1.png: Predicted PMI = 18.50 hours
# 9064R_1_2.png: Predicted PMI = 27.45 hours
# 9064R_1_3.png: Predicted PMI = 12.18 hours
# 9064R_2_1.png: Predicted PMI = 231.89 hours
# 9064R_2_2.png: Predicted PMI = 123.35 hours
# 9064R_2_3.png: Predicted PMI = 180.51 hours
# 9065L_1_1.png: Predicted PMI = 37.93 hours
# 9065L_1_2.png: Predicted PMI = 26.94 hours
# 9065L_1_3.png: Predicted PMI = 18.13 hours
# 9065L_2_1.png: Predicted PMI = 100.93 hours
# 9065L_2_2.png: Predicted PMI = 88.88 hours
# 9065L_2_3.png: Predicted PMI = 106.82 hours
# 9065R_1_1.png: Predicted PMI = 4.94 hours
# 9065R_1_2.png: Predicted PMI = 28.65 hours
# 9065R_1_3.png: Predicted PMI = 20.13 hours
# 9065R_2_1.png: Predicted PMI = 18.22 hours
# 9065R_2_2.png: Predicted PMI = 148.99 hours
# 9065R_2_3.png: Predicted PMI = 114.61 hours
# 9066L_1_1.png: Predicted PMI = 22.38 hours
# 9066L_1_2.png: Predicted PMI = 38.08 hours
# 9066L_1_3.png: Predicted PMI = 14.91 hours
# 9066L_2_1.png: Predicted PMI = 124.86 hours
# 9066L_2_2.png: Predicted PMI = 46.10 hours
# 9066L_2_3.png: Predicted PMI = 84.86 hours
# 9066R_1_1.png: Predicted PMI = 39.39 hours
# 9066R_1_2.png: Predicted PMI = 36.51 hours
# 9066R_1_3.png: Predicted PMI = 21.03 hours
# 9066R_2_1.png: Predicted PMI = 12.70 hours
# 9066R_2_2.png: Predicted PMI = 34.08 hours
# 9066R_2_3.png: Predicted PMI = 49.88 hours
# 9067L_1_1.png: Predicted PMI = 67.89 hours
# 9067L_1_2.png: Predicted PMI = 61.29 hours
# 9067L_1_3.png: Predicted PMI = 12.37 hours
# 9067R_1_1.png: Predicted PMI = 33.81 hours
# 9067R_1_2.png: Predicted PMI = 52.07 hours
# 9067R_1_3.png: Predicted PMI = 5.47 hours
# 9068L_1_1.png: Predicted PMI = 48.68 hours
# 9068L_1_2.png: Predicted PMI = 30.29 hours
# 9068L_1_3.png: Predicted PMI = 139.29 hours
# 9068L_2_1.png: Predicted PMI = 22.29 hours
# 9068L_2_2.png: Predicted PMI = 17.25 hours
# 9068L_2_3.png: Predicted PMI = 11.98 hours
# 9068R_1_1.png: Predicted PMI = 46.39 hours
# 9068R_1_2.png: Predicted PMI = 45.44 hours
# 9068R_1_3.png: Predicted PMI = 48.37 hours
# 9068R_2_1.png: Predicted PMI = 105.40 hours
# 9068R_2_2.png: Predicted PMI = 167.02 hours
# 9068R_2_3.png: Predicted PMI = 164.85 hours
# 9069L_1_1.png: Predicted PMI = 1.82 hours
# 9069L_1_2.png: Predicted PMI = 28.91 hours
# 9069L_1_3.png: Predicted PMI = 19.90 hours
# 9069L_2_1.png: Predicted PMI = 7.15 hours
# 9069L_2_2.png: Predicted PMI = 17.55 hours
# 9069L_2_3.png: Predicted PMI = 17.57 hours
# 9069R_1_1.png: Predicted PMI = 29.50 hours
# 9069R_1_2.png: Predicted PMI = 22.85 hours
# 9069R_1_3.png: Predicted PMI = 127.22 hours
# 9069R_2_1.png: Predicted PMI = 60.11 hours
# 9069R_2_2.png: Predicted PMI = 65.16 hours
# 9069R_2_3.png: Predicted PMI = 83.87 hours
# 9070L_1_1.png: Predicted PMI = 27.23 hours
# 9070L_1_2.png: Predicted PMI = 34.17 hours
# 9070L_1_3.png: Predicted PMI = 21.88 hours
# 9070R_1_1.png: Predicted PMI = 20.98 hours
# 9070R_1_2.png: Predicted PMI = 16.07 hours
# 9070R_1_3.png: Predicted PMI = 26.93 hours
# 9071L_1_1.png: Predicted PMI = 65.44 hours
# 9071L_2_1.png: Predicted PMI = 97.66 hours
# 9071L_2_2.png: Predicted PMI = 93.75 hours
# 9071R_1_1.png: Predicted PMI = 19.02 hours
# 9071R_1_2.png: Predicted PMI = 1.60 hours
# 9071R_1_3.png: Predicted PMI = 22.29 hours
# 9071R_2_1.png: Predicted PMI = 105.34 hours
# 9072L_1_1.png: Predicted PMI = 58.87 hours
# 9072L_1_2.png: Predicted PMI = 94.59 hours
# 9072L_1_3.png: Predicted PMI = 29.31 hours
# 9072R_1_1.png: Predicted PMI = 40.33 hours
# 9072R_1_2.png: Predicted PMI = 63.19 hours
# 9072R_1_3.png: Predicted PMI = 131.00 hours
# 9073L_1_1.png: Predicted PMI = 44.81 hours
# 9073L_1_2.png: Predicted PMI = 60.46 hours
# 9073L_1_3.png: Predicted PMI = 9.78 hours
# 9073L_2_1.png: Predicted PMI = 85.40 hours
# 9073L_2_2.png: Predicted PMI = 10.48 hours
# 9073L_2_3.png: Predicted PMI = 67.69 hours
# 9073R_1_1.png: Predicted PMI = 2.27 hours
# 9073R_1_2.png: Predicted PMI = 100.04 hours
# 9073R_1_3.png: Predicted PMI = 27.54 hours
# 9073R_2_1.png: Predicted PMI = 169.31 hours
# 9073R_2_2.png: Predicted PMI = 136.27 hours
# 9073R_2_3.png: Predicted PMI = 56.42 hours
# 9074L_1_1.png: Predicted PMI = 102.56 hours
# 9074L_1_2.png: Predicted PMI = 29.54 hours
# 9074L_1_3.png: Predicted PMI = 22.72 hours
# 9074R_1_1.png: Predicted PMI = 121.70 hours
# 9074R_1_2.png: Predicted PMI = 129.86 hours
# 9074R_1_3.png: Predicted PMI = 53.34 hours
# 9075L_1_1.png: Predicted PMI = 24.78 hours
# 9075L_1_2.png: Predicted PMI = 18.66 hours
# 9075L_1_3.png: Predicted PMI = 26.17 hours
# 9075R_1_1.png: Predicted PMI = 30.39 hours
# 9075R_1_2.png: Predicted PMI = 27.25 hours
# 9075R_1_3.png: Predicted PMI = 28.73 hours
# 9076L_1_1.png: Predicted PMI = 43.20 hours
# 9076L_1_2.png: Predicted PMI = 101.91 hours
# 9076L_1_3.png: Predicted PMI = 29.79 hours
# 9076R_1_1.png: Predicted PMI = 79.21 hours
# 9076R_1_2.png: Predicted PMI = 104.76 hours
# 9076R_1_3.png: Predicted PMI = 164.72 hours
# 9078L_1_1.png: Predicted PMI = 104.36 hours
# 9078L_1_2.png: Predicted PMI = 8.16 hours
# 9078L_1_3.png: Predicted PMI = 55.37 hours
# 9078L_2_1.png: Predicted PMI = 49.32 hours
# 9078L_2_2.png: Predicted PMI = 81.66 hours
# 9078L_2_3.png: Predicted PMI = 46.62 hours
# 9078R_1_1.png: Predicted PMI = 9.23 hours
# 9078R_1_2.png: Predicted PMI = 15.56 hours
# 9078R_1_3.png: Predicted PMI = 7.28 hours
# 9078R_2_1.png: Predicted PMI = 167.41 hours
# 9078R_2_2.png: Predicted PMI = 197.61 hours
# 9078R_2_3.png: Predicted PMI = 121.49 hours
# 9079L_1_1.png: Predicted PMI = 25.58 hours
# 9079L_1_2.png: Predicted PMI = 10.50 hours
# 9079L_1_3.png: Predicted PMI = 7.91 hours
# 9079L_2_1.png: Predicted PMI = 35.42 hours
# 9079L_2_2.png: Predicted PMI = 44.69 hours
# 9079L_2_3.png: Predicted PMI = 56.88 hours
# 9079L_3_1.png: Predicted PMI = 87.55 hours
# 9079L_3_2.png: Predicted PMI = 121.66 hours
# 9079L_3_3.png: Predicted PMI = 97.21 hours
# 9079R_1_1.png: Predicted PMI = 9.94 hours
# 9079R_1_2.png: Predicted PMI = 12.50 hours
# 9079R_1_3.png: Predicted PMI = 11.58 hours
# 9079R_2_1.png: Predicted PMI = 35.31 hours
# 9079R_2_2.png: Predicted PMI = 34.79 hours
# 9079R_2_3.png: Predicted PMI = 32.04 hours
# 9079R_3_1.png: Predicted PMI = 143.26 hours
# 9079R_3_2.png: Predicted PMI = 96.28 hours
# 9080L_10_1.png: Predicted PMI = 151.26 hours
# 9080L_10_2.png: Predicted PMI = 280.47 hours
# 9080L_1_1.png: Predicted PMI = 4.17 hours
# 9080L_1_2.png: Predicted PMI = 5.52 hours
# 9080L_1_3.png: Predicted PMI = 13.96 hours
# 9080L_2_1.png: Predicted PMI = 18.59 hours
# 9080L_2_2.png: Predicted PMI = 51.03 hours
# 9080L_2_3.png: Predicted PMI = 54.83 hours
# 9080L_3_1.png: Predicted PMI = 39.66 hours
# 9080L_3_2.png: Predicted PMI = 69.12 hours
# 9080L_3_3.png: Predicted PMI = 49.09 hours
# 9080L_4_1.png: Predicted PMI = 216.35 hours
# 9080L_4_2.png: Predicted PMI = 50.32 hours
# 9080L_4_3.png: Predicted PMI = 165.62 hours
# 9080L_5_1.png: Predicted PMI = 90.08 hours
# 9080L_5_2.png: Predicted PMI = 89.74 hours
# 9080L_5_3.png: Predicted PMI = 54.68 hours
# 9080L_7_2.png: Predicted PMI = 73.49 hours
# 9080L_8_1.png: Predicted PMI = 167.32 hours
# 9080L_8_2.png: Predicted PMI = 238.64 hours
# 9080L_8_3.png: Predicted PMI = 172.94 hours
# 9080L_9_1.png: Predicted PMI = 85.56 hours
# 9080L_9_2.png: Predicted PMI = 131.47 hours
# 9080L_9_3.png: Predicted PMI = 44.53 hours
# 9080R_10_1.png: Predicted PMI = 39.61 hours
# 9080R_10_2.png: Predicted PMI = 81.19 hours
# 9080R_10_3.png: Predicted PMI = 100.62 hours
# 9080R_1_1.png: Predicted PMI = 125.92 hours
# 9080R_1_2.png: Predicted PMI = 13.41 hours
# 9080R_1_3.png: Predicted PMI = 83.33 hours
# 9080R_2_1.png: Predicted PMI = 71.95 hours
# 9080R_2_2.png: Predicted PMI = 88.81 hours
# 9080R_2_3.png: Predicted PMI = 53.34 hours
# 9080R_3_1.png: Predicted PMI = 83.56 hours
# 9080R_3_2.png: Predicted PMI = 76.43 hours
# 9080R_3_3.png: Predicted PMI = 53.84 hours
# 9080R_4_1.png: Predicted PMI = 28.45 hours
# 9080R_4_2.png: Predicted PMI = 22.86 hours
# 9080R_4_3.png: Predicted PMI = 23.63 hours
# 9080R_5_1.png: Predicted PMI = 69.38 hours
# 9080R_5_2.png: Predicted PMI = 38.08 hours
# 9080R_5_3.png: Predicted PMI = 155.89 hours
# 9080R_6_1.png: Predicted PMI = 42.40 hours
# 9080R_6_3.png: Predicted PMI = 213.39 hours
# 9080R_7_1.png: Predicted PMI = 59.69 hours
# 9080R_7_2.png: Predicted PMI = 46.11 hours
# 9080R_7_3.png: Predicted PMI = 30.64 hours
# 9080R_8_1.png: Predicted PMI = 133.25 hours
# 9080R_8_2.png: Predicted PMI = 35.39 hours
# 9080R_8_3.png: Predicted PMI = 107.04 hours
# 9080R_9_1.png: Predicted PMI = 63.62 hours
# 9080R_9_2.png: Predicted PMI = 63.17 hours
# 9080R_9_3.png: Predicted PMI = 43.38 hours
# 9081L_1_1.png: Predicted PMI = 55.55 hours
# 9081L_1_2.png: Predicted PMI = 66.70 hours
# 9081L_1_3.png: Predicted PMI = 118.33 hours
# 9081R_1_1.png: Predicted PMI = 40.98 hours
# 9081R_1_2.png: Predicted PMI = 127.85 hours
# 9081R_1_3.png: Predicted PMI = 33.04 hours
# 9082L_1_1.png: Predicted PMI = 30.65 hours
# 9082L_1_2.png: Predicted PMI = 42.48 hours
# 9082L_1_3.png: Predicted PMI = 81.38 hours
# 9082L_2_1.png: Predicted PMI = 69.99 hours
# 9082L_2_2.png: Predicted PMI = 19.34 hours
# 9082L_2_3.png: Predicted PMI = 51.07 hours
# 9082R_1_1.png: Predicted PMI = 11.65 hours
# 9082R_1_2.png: Predicted PMI = 28.89 hours
# 9082R_1_3.png: Predicted PMI = 26.32 hours
# 9082R_2_1.png: Predicted PMI = 1.24 hours
# 9082R_2_2.png: Predicted PMI = 77.96 hours
# 9082R_2_3.png: Predicted PMI = 4.83 hours
# 9083L_10_1.png: Predicted PMI = 159.12 hours
# 9083L_10_2.png: Predicted PMI = 9.14 hours
# 9083L_10_3.png: Predicted PMI = 55.64 hours
# 9083L_11_1.png: Predicted PMI = 25.05 hours
# 9083L_11_2.png: Predicted PMI = 26.10 hours
# 9083L_11_3.png: Predicted PMI = 67.68 hours
# 9083L_12_1.png: Predicted PMI = 103.82 hours
# 9083L_12_2.png: Predicted PMI = 64.41 hours
# 9083L_12_3.png: Predicted PMI = 169.79 hours
# 9083L_13_1.png: Predicted PMI = 100.79 hours
# 9083L_13_2.png: Predicted PMI = 49.84 hours
# 9083L_13_3.png: Predicted PMI = 45.22 hours
# 9083L_14_1.png: Predicted PMI = 102.44 hours
# 9083L_14_2.png: Predicted PMI = 26.00 hours
# 9083L_14_3.png: Predicted PMI = 68.07 hours
# 9083L_15_1.png: Predicted PMI = 38.73 hours
# 9083L_15_2.png: Predicted PMI = 79.09 hours
# 9083L_15_3.png: Predicted PMI = 54.37 hours
# 9083L_16_1.png: Predicted PMI = 27.65 hours
# 9083L_16_2.png: Predicted PMI = 66.15 hours
# 9083L_16_3.png: Predicted PMI = 56.28 hours
# 9083L_1_1.png: Predicted PMI = 15.36 hours
# 9083L_1_2.png: Predicted PMI = 4.99 hours
# 9083L_1_3.png: Predicted PMI = 4.68 hours
# 9083L_2_1.png: Predicted PMI = 57.91 hours
# 9083L_2_2.png: Predicted PMI = 94.43 hours
# 9083L_2_3.png: Predicted PMI = 42.99 hours
# 9083L_3_1.png: Predicted PMI = 4.74 hours
# 9083L_3_2.png: Predicted PMI = 26.74 hours
# 9083L_3_3.png: Predicted PMI = 66.84 hours
# 9083L_4_1.png: Predicted PMI = 130.30 hours
# 9083L_4_2.png: Predicted PMI = 87.35 hours
# 9083L_4_3.png: Predicted PMI = 78.92 hours
# 9083L_5_1.png: Predicted PMI = 175.87 hours
# 9083L_5_2.png: Predicted PMI = 141.17 hours
# 9083L_5_3.png: Predicted PMI = 141.10 hours
# 9083L_6_1.png: Predicted PMI = 24.16 hours
# 9083L_6_2.png: Predicted PMI = 28.04 hours
# 9083L_6_3.png: Predicted PMI = 44.56 hours
# 9083L_7_1.png: Predicted PMI = 156.36 hours
# 9083L_7_2.png: Predicted PMI = 107.96 hours
# 9083L_7_3.png: Predicted PMI = 93.05 hours
# 9083L_8_1.png: Predicted PMI = 145.88 hours
# 9083L_8_2.png: Predicted PMI = 44.15 hours
# 9083L_8_3.png: Predicted PMI = 66.71 hours
# 9083L_9_1.png: Predicted PMI = 41.50 hours
# 9083L_9_2.png: Predicted PMI = 167.21 hours
# 9083L_9_3.png: Predicted PMI = 176.84 hours
# 9083R_10_1.png: Predicted PMI = 68.36 hours
# 9083R_10_2.png: Predicted PMI = 112.17 hours
# 9083R_10_3.png: Predicted PMI = 76.08 hours
# 9083R_11_1.png: Predicted PMI = 80.01 hours
# 9083R_11_2.png: Predicted PMI = 159.85 hours
# 9083R_11_3.png: Predicted PMI = 141.93 hours
# 9083R_12_1.png: Predicted PMI = 138.14 hours
# 9083R_12_2.png: Predicted PMI = 124.51 hours
# 9083R_12_3.png: Predicted PMI = 78.10 hours
# 9083R_13_1.png: Predicted PMI = 148.16 hours
# 9083R_13_2.png: Predicted PMI = 77.76 hours
# 9083R_13_3.png: Predicted PMI = 63.35 hours
# 9083R_14_1.png: Predicted PMI = 73.13 hours
# 9083R_14_2.png: Predicted PMI = 79.95 hours
# 9083R_14_3.png: Predicted PMI = 95.60 hours
# 9083R_15_1.png: Predicted PMI = 82.10 hours
# 9083R_15_2.png: Predicted PMI = 32.97 hours
# 9083R_15_3.png: Predicted PMI = 66.27 hours
# 9083R_16_1.png: Predicted PMI = 159.58 hours
# 9083R_16_2.png: Predicted PMI = 160.98 hours
# 9083R_16_3.png: Predicted PMI = 220.34 hours
# 9083R_1_1.png: Predicted PMI = 21.85 hours
# 9083R_1_2.png: Predicted PMI = 62.93 hours
# 9083R_1_3.png: Predicted PMI = 5.41 hours
# 9083R_2_1.png: Predicted PMI = 8.22 hours
# 9083R_2_2.png: Predicted PMI = 11.88 hours
# 9083R_2_3.png: Predicted PMI = 15.12 hours
# 9083R_3_1.png: Predicted PMI = 6.42 hours
# 9083R_3_2.png: Predicted PMI = 76.07 hours
# 9083R_3_3.png: Predicted PMI = 85.47 hours
# 9083R_4_1.png: Predicted PMI = 205.76 hours
# 9083R_4_2.png: Predicted PMI = 99.93 hours
# 9083R_4_3.png: Predicted PMI = 39.64 hours
# 9083R_5_1.png: Predicted PMI = 62.49 hours
# 9083R_5_2.png: Predicted PMI = 22.09 hours
# 9083R_5_3.png: Predicted PMI = 68.13 hours
# 9083R_6_1.png: Predicted PMI = 16.45 hours
# 9083R_6_2.png: Predicted PMI = 42.09 hours
# 9083R_6_3.png: Predicted PMI = 78.51 hours
# 9083R_7_1.png: Predicted PMI = 113.00 hours
# 9083R_7_2.png: Predicted PMI = 69.58 hours
# 9083R_7_3.png: Predicted PMI = 47.09 hours
# 9083R_8_1.png: Predicted PMI = 55.97 hours
# 9083R_8_2.png: Predicted PMI = 108.33 hours
# 9083R_8_3.png: Predicted PMI = 95.42 hours
# 9083R_9_1.png: Predicted PMI = 161.49 hours
# 9083R_9_2.png: Predicted PMI = 63.63 hours
# 9083R_9_3.png: Predicted PMI = 202.82 hours
# 9084L_1_1.png: Predicted PMI = 45.25 hours
# 9084L_1_2.png: Predicted PMI = 48.83 hours
# 9084L_1_3.png: Predicted PMI = 7.43 hours
# 9084R_1_1.png: Predicted PMI = 4.84 hours
# 9084R_1_2.png: Predicted PMI = 23.00 hours
# 9084R_1_3.png: Predicted PMI = 28.82 hours
# 9085L_1_1.png: Predicted PMI = 8.56 hours
# 9085L_1_2.png: Predicted PMI = 7.73 hours
# 9085L_1_3.png: Predicted PMI = 30.14 hours
# 9085L_2_1.png: Predicted PMI = 28.88 hours
# 9085L_2_2.png: Predicted PMI = 16.83 hours
# 9085L_2_3.png: Predicted PMI = 8.07 hours
# 9085L_3_1.png: Predicted PMI = 13.45 hours
# 9085L_3_2.png: Predicted PMI = 16.88 hours
# 9085L_3_3.png: Predicted PMI = 36.14 hours
# 9085R_1_1.png: Predicted PMI = 18.26 hours
# 9085R_1_2.png: Predicted PMI = 3.47 hours
# 9085R_1_3.png: Predicted PMI = 248.20 hours
# 9085R_2_1.png: Predicted PMI = 17.72 hours
# 9085R_2_2.png: Predicted PMI = 15.32 hours
# 9085R_2_3.png: Predicted PMI = 48.75 hours
# 9085R_3_1.png: Predicted PMI = 28.21 hours
# 9085R_3_2.png: Predicted PMI = 24.12 hours
# 9085R_3_3.png: Predicted PMI = 25.16 hours
# 9086L_1_1.png: Predicted PMI = 28.91 hours
# 9086L_1_2.png: Predicted PMI = 10.99 hours
# 9086L_1_3.png: Predicted PMI = 27.58 hours
# 9086L_2_1.png: Predicted PMI = 9.78 hours
# 9086L_2_2.png: Predicted PMI = 3.43 hours
# 9086L_2_3.png: Predicted PMI = 1.79 hours
# 9086R_1_1.png: Predicted PMI = 2.13 hours
# 9086R_1_2.png: Predicted PMI = 2.95 hours
# 9086R_1_3.png: Predicted PMI = 2.73 hours
# 9086R_2_1.png: Predicted PMI = 28.14 hours
# 9086R_2_2.png: Predicted PMI = 26.42 hours
# 9086R_2_3.png: Predicted PMI = 5.96 hours
# 9087L_1_1.png: Predicted PMI = 0.81 hours
# 9087L_1_2.png: Predicted PMI = 0.63 hours
# 9087L_1_3.png: Predicted PMI = 0.43 hours
# 9087L_2_1.png: Predicted PMI = 11.16 hours
# 9087L_2_2.png: Predicted PMI = 4.27 hours
# 9087L_2_3.png: Predicted PMI = 14.19 hours
# 9087R_1_1.png: Predicted PMI = 38.78 hours
# 9087R_1_2.png: Predicted PMI = 42.29 hours
# 9087R_1_3.png: Predicted PMI = 12.57 hours
# 9087R_2_1.png: Predicted PMI = 3.50 hours
# 9087R_2_2.png: Predicted PMI = 44.85 hours
# 9087R_2_3.png: Predicted PMI = 16.53 hours
# 9088L_1_1.png: Predicted PMI = 17.04 hours
# 9088L_1_2.png: Predicted PMI = 16.97 hours
# 9088L_1_3.png: Predicted PMI = 4.42 hours
# 9088L_2_1.png: Predicted PMI = 6.28 hours
# 9088L_2_2.png: Predicted PMI = 11.08 hours
# 9088L_3_1.png: Predicted PMI = 114.87 hours
# 9088L_3_2.png: Predicted PMI = 82.12 hours
# 9088L_3_3.png: Predicted PMI = 14.91 hours
# 9088R_1_1.png: Predicted PMI = 9.67 hours
# 9088R_1_2.png: Predicted PMI = 14.59 hours
# 9088R_1_3.png: Predicted PMI = 13.55 hours
# 9088R_2_3.png: Predicted PMI = 6.04 hours
# 9088R_3_1.png: Predicted PMI = 362.93 hours
# 9088R_3_2.png: Predicted PMI = 266.64 hours
# 9088R_3_3.png: Predicted PMI = 258.05 hours
# 9089L_1_1.png: Predicted PMI = 46.02 hours
# 9089L_1_2.png: Predicted PMI = 7.56 hours
# 9089L_1_3.png: Predicted PMI = 24.06 hours
# 9089R_1_1.png: Predicted PMI = 35.50 hours
# 9089R_1_2.png: Predicted PMI = 27.44 hours
# 9089R_1_3.png: Predicted PMI = 38.27 hours
# 9090L_1_1.png: Predicted PMI = 84.40 hours
# 9090L_1_2.png: Predicted PMI = 8.77 hours
# 9090L_1_3.png: Predicted PMI = 56.68 hours
# 9090L_2_1.png: Predicted PMI = 33.19 hours
# 9090L_2_2.png: Predicted PMI = 44.23 hours
# 9090L_2_3.png: Predicted PMI = 45.42 hours
# 9090L_3_1.png: Predicted PMI = 50.16 hours
# 9090L_3_2.png: Predicted PMI = 58.27 hours
# 9090L_3_3.png: Predicted PMI = 64.41 hours
# 9090L_4_1.png: Predicted PMI = 101.26 hours
# 9090L_4_2.png: Predicted PMI = 48.85 hours
# 9090L_4_4.png: Predicted PMI = 9.66 hours
# 9090L_5_1.png: Predicted PMI = 103.55 hours
# 9090L_5_2.png: Predicted PMI = 124.77 hours
# 9090L_5_3.png: Predicted PMI = 182.99 hours
# 9090R_1_1.png: Predicted PMI = 18.43 hours
# 9090R_1_2.png: Predicted PMI = 2.51 hours
# 9090R_1_3.png: Predicted PMI = 1.91 hours
# 9090R_2_1.png: Predicted PMI = 23.22 hours
# 9090R_2_2.png: Predicted PMI = 1.93 hours
# 9090R_2_3.png: Predicted PMI = 8.00 hours
# 9090R_3_1.png: Predicted PMI = 33.17 hours
# 9090R_3_2.png: Predicted PMI = 28.43 hours
# 9090R_3_3.png: Predicted PMI = 30.70 hours
# 9090R_4_1.png: Predicted PMI = 80.71 hours
# 9090R_4_2.png: Predicted PMI = 101.03 hours
# 9090R_4_3.png: Predicted PMI = 92.86 hours
# 9090R_5_1.png: Predicted PMI = 95.46 hours
# 9090R_5_2.png: Predicted PMI = 75.85 hours
# 9090R_5_3.png: Predicted PMI = 81.37 hours
# 9091L_1_1.png: Predicted PMI = 0.81 hours
# 9091L_1_2.png: Predicted PMI = 7.86 hours
# 9091L_1_3.png: Predicted PMI = 55.92 hours
# 9091L_2_1.png: Predicted PMI = 18.93 hours
# 9091L_2_2.png: Predicted PMI = 8.26 hours
# 9091L_2_3.png: Predicted PMI = 20.45 hours
# 9091L_4_2.png: Predicted PMI = 70.35 hours
# 9091R_1_1.png: Predicted PMI = 63.13 hours
# 9091R_1_2.png: Predicted PMI = 33.15 hours
# 9091R_1_3.png: Predicted PMI = 32.00 hours
# 9091R_2_1.png: Predicted PMI = 143.64 hours
# 9091R_2_2.png: Predicted PMI = 145.27 hours
# 9091R_2_3.png: Predicted PMI = 67.11 hours
# 9091R_3_1.png: Predicted PMI = 119.76 hours
# 9091R_3_2.png: Predicted PMI = 150.26 hours
# 9091R_3_3.png: Predicted PMI = 229.14 hours
# 9091R_4_1.png: Predicted PMI = 261.42 hours
# 9091R_4_2.png: Predicted PMI = 182.92 hours
# 9091R_4_3.png: Predicted PMI = 111.87 hours
# 9092L_1_1.png: Predicted PMI = 18.78 hours
# 9092L_1_2.png: Predicted PMI = 2.33 hours
# 9092L_1_3.png: Predicted PMI = 6.53 hours
# 9092L_2_1.png: Predicted PMI = 7.59 hours
# 9092L_2_2.png: Predicted PMI = 27.14 hours
# 9092L_2_3.png: Predicted PMI = 72.37 hours
# 9092L_3_1.png: Predicted PMI = 45.37 hours
# 9092L_3_2.png: Predicted PMI = 36.34 hours
# 9092L_3_3.png: Predicted PMI = 155.33 hours
# 9092L_5_1.png: Predicted PMI = 119.89 hours
# 9092L_5_2.png: Predicted PMI = 42.18 hours
# 9092L_5_3.png: Predicted PMI = 34.62 hours
# 9092L_6_1.png: Predicted PMI = 77.27 hours
# 9092L_6_2.png: Predicted PMI = 138.63 hours
# 9092R_1_1.png: Predicted PMI = 6.38 hours
# 9092R_1_2.png: Predicted PMI = 101.08 hours
# 9092R_1_3.png: Predicted PMI = 10.68 hours
# 9092R_3_1.png: Predicted PMI = 129.52 hours
# 9092R_3_2.png: Predicted PMI = 120.91 hours
# 9092R_3_3.png: Predicted PMI = 120.18 hours
# 9092R_4_1.png: Predicted PMI = 44.62 hours
# 9092R_4_2.png: Predicted PMI = 7.91 hours
# 9092R_4_3.png: Predicted PMI = 99.33 hours
# 9092R_5_1.png: Predicted PMI = 33.45 hours
# 9092R_5_2.png: Predicted PMI = 45.18 hours
# 9092R_5_3.png: Predicted PMI = 40.33 hours
# 9092R_6_1.png: Predicted PMI = 51.61 hours
# 9092R_6_2.png: Predicted PMI = 40.15 hours
# 9092R_6_3.png: Predicted PMI = 82.74 hours
# 9093L_1_1.png: Predicted PMI = 18.36 hours
# 9093L_1_2.png: Predicted PMI = 17.41 hours
# 9093L_1_3.png: Predicted PMI = 14.38 hours
# 9093L_2_1.png: Predicted PMI = 127.31 hours
# 9093L_2_2.png: Predicted PMI = 63.76 hours
# 9093L_2_3.png: Predicted PMI = 59.05 hours
# 9093L_2_4.png: Predicted PMI = 136.48 hours
# 9093L_2_5.png: Predicted PMI = 146.56 hours
# 9093L_2_6.png: Predicted PMI = 193.44 hours
# 9093R_1_1.png: Predicted PMI = 6.56 hours
# 9093R_1_2.png: Predicted PMI = 21.00 hours
# 9093R_1_3.png: Predicted PMI = 6.49 hours
# 9093R_2_1.png: Predicted PMI = 67.11 hours
# 9093R_2_2.png: Predicted PMI = 36.76 hours
# 9093R_2_3.png: Predicted PMI = 78.02 hours
# 9093R_3_1.png: Predicted PMI = 81.82 hours
# 9093R_3_2.png: Predicted PMI = 58.91 hours
# 9093R_3_3.png: Predicted PMI = 91.74 hours
# 9094L_1_1.png: Predicted PMI = 65.50 hours
# 9094L_1_2.png: Predicted PMI = 13.72 hours
# 9094L_1_3.png: Predicted PMI = 121.45 hours
# 9094R_1_1.png: Predicted PMI = 5.35 hours
# 9094R_1_2.png: Predicted PMI = 28.33 hours
# 9094R_1_3.png: Predicted PMI = 12.76 hours
# 9095L_1_1.png: Predicted PMI = 17.45 hours
# 9095L_1_2.png: Predicted PMI = 10.98 hours
# 9095L_1_3.png: Predicted PMI = 14.10 hours
# 9095R_1_1.png: Predicted PMI = 8.86 hours
# 9095R_1_2.png: Predicted PMI = 11.78 hours
# 9095R_1_3.png: Predicted PMI = 15.20 hours
# 9096L_1_1.png: Predicted PMI = 197.42 hours
# 9096L_1_2.png: Predicted PMI = 157.39 hours
# 9096L_1_3.png: Predicted PMI = 85.57 hours
# 9096R_1_1.png: Predicted PMI = 29.70 hours
# 9096R_1_2.png: Predicted PMI = 13.10 hours
# 9096R_1_3.png: Predicted PMI = 33.52 hours
# 9096R_2_1.png: Predicted PMI = 149.74 hours
# 9096R_2_2.png: Predicted PMI = 178.02 hours
# 9096R_2_3.png: Predicted PMI = 88.71 hours
# 9097L_1_1.png: Predicted PMI = 16.87 hours
# 9097L_1_2.png: Predicted PMI = 21.02 hours
# 9097L_1_3.png: Predicted PMI = 17.06 hours
# 9097L_2_1.png: Predicted PMI = 48.43 hours
# 9097L_2_2.png: Predicted PMI = 11.92 hours
# 9097L_2_3.png: Predicted PMI = 23.50 hours
# 9097L_3_1.png: Predicted PMI = 133.54 hours
# 9097L_3_2.png: Predicted PMI = 156.60 hours
# 9097L_3_3.png: Predicted PMI = 94.43 hours
# 9097L_3_4.png: Predicted PMI = 126.66 hours
# 9097R_1_1.png: Predicted PMI = 24.45 hours
# 9097R_1_2.png: Predicted PMI = 12.61 hours
# 9097R_1_3.png: Predicted PMI = 26.47 hours
# 9097R_2_1.png: Predicted PMI = 152.51 hours
# 9097R_2_2.png: Predicted PMI = 156.95 hours
# 9097R_2_3.png: Predicted PMI = 122.76 hours
# 9097R_3_1.png: Predicted PMI = 36.37 hours
# 9097R_3_2.png: Predicted PMI = 32.28 hours
# 9097R_3_3.png: Predicted PMI = 13.51 hours
# 9097R_3_4.png: Predicted PMI = 21.72 hours
# 9098L_1_1.png: Predicted PMI = 9.40 hours
# 9098L_1_2.png: Predicted PMI = 10.18 hours
# 9098L_1_3.png: Predicted PMI = 9.68 hours
# 9098L_1_4.png: Predicted PMI = 160.06 hours
# 9098R_1_4.png: Predicted PMI = 19.44 hours
# 9098R_2_1.png: Predicted PMI = 42.78 hours
# 9098R_2_2.png: Predicted PMI = 31.77 hours
# 9098R_2_3.png: Predicted PMI = 97.61 hours
# 9098R_2_4.png: Predicted PMI = 76.07 hours
# 9099L_1_1.png: Predicted PMI = 7.92 hours
# 9099L_1_2.png: Predicted PMI = 2.50 hours
# 9099L_1_3.png: Predicted PMI = 2.93 hours
# 9099L_1_4.png: Predicted PMI = 4.58 hours
# 9099R_1_1.png: Predicted PMI = 36.79 hours
# 9099R_1_2.png: Predicted PMI = 47.79 hours
# 9099R_1_3.png: Predicted PMI = 24.59 hours
# 9099R_1_4.png: Predicted PMI = 23.25 hours
# 9100L_1_1.png: Predicted PMI = 8.24 hours
# 9100L_1_2.png: Predicted PMI = 23.94 hours
# 9100L_1_3.png: Predicted PMI = 27.29 hours
# 9100L_1_4.png: Predicted PMI = 2.95 hours
# 9100L_2_1.png: Predicted PMI = 82.30 hours
# 9100L_2_2.png: Predicted PMI = 95.08 hours
# 9100L_2_3.png: Predicted PMI = 142.13 hours
# 9100L_2_4.png: Predicted PMI = 335.11 hours
# 9100R_1_1.png: Predicted PMI = 165.68 hours
# 9100R_1_2.png: Predicted PMI = 74.75 hours
# 9100R_1_3.png: Predicted PMI = 66.43 hours
# 9100R_1_4.png: Predicted PMI = 59.68 hours
# 9100R_2_1.png: Predicted PMI = 22.39 hours
# 9100R_2_2.png: Predicted PMI = 10.12 hours
# 9100R_2_3.png: Predicted PMI = 30.78 hours
# 9100R_2_4.png: Predicted PMI = 23.10 hours
# 9101L_1_1.png: Predicted PMI = 10.77 hours
# 9101L_1_2.png: Predicted PMI = 11.91 hours
# 9101L_1_3.png: Predicted PMI = 33.37 hours
# 9101L_1_4.png: Predicted PMI = 18.11 hours
# 9101L_2_1.png: Predicted PMI = 11.61 hours
# 9101L_2_2.png: Predicted PMI = 9.49 hours
# 9101L_2_3.png: Predicted PMI = 17.63 hours
# ...
# 9233R_1_1.png: Predicted PMI = 62.97 hours
# 9233R_1_2.png: Predicted PMI = 15.67 hours
# 9233R_1_3.png: Predicted PMI = 48.35 hours
# 9233R_1_4.png: Predicted PMI = 63.27 hours
# 9234L_1_1.png: Predicted PMI = 164.19 hours
# 9234L_1_2.png: Predicted PMI = 193.82 hours
# 9234L_1_3.png: Predicted PMI = 230.18 hours
# 9234L_1_4.png: Predicted PMI = 192.19 hours
# 9234R_1_1.png: Predicted PMI = 93.61 hours
# 9234R_1_3.png: Predicted PMI = 78.25 hours
# 9234R_1_4.png: Predicted PMI = 106.61 hours
# 9235L_1_1.png: Predicted PMI = 110.65 hours
# 9235L_1_2.png: Predicted PMI = 76.25 hours
# 9235L_1_3.png: Predicted PMI = 109.64 hours
# 9235L_1_4.png: Predicted PMI = 126.41 hours
# 9235L_2_1.png: Predicted PMI = 447.27 hours
# 9235L_2_2.png: Predicted PMI = 644.88 hours
# 9235L_2_3.png: Predicted PMI = 604.61 hours
# 9235L_2_4.png: Predicted PMI = 444.02 hours
# 9235R_1_1.png: Predicted PMI = 260.94 hours
# 9235R_1_2.png: Predicted PMI = 186.54 hours
# 9235R_1_3.png: Predicted PMI = 300.05 hours
# 9235R_1_4.png: Predicted PMI = 263.72 hours
# 9235R_2_1.png: Predicted PMI = 59.65 hours
# 9235R_2_2.png: Predicted PMI = 76.14 hours
# 9235R_2_3.png: Predicted PMI = 122.16 hours
# 9235R_2_4.png: Predicted PMI = 231.62 hours
# 9236L_1_1.png: Predicted PMI = 273.19 hours
# 9236L_1_2.png: Predicted PMI = 218.65 hours
# 9236L_1_3.png: Predicted PMI = 86.11 hours
# 9236L_1_4.png: Predicted PMI = 28.60 hours
# 9236L_2_1.png: Predicted PMI = 71.72 hours
# 9236L_2_2.png: Predicted PMI = 125.28 hours
# 9236L_2_3.png: Predicted PMI = 74.72 hours
# 9236L_2_4.png: Predicted PMI = 54.91 hours
# 9236L_3_1.png: Predicted PMI = 163.59 hours
# 9236L_3_2.png: Predicted PMI = 77.89 hours
# 9236L_3_3.png: Predicted PMI = 296.27 hours
# 9236L_3_4.png: Predicted PMI = 99.22 hours
# 9236L_4_1.png: Predicted PMI = 109.04 hours
# 9236L_4_2.png: Predicted PMI = 40.20 hours
# 9236L_4_3.png: Predicted PMI = 41.41 hours
# 9236L_4_4.png: Predicted PMI = 85.38 hours
# 9236R_1_1.png: Predicted PMI = 209.09 hours
# 9236R_1_2.png: Predicted PMI = 32.76 hours
# 9236R_1_3.png: Predicted PMI = 150.39 hours
# 9236R_1_4.png: Predicted PMI = 95.20 hours
# 9236R_2_1.png: Predicted PMI = 24.53 hours
# 9236R_2_2.png: Predicted PMI = 50.08 hours
# 9236R_2_3.png: Predicted PMI = 35.67 hours
# 9236R_2_4.png: Predicted PMI = 48.93 hours
# 9236R_3_1.png: Predicted PMI = 91.93 hours
# 9236R_3_2.png: Predicted PMI = 37.59 hours
# 9236R_3_3.png: Predicted PMI = 63.19 hours
# 9236R_3_4.png: Predicted PMI = 57.66 hours
# 9236R_4_1.png: Predicted PMI = 107.31 hours
# 9236R_4_2.png: Predicted PMI = 209.83 hours
# 9236R_4_3.png: Predicted PMI = 83.81 hours
# 9236R_4_4.png: Predicted PMI = 112.36 hours
# 9237L_1_1.png: Predicted PMI = 7.32 hours
# 9237L_1_2.png: Predicted PMI = 13.82 hours
# 9237L_1_3.png: Predicted PMI = 5.45 hours
# 9237L_1_4.png: Predicted PMI = 15.72 hours
# 9237R_1_1.png: Predicted PMI = 11.73 hours
# 9237R_1_2.png: Predicted PMI = 5.91 hours
# 9237R_1_3.png: Predicted PMI = 47.73 hours
# 9237R_1_4.png: Predicted PMI = 8.89 hours
# 9238L_1_1.png: Predicted PMI = 12.27 hours
# 9238L_1_2.png: Predicted PMI = 18.88 hours
# 9238L_1_3.png: Predicted PMI = 4.13 hours
# 9238L_1_4.png: Predicted PMI = 5.42 hours
# 9238L_2_1.png: Predicted PMI = 16.09 hours
# 9238L_2_2.png: Predicted PMI = 10.31 hours
# 9238L_2_3.png: Predicted PMI = 2.47 hours
# 9238R_1_1.png: Predicted PMI = 6.28 hours
# 9238R_1_2.png: Predicted PMI = 5.69 hours
# 9238R_1_3.png: Predicted PMI = 8.39 hours
# 9238R_1_4.png: Predicted PMI = 7.22 hours
# 9238R_2_1.png: Predicted PMI = 11.30 hours
# 9238R_2_2.png: Predicted PMI = 9.01 hours
# 9238R_2_3.png: Predicted PMI = 4.73 hours
# 9238R_2_4.png: Predicted PMI = 4.27 hours
# 9239L_1_1.png: Predicted PMI = 193.23 hours
# 9239L_1_2.png: Predicted PMI = 361.97 hours
# 9239L_1_3.png: Predicted PMI = 158.31 hours
# 9239L_1_4.png: Predicted PMI = 218.83 hours
# 9239L_2_1.png: Predicted PMI = 34.04 hours
# 9239L_2_2.png: Predicted PMI = 13.08 hours
# 9239L_2_3.png: Predicted PMI = 7.65 hours
# 9239L_2_4.png: Predicted PMI = 1.86 hours
# 9239R_1_1.png: Predicted PMI = 125.01 hours
# 9239R_1_2.png: Predicted PMI = 191.10 hours
# 9239R_1_3.png: Predicted PMI = 158.03 hours
# 9239R_1_4.png: Predicted PMI = 180.69 hours
# 9239R_2_1.png: Predicted PMI = 28.18 hours
# 9239R_2_2.png: Predicted PMI = 62.81 hours
# 9239R_2_3.png: Predicted PMI = 134.30 hours
# 9239R_2_4.png: Predicted PMI = 15.66 hours
# 9240L_1_1.png: Predicted PMI = 202.55 hours
# 9240L_1_2.png: Predicted PMI = 176.73 hours
# 9240L_1_3.png: Predicted PMI = 301.64 hours
# 9240L_1_4.png: Predicted PMI = 84.38 hours
# 9240R_1_1.png: Predicted PMI = 33.23 hours
# 9240R_1_2.png: Predicted PMI = 43.09 hours
# 9240R_1_3.png: Predicted PMI = 187.54 hours
# 9240R_1_4.png: Predicted PMI = 163.14 hours
# 9241L_1_1.png: Predicted PMI = 108.54 hours
# 9241L_1_2.png: Predicted PMI = 172.38 hours
# 9241L_1_3.png: Predicted PMI = 56.23 hours
# 9241L_1_4.png: Predicted PMI = 57.84 hours
# 9241L_2_1.png: Predicted PMI = 193.18 hours
# 9241L_2_2.png: Predicted PMI = 296.38 hours
# 9241L_2_3.png: Predicted PMI = 128.24 hours
# 9241L_2_4.png: Predicted PMI = 175.91 hours
# 9241L_3_2.png: Predicted PMI = 118.40 hours
# 9241L_3_3.png: Predicted PMI = 147.97 hours
# 9241L_3_4.png: Predicted PMI = 62.58 hours
# 9241R_1_1.png: Predicted PMI = 124.79 hours
# 9241R_1_2.png: Predicted PMI = 73.93 hours
# 9241R_1_3.png: Predicted PMI = 57.84 hours
# 9241R_1_4.png: Predicted PMI = 65.92 hours
# 9241R_2_1.png: Predicted PMI = 254.31 hours
# 9241R_2_2.png: Predicted PMI = 353.25 hours
# 9241R_2_3.png: Predicted PMI = 165.32 hours
# 9241R_2_4.png: Predicted PMI = 216.80 hours
# 9241R_3_1.png: Predicted PMI = 206.35 hours
# 9241R_3_2.png: Predicted PMI = 285.45 hours
# 9241R_3_3.png: Predicted PMI = 48.98 hours
# 9241R_3_4.png: Predicted PMI = 184.50 hours
# 9242L_3_1.png: Predicted PMI = 132.22 hours
# 9242L_3_2.png: Predicted PMI = 137.32 hours
# 9242L_3_3.png: Predicted PMI = 176.90 hours
# 9242L_3_4.png: Predicted PMI = 146.20 hours
# 9242R_3_1.png: Predicted PMI = 49.80 hours
# 9242R_3_2.png: Predicted PMI = 101.07 hours
# 9242R_3_3.png: Predicted PMI = 54.66 hours
# 9242R_3_4.png: Predicted PMI = 84.77 hours
# 9243L_1_1.png: Predicted PMI = 35.24 hours
# 9243L_1_2.png: Predicted PMI = 45.32 hours
# 9243L_1_3.png: Predicted PMI = 35.66 hours
# 9243L_1_4.png: Predicted PMI = 23.09 hours
# 9243R_1_1.png: Predicted PMI = 47.04 hours
# 9243R_1_2.png: Predicted PMI = 42.89 hours
# 9243R_1_3.png: Predicted PMI = 41.19 hours
# 9243R_1_4.png: Predicted PMI = 21.72 hours
# 9244L_1_1.png: Predicted PMI = 158.36 hours
# 9244L_1_2.png: Predicted PMI = 24.57 hours
# 9244L_1_3.png: Predicted PMI = 59.31 hours
# 9244L_1_4.png: Predicted PMI = 35.91 hours
# 9244L_2_1.png: Predicted PMI = 61.33 hours
# 9244L_2_2.png: Predicted PMI = 10.39 hours
# 9244L_2_3.png: Predicted PMI = 7.17 hours
# 9244L_2_4.png: Predicted PMI = 16.17 hours
# 9244R_1_1.png: Predicted PMI = 75.92 hours
# 9244R_1_2.png: Predicted PMI = 165.87 hours
# 9244R_1_3.png: Predicted PMI = 52.08 hours
# 9244R_1_4.png: Predicted PMI = 31.07 hours
# 9244R_2_2.png: Predicted PMI = 24.57 hours
# 9244R_2_3.png: Predicted PMI = 31.84 hours
# 9244R_2_4.png: Predicted PMI = 70.63 hours
# 9245L_1_1.png: Predicted PMI = 40.79 hours
# 9245L_1_2.png: Predicted PMI = 17.96 hours
# 9245L_1_3.png: Predicted PMI = 7.01 hours
# 9245L_1_4.png: Predicted PMI = 11.23 hours
# 9245L_2_1.png: Predicted PMI = 16.04 hours
# 9245L_2_2.png: Predicted PMI = 48.25 hours
# 9245L_2_3.png: Predicted PMI = 24.05 hours
# 9245L_2_4.png: Predicted PMI = 21.20 hours
# 9245L_3_1.png: Predicted PMI = 40.56 hours
# 9245L_3_3.png: Predicted PMI = 84.88 hours
# 9245L_3_4.png: Predicted PMI = 57.19 hours
# 9245R_1_1.png: Predicted PMI = 21.74 hours
# 9245R_1_2.png: Predicted PMI = 31.30 hours
# 9245R_1_3.png: Predicted PMI = 21.68 hours
# 9245R_1_4.png: Predicted PMI = 18.44 hours
# 9245R_2_1.png: Predicted PMI = 25.26 hours
# 9245R_2_2.png: Predicted PMI = 10.36 hours
# 9245R_2_3.png: Predicted PMI = 13.48 hours
# 9245R_2_4.png: Predicted PMI = 15.28 hours
# 9245R_3_1.png: Predicted PMI = 149.54 hours
# 9245R_3_2.png: Predicted PMI = 64.96 hours
# 9245R_3_3.png: Predicted PMI = 150.25 hours
# 9245R_3_4.png: Predicted PMI = 114.87 hours
# 9246L_1_1.png: Predicted PMI = 187.56 hours
# 9246L_1_2.png: Predicted PMI = 140.83 hours
# 9246L_1_3.png: Predicted PMI = 158.19 hours
# 9246L_1_4.png: Predicted PMI = 166.34 hours
# 9246R_1_1.png: Predicted PMI = 63.26 hours
# 9246R_1_2.png: Predicted PMI = 57.51 hours
# 9246R_1_3.png: Predicted PMI = 29.65 hours
# 9246R_1_4.png: Predicted PMI = 36.17 hours
# 9247L_1_1.png: Predicted PMI = 102.78 hours
# 9247L_1_2.png: Predicted PMI = 249.23 hours
# 9247L_1_3.png: Predicted PMI = 198.43 hours
# 9247L_1_4.png: Predicted PMI = 74.74 hours
# 9247R_1_1.png: Predicted PMI = 73.39 hours
# 9247R_1_2.png: Predicted PMI = 17.35 hours
# 9247R_1_3.png: Predicted PMI = 9.80 hours
# 9247R_1_4.png: Predicted PMI = 22.15 hours
# 9248L_1_1.png: Predicted PMI = 200.29 hours
# 9248L_1_2.png: Predicted PMI = 64.31 hours
# 9248L_1_3.png: Predicted PMI = 83.98 hours
# 9248L_1_4.png: Predicted PMI = 5.03 hours
# 9248L_2_1.png: Predicted PMI = 6.76 hours
# 9248L_2_2.png: Predicted PMI = 16.58 hours
# 9248R_1_1.png: Predicted PMI = 33.77 hours
# 9248R_1_2.png: Predicted PMI = 27.97 hours
# 9248R_1_3.png: Predicted PMI = 35.78 hours
# 9248R_1_4.png: Predicted PMI = 30.51 hours
# 9248R_2_1.png: Predicted PMI = 14.13 hours
# 9248R_2_2.png: Predicted PMI = 32.27 hours
# 9248R_2_3.png: Predicted PMI = 76.62 hours
# 9248R_2_4.png: Predicted PMI = 8.37 hours
# 9249L_1_1.png: Predicted PMI = 27.55 hours
# 9249L_1_2.png: Predicted PMI = 48.83 hours
# 9249L_1_3.png: Predicted PMI = 44.09 hours
# 9249L_1_4.png: Predicted PMI = 39.87 hours
# 9249L_2_1.png: Predicted PMI = 18.60 hours
# 9249L_2_2.png: Predicted PMI = 31.53 hours
# 9249L_2_3.png: Predicted PMI = 15.65 hours
# 9249L_2_4.png: Predicted PMI = 24.62 hours
# 9249R_1_1.png: Predicted PMI = 218.69 hours
# 9249R_1_2.png: Predicted PMI = 72.12 hours
# 9249R_1_3.png: Predicted PMI = 58.55 hours
# 9249R_1_4.png: Predicted PMI = 36.54 hours
# 9249R_2_1.png: Predicted PMI = 4.39 hours
# 9249R_2_2.png: Predicted PMI = 27.06 hours
# 9249R_2_3.png: Predicted PMI = 98.06 hours
# 9249R_2_4.png: Predicted PMI = 22.65 hours
# 9250L_1_1.png: Predicted PMI = 100.73 hours
# 9250L_1_2.png: Predicted PMI = 108.22 hours
# 9250L_1_3.png: Predicted PMI = 211.43 hours
# 9250L_1_4.png: Predicted PMI = 223.44 hours
# 9250R_1_1.png: Predicted PMI = 127.02 hours
# 9250R_1_2.png: Predicted PMI = 136.64 hours
# 9250R_1_3.png: Predicted PMI = 94.56 hours
# 9250R_1_4.png: Predicted PMI = 101.39 hours
# 9250R_2_1.png: Predicted PMI = 109.47 hours
# 9250R_2_2.png: Predicted PMI = 63.82 hours
# 9250R_2_3.png: Predicted PMI = 67.54 hours
# 9250R_2_4.png: Predicted PMI = 90.87 hours
# 9251L_1_1.png: Predicted PMI = 12.54 hours
# 9251L_1_2.png: Predicted PMI = 8.68 hours
# 9251L_1_3.png: Predicted PMI = 6.93 hours
# 9251L_1_4.png: Predicted PMI = 25.55 hours
# 9251R_1_1.png: Predicted PMI = 4.53 hours
# 9251R_1_2.png: Predicted PMI = 14.22 hours
# 9251R_1_3.png: Predicted PMI = 10.41 hours
# 9251R_1_4.png: Predicted PMI = 22.88 hours
# 9252L_1_1.png: Predicted PMI = 46.82 hours
# 9252L_1_2.png: Predicted PMI = 63.92 hours
# 9252L_1_3.png: Predicted PMI = 29.16 hours
# 9252L_1_4.png: Predicted PMI = 47.88 hours
# 9252R_1_1.png: Predicted PMI = 106.52 hours
# 9252R_1_2.png: Predicted PMI = 41.90 hours
# 9252R_1_3.png: Predicted PMI = 12.75 hours
# 9252R_1_4.png: Predicted PMI = 29.43 hours
# 9253L_1_1.png: Predicted PMI = 100.31 hours
# 9253L_1_2.png: Predicted PMI = 69.22 hours
# 9253L_1_3.png: Predicted PMI = 24.77 hours
# 9253L_1_4.png: Predicted PMI = 32.24 hours
# 9253R_1_1.png: Predicted PMI = 33.86 hours
# 9253R_1_2.png: Predicted PMI = 22.61 hours
# 9253R_1_3.png: Predicted PMI = 44.16 hours
# 9253R_1_4.png: Predicted PMI = 58.17 hours
# 9254L_1_1.png: Predicted PMI = 25.02 hours
# 9254L_1_2.png: Predicted PMI = 10.96 hours
# 9254L_1_3.png: Predicted PMI = 16.50 hours
# 9254L_1_4.png: Predicted PMI = 18.16 hours
# 9254R_1_1.png: Predicted PMI = 54.35 hours
# 9254R_1_2.png: Predicted PMI = 236.12 hours
# 9254R_1_3.png: Predicted PMI = 22.52 hours
# 9254R_1_4.png: Predicted PMI = 8.31 hours
# 9255L_1_1.png: Predicted PMI = 109.03 hours
# 9255L_1_2.png: Predicted PMI = 40.61 hours
# 9255L_1_3.png: Predicted PMI = 34.03 hours
# 9255L_1_4.png: Predicted PMI = 62.78 hours
# 9255R_1_1.png: Predicted PMI = 45.26 hours
# 9255R_1_2.png: Predicted PMI = 111.13 hours
# 9255R_1_3.png: Predicted PMI = 20.26 hours
# 9255R_1_4.png: Predicted PMI = 73.81 hours
# 9256L_1_1.png: Predicted PMI = 162.47 hours
# 9256L_1_2.png: Predicted PMI = 22.39 hours
# 9256L_1_3.png: Predicted PMI = 19.39 hours
# 9256L_1_4.png: Predicted PMI = 21.74 hours
# 9256L_2_1.png: Predicted PMI = 175.46 hours
# 9256L_2_2.png: Predicted PMI = 185.21 hours
# 9256L_2_3.png: Predicted PMI = 110.86 hours
# 9256L_2_4.png: Predicted PMI = 52.00 hours
# 9256R_1_1.png: Predicted PMI = 212.53 hours
# 9256R_1_2.png: Predicted PMI = 172.91 hours
# 9256R_1_3.png: Predicted PMI = 155.99 hours
# 9256R_1_4.png: Predicted PMI = 214.75 hours
# 9256R_2_1.png: Predicted PMI = 71.97 hours
# 9256R_2_2.png: Predicted PMI = 40.85 hours
# 9256R_2_3.png: Predicted PMI = 55.53 hours
# 9256R_2_4.png: Predicted PMI = 28.18 hours
# 9257L_1_1.png: Predicted PMI = 97.83 hours
# 9257L_1_3.png: Predicted PMI = 19.95 hours
# 9257L_1_4.png: Predicted PMI = 9.19 hours
# 9257R_1_1.png: Predicted PMI = 3.82 hours
# 9257R_1_2.png: Predicted PMI = 4.97 hours
# 9257R_1_3.png: Predicted PMI = 9.60 hours
# 9257R_1_4.png: Predicted PMI = 9.56 hours
# 9258L_1_1.png: Predicted PMI = 66.66 hours
# 9258L_1_2.png: Predicted PMI = 67.98 hours
# 9258L_1_3.png: Predicted PMI = 45.35 hours
# 9258L_1_4.png: Predicted PMI = 34.07 hours
# 9258R_1_1.png: Predicted PMI = 57.77 hours
# 9258R_1_2.png: Predicted PMI = 74.87 hours
# 9258R_1_3.png: Predicted PMI = 35.65 hours
# 9258R_1_4.png: Predicted PMI = 112.87 hours
# 9259L_1_1.png: Predicted PMI = 30.33 hours
# 9259L_1_2.png: Predicted PMI = 105.17 hours
# 9259L_1_4.png: Predicted PMI = 11.55 hours
# 9259L_2_1.png: Predicted PMI = 57.31 hours
# 9259L_2_2.png: Predicted PMI = 43.10 hours
# 9259L_2_3.png: Predicted PMI = 37.83 hours
# 9259L_2_4.png: Predicted PMI = 48.32 hours
# 9259L_3_1.png: Predicted PMI = 136.99 hours
# 9259L_3_3.png: Predicted PMI = 130.76 hours
# 9259R_1_1.png: Predicted PMI = 11.95 hours
# 9259R_1_4.png: Predicted PMI = 42.48 hours
# 9259R_2_2.png: Predicted PMI = 67.82 hours
# 9259R_2_3.png: Predicted PMI = 27.02 hours
# 9259R_2_4.png: Predicted PMI = 62.21 hours
# 9259R_3_1.png: Predicted PMI = 109.73 hours
# 9259R_3_2.png: Predicted PMI = 182.37 hours
# 9259R_3_3.png: Predicted PMI = 74.10 hours
# 9259R_3_4.png: Predicted PMI = 157.40 hours
# 9260L_1_1.png: Predicted PMI = 62.23 hours
# 9260L_1_2.png: Predicted PMI = 38.80 hours
# 9260L_1_3.png: Predicted PMI = 48.07 hours
# 9260L_1_4.png: Predicted PMI = 39.12 hours
# 9260R_1_1.png: Predicted PMI = 77.79 hours
# 9260R_1_2.png: Predicted PMI = 52.67 hours
# 9260R_1_3.png: Predicted PMI = 122.47 hours
# 9260R_1_4.png: Predicted PMI = 133.23 hours
# 9260R_2_1.png: Predicted PMI = 116.24 hours
# 9260R_2_2.png: Predicted PMI = 207.38 hours
# 9260R_2_3.png: Predicted PMI = 274.08 hours
# 9260R_2_4.png: Predicted PMI = 94.16 hours
# 9261L_1_1.png: Predicted PMI = 152.73 hours
# 9261L_1_2.png: Predicted PMI = 44.72 hours
# 9261L_1_3.png: Predicted PMI = 75.37 hours
# 9261L_1_4.png: Predicted PMI = 115.76 hours
# 9261R_1_1.png: Predicted PMI = 100.08 hours
# 9261R_1_2.png: Predicted PMI = 173.63 hours
# 9261R_1_3.png: Predicted PMI = 70.65 hours
# 9261R_1_4.png: Predicted PMI = 34.30 hours
# 9262L_1_1.png: Predicted PMI = 110.03 hours
# 9262L_1_2.png: Predicted PMI = 118.07 hours
# 9262L_1_3.png: Predicted PMI = 68.30 hours
# 9262L_1_4.png: Predicted PMI = 181.44 hours
# 9262R_1_1.png: Predicted PMI = 18.47 hours
# 9262R_1_2.png: Predicted PMI = 21.87 hours
# 9262R_1_3.png: Predicted PMI = 15.23 hours
# 9262R_1_4.png: Predicted PMI = 20.35 hours
# 9263L_1_1.png: Predicted PMI = 203.98 hours
# 9263L_1_2.png: Predicted PMI = 131.09 hours
# 9263L_1_3.png: Predicted PMI = 117.35 hours
# 9263L_1_4.png: Predicted PMI = 173.77 hours
# 9263R_1_1.png: Predicted PMI = 156.48 hours
# 9263R_1_2.png: Predicted PMI = 96.91 hours
# 9263R_1_3.png: Predicted PMI = 81.03 hours
# 9263R_1_4.png: Predicted PMI = 70.62 hours
# 9275L_1_2.png: Predicted PMI = 8.76 hours
#
# ================= Evaluation Metrics =================
# MAE : 93.710
# RMSE: 202.216
# R²  : -0.178

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torchvision.datasets.folder import default_loader
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import numpy as np
from tqdm import tqdm
import timm
import glob

# ======== Configuration ========
BATCH_SIZE = 16
IMG_SIZE = 224
CHECKPOINT_DIR = "/DATA2/akshay/Akshat/checkpoints_coatnet_augmented"
CSV_PATH = "/DATA2/akshay/Akshat/metadata/nij_nir.csv"
IMAGE_DIR = "/DATA2/akshay/Akshat/NIJ/nir_images"  # ✅ Single image directory

# ======== Transforms ========
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])

# ======== Dataset Class for Single Image Directory ========
class IrisImageDatasetSingleDir(Dataset):
    def __init__(self, csv_path, image_dir, transform=None):
        df = pd.read_csv(csv_path)

        # ✅ Filter PMI < 100
        df = df[df['pmi'] < 600].reset_index(drop=True)

        self.df = df
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.image_dir, row['filename'])
        if not os.path.exists(img_path):
            raise FileNotFoundError(f"Image {row['filename']} not found in {self.image_dir}")
        image = default_loader(img_path)
        if self.transform:
            image = self.transform(image)
        pmi = np.log1p(row['pmi'])  # Log scale
        return image, torch.tensor(pmi, dtype=torch.float32)


# ======== CoAtNet Regressor ========
class CoAtNetRegressor(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = timm.create_model("coatnet_0_rw_224", pretrained=True, num_classes=0)
        in_features = self.backbone.num_features
        self.regressor = nn.Sequential(
            nn.Linear(in_features, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        feats = self.backbone(x)
        out = self.regressor(feats).squeeze(1)
        return out

# ======== Inference Function ========
def inference():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Dataset & Loader
    test_dataset = IrisImageDatasetSingleDir(CSV_PATH, IMAGE_DIR, transform)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

    # Load model & latest checkpoint
    model = CoAtNetRegressor().to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

    ckpts = sorted(glob.glob(os.path.join(CHECKPOINT_DIR, "epoch_*.pt")), key=os.path.getmtime)
    if not ckpts:
        raise FileNotFoundError("❌ No checkpoint found for inference.")
    latest_ckpt = ckpts[-1]
    checkpoint = torch.load(latest_ckpt, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"✅ Loaded checkpoint: {latest_ckpt}")

    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for x, y in tqdm(test_loader, desc="Running Inference"):
            x, y = x.to(device), y.to(device)
            preds = model(x)
            preds = torch.expm1(preds)  # Convert back from log1p
            y = torch.expm1(y)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    # Compute metrics
    mae = mean_absolute_error(all_labels, all_preds)
    mse = mean_squared_error(all_labels, all_preds)
    rmse = np.sqrt(mse)
    r2 = r2_score(all_labels, all_preds)

    print("\n📊 Inference Metrics:")
    print(f"MAE : {mae:.2f}")
    print(f"MSE : {mse:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"R²  : {r2:.4f}")

    return all_preds, all_labels

if __name__ == "__main__":
    inference()
# Out:
# ✅ Loaded checkpoint: /DATA2/akshay/Akshat/checkpoints_coatnet_augmented/epoch_98.pt
# Running Inference: 100%|██████████| 343/343 [07:41<00:00,  1.35s/it]
# 📊 Inference Metrics:
# MAE : 57.67
# MSE : 9194.24
# RMSE: 95.89
# R²  : -0.3258

# %% [markdown]
# ## INFERENCING ON DINO TRAINED ON SYNTHETIC DATASET

# %%
import torch
import timm
import numpy as np
import pandas as pd
import cv2
import os
from tqdm import tqdm
import joblib
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# =================== CONFIG ===================
data_root = "/DATA2/akshay/Akshat/NIJ/nir_images"  # <- change this
metadata_path = "/DATA2/akshay/Akshat/metadata/nij_nir.csv"  # <- change this
model_save_path = "/DATA2/akshay/Akshat/mlp_model.joblib"
scaler_save_path = "/DATA2/akshay/Akshat/scaler.joblib"
PMI_THRESHOLD = 400
# ==============================================

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

# Load trained model and scaler
mlp = joblib.load(model_save_path)
scaler = joblib.load(scaler_save_path)

# Load pretrained DINO model
dino_model = timm.create_model("vit_base_patch16_224_dino", pretrained=True)
dino_model.eval().to(device)

# Load metadata
metadata = pd.read_csv(metadata_path)
metadata = metadata[metadata['pmi'] < PMI_THRESHOLD]  # Filter here
filename_to_pmi = dict(zip(metadata['filename'], metadata['pmi']))

# Collect valid image paths and PMI values
image_paths = []
pmi_values = []

for fname in os.listdir(data_root):
    if fname.endswith(".bmp") and fname in filename_to_pmi:
        image_paths.append(os.path.join(data_root, fname))
        pmi_values.append(filename_to_pmi[fname])
    elif fname.endswith(".bmp") and fname not in filename_to_pmi:
        print(f"Skipping {fname}: No valid PMI or exceeds threshold")

# DINO feature extraction
def extract_dino_features(image_paths, batch_size=32):
    features = []

    for i in tqdm(range(0, len(image_paths), batch_size), desc="Extracting DINO Features"):
        batch_paths = image_paths[i:i + batch_size]
        batch_images = []

        for path in batch_paths:
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"Warning: Unable to load image {path}")
                batch_images.append(torch.zeros((3, 224, 224)))
                continue

            img = cv2.resize(img, (224, 224))
            img = np.stack([img] * 3, axis=-1)
            img = torch.tensor(img).permute(2, 0, 1).float() / 255.0
            batch_images.append(img)

        batch_tensor = torch.stack(batch_images).to(device)
        with torch.no_grad():
            batch_features = dino_model.forward_features(batch_tensor)
            batch_features = batch_features.cpu().numpy()

        features.append(batch_features)

    return np.vstack(features)

# Extract and preprocess features
raw_features = extract_dino_features(image_paths)
cls_features = raw_features[:, 0, :]
X = pd.DataFrame(cls_features)
X_scaled = scaler.transform(X)

# Predict
y_true = np.array(pmi_values)
y_pred = mlp.predict(X_scaled)

# Evaluate
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print(f"\n--- Inference Metrics (PMI < {PMI_THRESHOLD}) ---")
print(f"MAE : {mae:.3f}")
print(f"RMSE: {rmse:.3f}")
print(f"R²  : {r2:.3f}")
# Out:
# Device: cuda
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/timm/models/_factory.py:126: UserWarning: Mapping deprecated model name vit_base_patch16_224_dino to current vit_base_patch16_224.dino.
#   model = create_fn(
# Skipping 9129L_53_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_7.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_2_3.bmp: No valid PMI or exceeds threshold
# Skipping 9052R_5_3.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_15_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_1_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_21_3.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_3_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_4.bmp: No valid PMI or exceeds threshold
# Skipping 9140R_4_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_1.bmp: No valid PMI or exceeds threshold
# Skipping 9200L_2_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_30_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_6.bmp: No valid PMI or exceeds threshold
# Skipping 9103R_9_4.bmp: No valid PMI or exceeds threshold
# Skipping 9167L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_28_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_28_1.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_2_1.bmp: No valid PMI or exceeds threshold
# Skipping 9928L_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_5.bmp: No valid PMI or exceeds threshold
# Skipping 9091R_2_1.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_3_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_25_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_18_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_22_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_30_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_29_1.bmp: No valid PMI or exceeds threshold
# Skipping 9207R_2_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_10.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_16_4.bmp: No valid PMI or exceeds threshold
# Skipping 9139L_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9148L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_2_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_33_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_17_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_4.bmp: No valid PMI or exceeds threshold
# Skipping 9205L_4_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_29_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_17_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_25_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_39_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_17_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_38_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_7.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_7_3.bmp: No valid PMI or exceeds threshold
# Skipping 9103R_6_2.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_3_4.bmp: No valid PMI or exceeds threshold
# Skipping 9049L_9_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_12.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_24_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_19_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_37_4.bmp: No valid PMI or exceeds threshold
# Skipping 9028R_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_32_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_27_3.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_3_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_39_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_39_1.bmp: No valid PMI or exceeds threshold
# Skipping 9922R_2_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_25_2.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_15_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_38_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_6.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_2_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_7.bmp: No valid PMI or exceeds threshold
# Skipping 9049R_10_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_26_1.bmp: No valid PMI or exceeds threshold
# Skipping 9049R_9_2.bmp: No valid PMI or exceeds threshold
# Skipping 9173R_2_7.bmp: No valid PMI or exceeds threshold
# Skipping 9936R_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_5.bmp: No valid PMI or exceeds threshold
# Skipping 9017L_1_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_21_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_8.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_16_1.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_2_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_2.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_3_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_16_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_19_2.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_15_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_26_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_4.bmp: No valid PMI or exceeds threshold
# Skipping 9145R_4_4.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_16_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_1.bmp: No valid PMI or exceeds threshold
# Skipping 9217L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_16_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_4.bmp: No valid PMI or exceeds threshold
# Skipping 9201R_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9155L_6_1.bmp: No valid PMI or exceeds threshold
# Skipping 9049R_10_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_31_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_16_2.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_6_4.bmp: No valid PMI or exceeds threshold
# Skipping 9022R_2_3.bmp: No valid PMI or exceeds threshold
# Skipping 9243L_1_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_9.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_27_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_31_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_33_1.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_3_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_24_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_1.bmp: No valid PMI or exceeds threshold
# Skipping 9240L_1_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_1_4.bmp: No valid PMI or exceeds threshold
# Skipping 9177L_3_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_27_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_25_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_8.bmp: No valid PMI or exceeds threshold
# Skipping 9024R_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_2_4.bmp: No valid PMI or exceeds threshold
# Skipping 9912L_6_4.bmp: No valid PMI or exceeds threshold
# Skipping 9181R_2_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_37_3.bmp: No valid PMI or exceeds threshold
# Skipping 9145L_5_2.bmp: No valid PMI or exceeds threshold
# Skipping 9151R_2_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_37_2.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_15_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_9.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_15_3.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_16_4.bmp: No valid PMI or exceeds threshold
# Skipping 9201R_2_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_32_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_22_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_49_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_29_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_3.bmp: No valid PMI or exceeds threshold
# Skipping 9245L_2_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_37_1.bmp: No valid PMI or exceeds threshold
# Skipping 9185R_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9240L_1_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_20_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_1.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_15_1.bmp: No valid PMI or exceeds threshold
# Skipping 9179R_1_8.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_3_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_7.bmp: No valid PMI or exceeds threshold
# Skipping 9199R_3_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_18_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_1_5.bmp: No valid PMI or exceeds threshold
# Skipping 9040L_3_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_19_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_49_1.bmp: No valid PMI or exceeds threshold
# Skipping 9178L_1_10.bmp: No valid PMI or exceeds threshold
# Skipping 9199R_3_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_7.bmp: No valid PMI or exceeds threshold
# Skipping 9179R_1_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_11.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_26_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_24_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_6.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_15_4.bmp: No valid PMI or exceeds threshold
# Skipping 9016L_5_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_28_4.bmp: No valid PMI or exceeds threshold
# Skipping 9049L_7_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_49_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_2.bmp: No valid PMI or exceeds threshold
# Skipping 9049L_7_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_48_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_20_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_1_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_33_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_48_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9219R_2_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_2.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_2_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_50_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_3.bmp: No valid PMI or exceeds threshold
# Skipping 9140R_8_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_33_3.bmp: No valid PMI or exceeds threshold
# Skipping 9016L_7_2.bmp: No valid PMI or exceeds threshold
# Skipping 9145L_3_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_16_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_19_1.bmp: No valid PMI or exceeds threshold
# Skipping 9137R_1_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_12.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_31_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_22_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_7.bmp: No valid PMI or exceeds threshold
# Skipping 9977R_4_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_24_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_29_6.bmp: No valid PMI or exceeds threshold
# Skipping 9178L_1_9.bmp: No valid PMI or exceeds threshold
# Skipping 9124L_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_23_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_1_7.bmp: No valid PMI or exceeds threshold
# Skipping 9029R_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_30_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_29_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_31_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_10.bmp: No valid PMI or exceeds threshold
# Skipping 9049R_9_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_32_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_28_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_39_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_20_4.bmp: No valid PMI or exceeds threshold
# Skipping 9115R_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9140R_8_1.bmp: No valid PMI or exceeds threshold
# Skipping 9177L_3_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_5.bmp: No valid PMI or exceeds threshold
# Skipping 9214R_3_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_4.bmp: No valid PMI or exceeds threshold
# Skipping 9204L_2_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_4.bmp: No valid PMI or exceeds threshold
# Skipping 9199R_3_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_18_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_51_5.bmp: No valid PMI or exceeds threshold
# Skipping 9973R_1_4.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_16_3.bmp: No valid PMI or exceeds threshold
# Skipping 9016L_7_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_48_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_38_3.bmp: No valid PMI or exceeds threshold
# Skipping 9211L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_15_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_7.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_29_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_21_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_1.bmp: No valid PMI or exceeds threshold
# Skipping 9049L_9_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_17_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_30_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_18_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_21_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_1.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_2_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_43_1.bmp: No valid PMI or exceeds threshold
# Skipping 9224L_16_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_21_6.bmp: No valid PMI or exceeds threshold
# Skipping 9148L_1_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_44_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_48_4.bmp: No valid PMI or exceeds threshold
# Skipping 9200L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_37_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_17_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_17_6.bmp: No valid PMI or exceeds threshold
# Skipping 9140R_7_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_22_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_26_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_28_5.bmp: No valid PMI or exceeds threshold
# Skipping 9199R_3_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_42_6.bmp: No valid PMI or exceeds threshold
# Skipping 9124R_3_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_16_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_38_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_27_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_4.bmp: No valid PMI or exceeds threshold
# Skipping 9173R_2_8.bmp: No valid PMI or exceeds threshold
# Skipping 9207R_3_1.bmp: No valid PMI or exceeds threshold
# Skipping 9181R_2_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_21_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_4.bmp: No valid PMI or exceeds threshold
# Skipping 9016L_3_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_45_2.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_32_4.bmp: No valid PMI or exceeds threshold
# Skipping 9156R_1_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_27_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_46_8.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_41_6.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_53_5.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_27_2.bmp: No valid PMI or exceeds threshold
# Skipping 9224R_16_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_47_6.bmp: No valid PMI or exceeds threshold
# Skipping 9152L_1_3.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_49_4.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_20_3.bmp: No valid PMI or exceeds threshold
# Skipping 9199R_3_7.bmp: No valid PMI or exceeds threshold
# Skipping 9191R_1_4.bmp: No valid PMI or exceeds threshold
# Skipping 9083R_10_1.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_15_11.bmp: No valid PMI or exceeds threshold
# Skipping 9129L_52_6.bmp: No valid PMI or exceeds threshold
# Skipping 9199R_3_2.bmp: No valid PMI or exceeds threshold
# Skipping 9155L_4_4.bmp: No valid PMI or exceeds threshold
# Extracting DINO Features: 100%|██████████| 170/170 [00:20<00:00,  8.47it/s]
# --- Inference Metrics (PMI < 400) ---
# MAE : 42.956
# RMSE: 67.427
# R²  : 0.176

# %% [markdown]
# ## INFERENCING ON CLIP TRAINED ON SYNTHETIC DATASET

# %%
import torch
import clip
import numpy as np
import pandas as pd
import cv2
import os
from tqdm import tqdm
import joblib
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from torchvision import transforms

# ================ CONFIG =================
test_data_dir = "/DATA2/akshay/Akshat/NIJ/nir_images"
metadata_path = "/DATA2/akshay/Akshat/metadata/nij_nir.csv"
model_save_path = "/DATA2/akshay/Akshat/clip_mlp_model.joblib"
scaler_save_path = "/DATA2/akshay/Akshat/clip_scaler.joblib"
# ==========================================

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
clip_model, _ = clip.load("ViT-B/32", device=device)
clip_model.eval()

# CLIP-compatible preprocessing
preprocess_fast = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(224, interpolation=transforms.InterpolationMode.BICUBIC),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.4815, 0.4578, 0.4082),
                         std=(0.2686, 0.2613, 0.2758))
])

# Load metadata and extract PMI for test images
metadata = pd.read_csv(metadata_path)
# metadata = metadata[metadata['pmi'] < 400].reset_index(drop=True)
filename_to_pmi = dict(zip(metadata['filename'], metadata['pmi']))

test_image_paths = []
test_pmi_values = []

for fname in os.listdir(test_data_dir):
    if fname.endswith(".bmp") and fname in filename_to_pmi:
        test_image_paths.append(os.path.join(test_data_dir, fname))
        test_pmi_values.append(filename_to_pmi[fname])
    elif fname.endswith(".bmp"):
        print(f"Warning: {fname} not found in metadata!")

def extract_clip_features(image_paths, batch_size=32):
    all_features = []

    for i in tqdm(range(0, len(image_paths), batch_size), desc="Extracting CLIP Features"):
        batch_paths = image_paths[i:i + batch_size]
        batch_images = []

        for path in batch_paths:
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"Warning: Failed to load image {path}. Using zeros.")
                img_tensor = torch.zeros(3, 224, 224)
            else:
                img = cv2.resize(img, (224, 224))
                img = np.stack([img]*3, axis=-1)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img_tensor = preprocess_fast(img)

            batch_images.append(img_tensor)

        batch_tensor = torch.stack(batch_images).to(device)

        with torch.no_grad():
            image_features = clip_model.encode_image(batch_tensor)
            image_features = image_features.cpu().numpy()

        all_features.append(image_features)

    return np.vstack(all_features)

# Extract features for test set
test_features = extract_clip_features(test_image_paths, batch_size=64)
test_pmi_values = np.array(test_pmi_values)

# Load model and scaler
mlp = joblib.load(model_save_path)
scaler = joblib.load(scaler_save_path)

# Scale and predict
X_test_scaled = scaler.transform(test_features)
y_pred = mlp.predict(X_test_scaled)

# Evaluation
mae = mean_absolute_error(test_pmi_values, y_pred)
rmse = np.sqrt(mean_squared_error(test_pmi_values, y_pred))
r2 = r2_score(test_pmi_values, y_pred)

print("\n====== Inference Metrics ======")
print(f"MAE: {mae:.3f}")
print(f"RMSE: {rmse:.3f}")
print(f"R² Score: {r2:.3f}")
# Out:
# Using device: cuda
# Warning: 9124L_2_3.bmp not found in metadata!
# Warning: 9052R_5_3.bmp not found in metadata!
# Warning: 9129L_1_6.bmp not found in metadata!
# Warning: 9124L_3_1.bmp not found in metadata!
# Warning: 9140R_4_1.bmp not found in metadata!
# Warning: 9200L_2_4.bmp not found in metadata!
# Warning: 9103R_9_4.bmp not found in metadata!
# Warning: 9167L_1_3.bmp not found in metadata!
# Warning: 9124L_2_1.bmp not found in metadata!
# Warning: 9928L_1_1.bmp not found in metadata!
# Warning: 9091R_2_1.bmp not found in metadata!
# Warning: 9124L_3_4.bmp not found in metadata!
# Warning: 9207R_2_2.bmp not found in metadata!
# Warning: 9139L_1_1.bmp not found in metadata!
# Warning: 9148L_1_3.bmp not found in metadata!
# Warning: 9124R_2_1.bmp not found in metadata!
# Warning: 9205L_4_2.bmp not found in metadata!
# Warning: 9124R_7_3.bmp not found in metadata!
# Warning: 9103R_6_2.bmp not found in metadata!
# Warning: 9124R_3_4.bmp not found in metadata!
# Warning: 9049L_9_5.bmp not found in metadata!
# Warning: 9028R_1_3.bmp not found in metadata!
# Warning: 9124R_3_1.bmp not found in metadata!
# Warning: 9922R_2_1.bmp not found in metadata!
# Warning: 9124R_2_2.bmp not found in metadata!
# Warning: 9049R_10_3.bmp not found in metadata!
# Warning: 9049R_9_2.bmp not found in metadata!
# Warning: 9173R_2_7.bmp not found in metadata!
# Warning: 9936R_1_1.bmp not found in metadata!
# Warning: 9017L_1_4.bmp not found in metadata!
# Warning: 9124L_2_2.bmp not found in metadata!
# Warning: 9124R_3_3.bmp not found in metadata!
# Warning: 9145R_4_4.bmp not found in metadata!
# Warning: 9217L_1_3.bmp not found in metadata!
# Warning: 9201R_1_3.bmp not found in metadata!
# Warning: 9155L_6_1.bmp not found in metadata!
# Warning: 9049R_10_4.bmp not found in metadata!
# Warning: 9124L_6_4.bmp not found in metadata!
# Warning: 9022R_2_3.bmp not found in metadata!
# Warning: 9243L_1_2.bmp not found in metadata!
# Warning: 9124L_3_2.bmp not found in metadata!
# Warning: 9240L_1_8.bmp not found in metadata!
# Warning: 9129L_1_4.bmp not found in metadata!
# Warning: 9177L_3_5.bmp not found in metadata!
# Warning: 9024R_1_1.bmp not found in metadata!
# Warning: 9124R_2_4.bmp not found in metadata!
# Warning: 9912L_6_4.bmp not found in metadata!
# Warning: 9181R_2_4.bmp not found in metadata!
# Warning: 9145L_5_2.bmp not found in metadata!
# Warning: 9151R_2_3.bmp not found in metadata!
# Warning: 9201R_2_3.bmp not found in metadata!
# Warning: 9245L_2_4.bmp not found in metadata!
# Warning: 9185R_1_3.bmp not found in metadata!
# Warning: 9240L_1_7.bmp not found in metadata!
# Warning: 9179R_1_8.bmp not found in metadata!
# Warning: 9124L_3_3.bmp not found in metadata!
# Warning: 9199R_3_8.bmp not found in metadata!
# Warning: 9129L_1_5.bmp not found in metadata!
# Warning: 9040L_3_3.bmp not found in metadata!
# Warning: 9178L_1_10.bmp not found in metadata!
# Warning: 9199R_3_1.bmp not found in metadata!
# Warning: 9179R_1_7.bmp not found in metadata!
# Warning: 9016L_5_1.bmp not found in metadata!
# Warning: 9049L_7_3.bmp not found in metadata!
# Warning: 9049L_7_4.bmp not found in metadata!
# Warning: 9129L_1_8.bmp not found in metadata!
# Warning: 9129L_1_3.bmp not found in metadata!
# Warning: 9219R_2_3.bmp not found in metadata!
# Warning: 9124L_2_4.bmp not found in metadata!
# Warning: 9140R_8_3.bmp not found in metadata!
# Warning: 9016L_7_2.bmp not found in metadata!
# Warning: 9145L_3_1.bmp not found in metadata!
# Warning: 9137R_1_2.bmp not found in metadata!
# Warning: 9977R_4_3.bmp not found in metadata!
# Warning: 9178L_1_9.bmp not found in metadata!
# Warning: 9124L_1_1.bmp not found in metadata!
# Warning: 9129L_1_7.bmp not found in metadata!
# Warning: 9029R_1_1.bmp not found in metadata!
# Warning: 9049R_9_1.bmp not found in metadata!
# Warning: 9115R_1_1.bmp not found in metadata!
# Warning: 9140R_8_1.bmp not found in metadata!
# Warning: 9177L_3_6.bmp not found in metadata!
# Warning: 9214R_3_1.bmp not found in metadata!
# Warning: 9204L_2_1.bmp not found in metadata!
# Warning: 9199R_3_6.bmp not found in metadata!
# Warning: 9973R_1_4.bmp not found in metadata!
# Warning: 9016L_7_1.bmp not found in metadata!
# Warning: 9211L_1_3.bmp not found in metadata!
# Warning: 9129L_21_4.bmp not found in metadata!
# Warning: 9049L_9_6.bmp not found in metadata!
# Warning: 9124R_2_3.bmp not found in metadata!
# Warning: 9148L_1_5.bmp not found in metadata!
# Warning: 9200L_1_3.bmp not found in metadata!
# Warning: 9140R_7_2.bmp not found in metadata!
# Warning: 9199R_3_5.bmp not found in metadata!
# Warning: 9124R_3_2.bmp not found in metadata!
# Warning: 9173R_2_8.bmp not found in metadata!
# Warning: 9207R_3_1.bmp not found in metadata!
# Warning: 9181R_2_1.bmp not found in metadata!
# Warning: 9016L_3_4.bmp not found in metadata!
# Warning: 9156R_1_1.bmp not found in metadata!
# Warning: 9152L_1_3.bmp not found in metadata!
# Warning: 9199R_3_7.bmp not found in metadata!
# Warning: 9191R_1_4.bmp not found in metadata!
# Warning: 9083R_10_1.bmp not found in metadata!
# Warning: 9199R_3_2.bmp not found in metadata!
# Warning: 9155L_4_4.bmp not found in metadata!
# Extracting CLIP Features: 100%|██████████| 89/89 [00:08<00:00, 10.26it/s]
# ====== Inference Metrics ======
# MAE: 92.426
# RMSE: 170.308
# R² Score: 0.385

# %% [markdown]
# ## CNN INFERENCE ON SYNTHETIC SET

# %%
import os
import json
import torch
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

from modules.networks import CustomInception , CustomDenseNet121 # or CustomVGG19, etc.

# === CONFIG ===
model_name = 'densenet'  # change if using another model
input_channels = 1
pretrained = False
batch_size = 64

image_dir = '/DATA2/akshay/Akshat/NIJ/nir_images'  # directory with images (no subfolders)
metadata_csv = '/DATA2/akshay/Akshat/metadata/nij_nir.csv'  # CSV with 'filename' and 'pmi' columns
checkpoint_dir = '/DATA2/akshay/Akshat/checkpoints/syn_den'
output_dir = '/DATA2/akshay/Akshat/metadata'
Path(output_dir).mkdir(parents=True, exist_ok=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Inference on device: {device}")

# === Load Checkpoint ===
def load_best_model(model, checkpoint_dir):
    latest_file = os.path.join(checkpoint_dir, 'latest.json')
    if os.path.exists(latest_file):
        with open(latest_file, 'r') as f:
            latest = json.load(f)
        checkpoint = torch.load(latest['path'], map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        print(f"Loaded model from checkpoint: {latest['path']}")
    else:
        raise FileNotFoundError("No checkpoint found!")

# === Dataset for Inference ===
class FlatDirNIRDataset(Dataset):
    def __init__(self, metadata_df, root_dir, transform=None):
        self.metadata = metadata_df
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        row = self.metadata.iloc[idx]
        img_path = os.path.join(self.root_dir, row['filename'])
        image = Image.open(img_path).convert('L')  # grayscale
        label = row['pmi']

        if self.transform:
            image = self.transform(image)

        return row['filename'], image, label

# === Transforms (match training) ===
if model_name == "inception":
    transform = transforms.Compose([
        transforms.Resize(299),
        transforms.ToTensor()
    ])
else:
    transform = transforms.Compose([
        transforms.Resize(224),
        transforms.ToTensor()
    ])

# === Load model ===
if model_name == "inception":
    model = CustomInception(input_channels=input_channels, pretrained=pretrained, num_classes=1)
elif model_name == "vgg":
    model = CustomVGG19(input_channels=input_channels, pretrained=pretrained, num_classes=1)
elif model_name == "resnet":
    model = CustomResNet152(input_channels=input_channels, pretrained=pretrained, num_classes=1)
elif model_name == "densenet":
    model = CustomDenseNet121(input_channels=input_channels, pretrained=pretrained, num_classes=1)
else:
    raise ValueError("Unknown model architecture")

model = model.to(device)
load_best_model(model, checkpoint_dir)
model.eval()

# === Load new dataset ===
metadata_df = pd.read_csv(metadata_csv)
# metadata_df = metadata_df[metadata_df['pmi'] < 400].reset_index(drop=True)
dataset = FlatDirNIRDataset(metadata_df, image_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# === Inference Loop ===
all_filenames = []
all_preds = []
all_targets = []

with torch.no_grad():
    for filenames, inputs, targets in tqdm(dataloader):
        inputs = inputs.to(device)
        outputs = model(inputs)
        preds = outputs.cpu().numpy().flatten()

        all_filenames.extend(filenames)
        all_preds.extend(preds)
        all_targets.extend(targets.numpy().flatten())

# === Metrics ===
mse = mean_squared_error(all_targets, all_preds)
rmse = np.sqrt(mse)
mae = mean_absolute_error(all_targets, all_preds)

print("\n====== Inference Results ======")
print(f"MSE :  {mse:.2f}")
print(f"RMSE:  {rmse:.2f}")
print(f"MAE :  {mae:.2f}")

# === Save Results ===
results_df = pd.DataFrame({
    'filename': all_filenames,
    'Actual': all_targets,
    'Predicted': all_preds
})
# results_df.to_csv(os.path.join(output_dir, f"{model_name}_inference_results.csv"), index=False)

# # === Scatter Plot ===
# plt.figure(figsize=(8, 6))
# plt.scatter(all_targets, all_preds, color='blue', label='Predicted')
# plt.plot(all_targets, all_targets, color='red', linestyle='dashed', label='Ideal')
# plt.xlabel('Actual PMI')
# plt.ylabel('Predicted PMI')
# plt.title('Inference Results')
# plt.legend()
# plt.grid(True)
# plt.savefig(os.path.join(output_dir, f"{model_name}_inference_plot.pdf"), dpi=300)
# plt.close()
# Out:
# Inference on device: cuda
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Loaded model from checkpoint: /DATA2/akshay/Akshat/checkpoints/syn_den/checkpoint_epoch_17.pt
# 100%|██████████| 89/89 [00:05<00:00, 15.27it/s]
# ====== Inference Results ======
# MSE :  34766.10
# RMSE:  186.46
# MAE :  94.76

# %% [markdown]
# ## CNN (WARSAW) INFERENCE ON NIJ

# %%
import os
import torch
import pandas as pd
from PIL import Image
from torchvision import transforms, models
from torch.utils.data import DataLoader
from modules.dataset import CustomDataset
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# ==== 🔧 MODIFY THESE PARAMETERS BELOW ====

MODEL_NAME = "inception"  # "inception" or "densenet"
CHECKPOINT_PATH = "/DATA2/akshay/Akshat/10_fold_results/RGB_sample_disjoint/inception_RGB_opt_Adam_pret_False_wd_True_best_model_fold_1.pth"
CSV_PATH = "/DATA2/akshay/Akshat/metadata/nij_rgb_meta.csv"
IMAGE_DIR = "/DATA2/akshay/Akshat/NIJ/rgb_images_ISOcropped_isoRes"
OUTPUT_PATH = "/DATA2/akshay/Akshat/cnn_predictions.csv"
os.makedirs(os.path.dirname(OUTPUT_PATH), exist_ok=True)
BATCH_SIZE = 16

# ===========================================

def get_transforms(model_name):
    if model_name == "inception":
        return transforms.Compose([
            transforms.Resize(299),
            transforms.ToTensor()
        ])
    return transforms.Compose([
        transforms.ToTensor()
    ])

def load_model(model_name, checkpoint_path, device):
    if model_name == "inception":
        model = models.inception_v3(pretrained=False, aux_logits=False)
        model.fc = torch.nn.Linear(model.fc.in_features, 1)
    elif model_name == "densenet":
        model = models.densenet121(pretrained=False)
        model.classifier = torch.nn.Linear(model.classifier.in_features, 1)
    else:
        raise ValueError("Invalid model name")
    
    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    return model.to(device).eval()

def run_inference():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    transform = get_transforms(MODEL_NAME)
    data = pd.read_csv(CSV_PATH)
    # data = data[data['pmi'] < 400]
    dataset = CustomDataset(data=data, root_dir=IMAGE_DIR, transform=transform)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

    model = load_model(MODEL_NAME, CHECKPOINT_PATH, device)

    filenames, preds, targets = [], [], []

    with torch.no_grad():
        for batch in dataloader:
            batch_filenames, inputs, labels = batch
            inputs = inputs.to(device)
            labels = labels.to(device).unsqueeze(1).float()

            outputs = model(inputs)
            filenames.extend(batch_filenames)
            preds.extend(outputs.squeeze(1).cpu().numpy())
            targets.extend(labels.squeeze(1).cpu().numpy())

    results_df = pd.DataFrame({
        'filename': filenames,
        'Actual': targets,
        'Predicted': preds
    })
    os.makedirs(os.path.dirname(OUTPUT_PATH), exist_ok=True)
    results_df.to_csv(OUTPUT_PATH, index=False)
    print(f"[✓] Results saved to {OUTPUT_PATH}")

    mae = mean_absolute_error(targets, preds)
    rmse = np.sqrt(mean_squared_error(targets, preds))
    print(f"MAE: {mae:.2f} | RMSE: {rmse:.2f}")

if __name__ == "__main__":
    run_inference()
# Out:
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# [✓] Results saved to /DATA2/akshay/Akshat/cnn_predictions.csv
# MAE: 95.21 | RMSE: 163.29

# %%
import os
import torch
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import mean_squared_error, mean_absolute_error
from torch.utils.data import DataLoader
from torchvision import transforms
from modules.dataset import CustomDataset
from modules.networks import CustomDenseNet121, CustomInception

# ========= CONFIGURABLE PARAMETERS ========= #
model_name = 'densenet'  # Options: 'inception' or 'densenet'
pretrained = False
input_channels = 1
batch_size = 16
num_workers = 4

# Paths
image_root_dir = '/DATA2/akshay/Akshat/NIJ/nir_images'
metadata_file = '/DATA2/akshay/Akshat/metadata/nij_nir.csv'
checkpoint_path = '/DATA2/akshay/Akshat/10_fold_results/NIR/densenet_NIR_opt_Adam_pret_False_wd_True_best_model_fold_1.pth'
# =========================================== #

# Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running inference on {device} using {model_name.upper()}")

# Load model
if model_name == 'inception':
    model = CustomInception(input_channels=input_channels, pretrained=pretrained, num_classes=1)
    transform = transforms.Compose([
        transforms.Resize(299),
        transforms.ToTensor()
    ])
elif model_name == 'densenet':
    model = CustomDenseNet121(input_channels=input_channels, pretrained=pretrained, num_classes=1)
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
else:
    raise ValueError("Unsupported model. Choose from 'inception' or 'densenet'.")

model = model.to(device)
model.load_state_dict(torch.load(checkpoint_path, map_location=device))
model.eval()

# Load test data
test_df = pd.read_csv(metadata_file)
test_dataset = CustomDataset(data=test_df, root_dir=image_root_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# Inference
all_preds = []
all_targets = []
all_filenames = []

with torch.no_grad():
    for filenames, inputs, targets in tqdm(test_loader, desc="Inferencing"):
        inputs = inputs.to(device)
        targets = targets.to(device, dtype=torch.float).unsqueeze(1)

        outputs = model(inputs)
        all_preds.extend(outputs.cpu().numpy().flatten())
        all_targets.extend(targets.cpu().numpy().flatten())
        all_filenames.extend(filenames)

# Metrics
mse = mean_squared_error(all_targets, all_preds)
rmse = np.sqrt(mse)
mae = mean_absolute_error(all_targets, all_preds)

print("\n========== Inference Results ==========")
print(f"Model       : {model_name}")
print(f"Checkpoint  : {os.path.basename(checkpoint_path)}")
print(f"MSE         : {mse:.4f}")
print(f"RMSE        : {rmse:.4f}")
print(f"MAE         : {mae:.4f}")
print("=======================================")

# Save predictions (optional)
results_df = pd.DataFrame({
    'filename': all_filenames,
    'actual': all_targets,
    'predicted': all_preds
})
out_path = checkpoint_path.replace('.pth', '_inference_results.csv')
results_df.to_csv(out_path, index=False)
print(f"Results saved to: {out_path}")
# Out:
# Running inference on cuda using DENSENET
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Inferencing: 100%|██████████| 354/354 [00:18<00:00, 19.21it/s]
# ========== Inference Results ==========
# Model       : densenet
# Checkpoint  : densenet_NIR_opt_Adam_pret_False_wd_True_best_model_fold_1.pth
# MSE         : 50326.9633
# RMSE        : 224.3367
# MAE         : 84.8452
# =======================================
# Results saved to: /DATA2/akshay/Akshat/10_fold_results/NIR/densenet_NIR_opt_Adam_pret_False_wd_True_best_model_fold_1_inference_results.csv

# %% [markdown]
# ## Multispectral Evaluation

# %%
import os
import torch
import pandas as pd
from tqdm import tqdm
import numpy as np
from torch.utils.data import DataLoader
import torch.nn as nn
from pathlib import Path
from torchvision import transforms
from PIL import Image, ImageEnhance
from sklearn.metrics import mean_squared_error, mean_absolute_error
from modules.dataset import TwoStreamCustomDataset
from modules.networks import TwoStreamVGG, TwoStreamDenseNet, TwoStreamResNet, TwoStreamInception

# --- Configs ---
nir_dir = '/DATA2/akshay/Akshat/NIJ/nir_images/'
rgb_dir = '/DATA2/akshay/Akshat/NIJ/rgb_images_ISOcropped_isoRes/'
test_metadata_csv = '/DATA2/akshay/Akshat/metadata/multi_nij.csv'
checkpoint_path = '/DATA2/akshay/Akshat/10_fold_results/multispectral_sam/inception_multispectral_opt_Adam_pret_False_wd_True_best_model_fold_3.pth'
output_results_csv = '/DATA2/akshay/Akshat/10_fold_results/multispectral_sam/inference_results.csv'
model_name = 'inception'  # or 'resnet', 'vgg', 'inception'
pretrained = False
batch_size = 32

# --- Device ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# --- Load Model ---
if model_name == "vgg":
    model = TwoStreamVGG(pretrained=pretrained, num_classes=1)
elif model_name == "resnet":
    model = TwoStreamResNet(pretrained=pretrained, num_classes=1)
elif model_name == "inception":
    model = TwoStreamInception(pretrained=pretrained, num_classes=1)
elif model_name == "densenet":
    model = TwoStreamDenseNet(pretrained=pretrained, num_classes=1)
else:
    raise ValueError("Unknown model name.")

model.load_state_dict(torch.load(checkpoint_path))
model.to(device)
model.eval()

# --- Transforms ---
if model_name == "inception":
    test_transform = transforms.Compose([
        transforms.Resize(299),
        transforms.ToTensor()
    ])
else:
    test_transform = transforms.Compose([
        transforms.ToTensor()
    ])

# --- Dataset ---
test_df = pd.read_csv(test_metadata_csv)
test_dataset = TwoStreamCustomDataset(data=test_df, nir_dir=nir_dir, rgb_dir=rgb_dir, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=8)

# --- Inference ---
all_filenames = []
all_subjects = []
all_actual_pmi = []
all_predicted_pmi = []

with torch.no_grad():
    for filenames, nir_imgs, rgb_imgs, targets in tqdm(test_loader, desc="Running inference"):
        nir_imgs = nir_imgs.to(device)
        rgb_imgs = rgb_imgs.to(device)
        targets = targets.unsqueeze(1).to(device, dtype=torch.float)

        outputs = model(nir_imgs, rgb_imgs)

        all_filenames.extend(filenames)
        all_subjects.extend([Path(f).stem.split('_')[0] for f in filenames])
        all_actual_pmi.extend(targets.view(-1).cpu().numpy())
        all_predicted_pmi.extend(outputs.view(-1).cpu().numpy())

# --- Save Results ---
results_df = pd.DataFrame({
    "filename": all_filenames,
    "subject_id": all_subjects,
    "actual_pmi": all_actual_pmi,
    "predicted_pmi": all_predicted_pmi
})
results_df.to_csv(output_results_csv, index=False)
print(f"\nSaved inference results to {output_results_csv}")

# --- Metrics ---
mse = mean_squared_error(all_actual_pmi, all_predicted_pmi)
rmse = np.sqrt(mse)
mae = mean_absolute_error(all_actual_pmi, all_predicted_pmi)

print(f"\n🧾 Inference Metrics:\nMSE: {mse:.2f} | RMSE: {rmse:.2f} | MAE: {mae:.2f}")
# Out:
# Using device: cuda
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /DATA2/akshay/Akshat/iris/lib/python3.11/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Running inference: 100%|██████████| 112/112 [00:08<00:00, 12.70it/s]
# Saved inference results to /DATA2/akshay/Akshat/10_fold_results/multispectral_sam/inference_results.csv
#
# 🧾 Inference Metrics:
# MSE: 28980.82 | RMSE: 170.24 | MAE: 84.54
